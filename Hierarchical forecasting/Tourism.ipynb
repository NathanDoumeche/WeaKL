# %% [markdown]
# # Australian tourism

# %% [markdown]
# ## Import data

# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
tourism_data = pd.read_csv('TourismData_v3.csv')

# %%
type_float64 = True

if type_float64:
  torch.set_default_dtype(torch.float64)
  np_dtype = np.float64
else:
  torch.set_default_dtype(torch.float32)
  np_dtype = np.float32

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Package

# %% [markdown]
# ### S matrix

# %%
def create_sum_matrix(identifiers, lambdas, device):
    states = sorted(set([id[:1] for id in identifiers]))
    zones = sorted(set([id[:2] for id in identifiers]))
    regions = sorted(set([id[:3] for id in identifiers]))

    n_states = len(states)
    n_zones = len(zones)
    n_regions = len(regions)
    n_categories = len(identifiers)
    n_tot = 1 + n_states + n_zones + n_regions +n_categories

    lambda_tot = lambdas["lambda_tot"]
    lambda_states = lambdas["lambda_states"]
    lambda_zones = lambdas["lambda_zones"]
    lambda_regions = lambdas["lambda_regions"]
    lambda_categories = lambdas["lambda_categories"]

    lambda_mat = torch.eye(n_tot, device = device)

    S_mat = torch.zeros(n_tot, n_categories, device = device)

    #The first row of the S matrix is always filled with 1
    S_mat[0] = torch.ones(n_categories, device = device)
    lambda_mat[0,0] = lambda_tot
    counter = 1

    #Then, we fill the next rows with the state level
    for state in states:
        for i in range(n_categories):
            if identifiers[i][:1] == state:
                S_mat[counter, i] = 1
        lambda_mat[counter, counter] = lambda_states
        counter+=1

    #Then, we fill the next rows with the zone level
    for zone in zones:
        for i in range(n_categories):
            if identifiers[i][:2] == zone:
                S_mat[counter, i] = 1
        lambda_mat[counter, counter] = lambda_zones
        counter+=1

    #Then, we fill the next rows with the region level
    for region in regions:
        for i in range(n_categories):
            if identifiers[i][:3] == region:
                S_mat[counter, i] = 1
        lambda_mat[counter, counter] = lambda_regions
        counter+=1

    #Then, we fill the next rows with the category level
    for i in range(n_categories):
        S_mat[counter, i] = 1
        lambda_mat[counter, counter] = lambda_categories
        counter+=1
    return S_mat, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories

# %% [markdown]
# ### Linear regression

# %%
def linear_weights(h_learn, start, tourism_data):
  lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":1}

  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_train = torch.tensor(tourism_data.iloc[:start, 2:].values, device=device)

  thetas = []

  for i in range(n_tot):
    combination = s_matrix_unscaled[i]
    y_train_i = y_train@combination

    lagged_columns = []
    for lag in range(1,h_learn+1):
        lagged_col = torch.roll(y_train_i, shifts=lag)
        lagged_columns.append(lagged_col)

    x_train_i = torch.stack(lagged_columns, dim=1)[h_learn:start]
    y_train_i = y_train_i[h_learn:start]

    thetas.append(torch.linalg.solve(x_train_i.T@x_train_i, (x_train_i.T)@y_train_i))
  return thetas

def linear_regression(h_learn, start, end, tourism_data, thetas):
  lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":1}

  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_test = torch.tensor(tourism_data.iloc[start-h_learn:end, 2:].values, device=device)

  tourism_tensor = torch.tensor(tourism_data.iloc[:, 2:].values, device=device)
  errors = []
  
  n_test = y_test.shape[0]
  se_table=pd.DataFrame()
  for i in range(n_tot):
    combination = s_matrix_unscaled[i]
    y_test_i = y_test@combination

    lagged_columns = []
    for lag in range(1,h_learn+1):
        lagged_col = torch.roll(y_test_i, shifts=lag)
        lagged_columns.append(lagged_col)

    x_test_i = torch.stack(lagged_columns, dim=1)[h_learn:]
    y_test_i = y_test_i[h_learn:]
    theta_i = thetas[i]

    forecast = x_test_i@theta_i
    err = torch.square(forecast - y_test_i)
    errors.append(torch.mean(err))
    se_table = pd.concat([se_table,pd.DataFrame(err.cpu().numpy()).T])
  errors = torch.stack(errors)
  se_by_level=pd.DataFrame()
    
  mse_tot = torch.sum(errors[0])
  se_by_level["total"]=se_table.iloc[0]
  counter=1
  mse_states = torch.sum(errors[counter:counter+n_states])
  se_by_level["states"]=(se_table.iloc[counter:(counter+n_states)]).sum(axis=0)
  counter+=n_states
  mse_zones = torch.sum(errors[counter:counter+n_zones])
  se_by_level["zones"]=(se_table.iloc[counter:(counter+n_zones)]).sum(axis=0)
  counter+=n_zones
  mse_regions = torch.sum(errors[counter:counter+n_regions])
  se_by_level["regions"]=(se_table.iloc[counter:(counter+n_regions)]).sum(axis=0)
  counter+=n_regions
  mse_categories = torch.sum(errors[counter:counter+n_categories])
  se_by_level["categories"]=(se_table.iloc[counter:(counter+n_categories)]).sum(axis=0)
  mse_hier = torch.sum(errors)
  se_by_level["hier"]=se_table.sum(axis=0)

    

  return mse_hier, mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level

# %% [markdown]
# ### WeaKL-BU

# %%
def weakl_bottom(lambdas, h_learn, start, end, tourism_data):
  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_train = torch.tensor(tourism_data.iloc[h_learn:start, 2:].values, device=device)
  y_test = torch.tensor(tourism_data.iloc[start:end, 2:].values, device=device)

  tourism_tensor = torch.tensor(tourism_data.iloc[:, 2:].values, device=device)

  x_train = []
  x_test = []
  for h in range(h_learn):
      x_train.append(tourism_tensor[h:start-h_learn+h].view(-1,n_categories,1))
      x_test.append(tourism_tensor[start-h_learn+h:end-h_learn+h].view(-1,n_categories,1))

  x_train = torch.cat(x_train, dim=2)
  x_test = torch.cat(x_test, dim=2)

  n = x_train.shape[0]
  d = h_learn
  s_matrix = lambda_mat@s_matrix_unscaled

  cov_x = torch.zeros(n_categories*d, n_categories*d, device=device)
  cov_y = torch.zeros(n_categories*d, device=device)
  s_sym = s_matrix.T @ s_matrix

  for i in range(n):
      X_mat = torch.zeros(n_categories, n_categories*d, device=device)
      for j in range(n_categories):
          X_mat[j, j*h_learn:((j+1)*h_learn)] = x_train[i,j]
      cov_y+= X_mat.T@s_sym@y_train[i]
      cov_x+= X_mat.T @ s_sym @ X_mat

  hat_theta = torch.linalg.solve(cov_x, cov_y)

  mse = torch.zeros(n_tot, device=device)

  n_test = y_test.shape[0]
  se_table=pd.DataFrame()
  for i in range(n_test):
      X_mat = torch.zeros(n_categories, n_categories*d, device=device)

      for j in range(n_categories):
          X_mat[j, j*h_learn:((j+1)*h_learn)] = x_test[i,j]

      forecast = s_matrix_unscaled@X_mat@hat_theta
      err = torch.square(forecast - s_matrix_unscaled@y_test[i])
     
      mse+=err
      se_table[len(se_table.columns)] = err.cpu().numpy()

  
  mse=mse/n_test
  se_by_level=pd.DataFrame()
  mse_tot = mse[0]
  se_by_level["total"]=se_table.iloc[0]
    
  counter=1
  mse_states = torch.sum(mse[counter:counter+n_states])
  se_by_level["states"]=(se_table.iloc[counter:(counter+n_states)]).sum(axis=0)
    
  counter+=n_states
  mse_zones = torch.sum(mse[counter:counter+n_zones])
  se_by_level["zones"]=(se_table.iloc[counter:(counter+n_zones)]).sum(axis=0)
    
  counter+=n_zones
  mse_regions = torch.sum(mse[counter:counter+n_regions])
  se_by_level["regions"]=(se_table.iloc[counter:(counter+n_regions)]).sum(axis=0)
    
  counter+=n_regions
  mse_categories = torch.sum(mse[counter:counter+n_categories])
  se_by_level["categories"]=(se_table.iloc[counter:(counter+n_categories)]).sum(axis=0)
    
  mse_hier = torch.sum(mse)
  se_by_level["hier"]=se_table.sum(axis=0)

  print("MSE total: ", mse_tot)
  print("MSE states: ", mse_states)
  print("MSE zones: ", mse_zones)
  print("MSE regions: ", mse_regions)
  print("MSE categories: ", mse_categories)
  print("MSE hier: ", mse_hier)
  return mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, hat_theta, se_by_level

# %% [markdown]
# ### Reconciliations (OLS + MinT)

# %%
def reconciliation_ols(h_learn, start, end, tourism_data, thetas):
  lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":1}

  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_test = torch.tensor(tourism_data.iloc[start-h_learn:end, 2:].values, device=device)

  tourism_tensor = torch.tensor(tourism_data.iloc[:, 2:].values, device=device)
  errors = []
  forecasts = []

  for i in range(n_tot):
    combination = s_matrix_unscaled[i]
    y_test_i = y_test@combination

    lagged_columns = []
    for lag in range(1,h_learn+1):
        lagged_col = torch.roll(y_test_i, shifts=lag)
        lagged_columns.append(lagged_col)

    x_test_i = torch.stack(lagged_columns, dim=1)[h_learn:]
    y_test_i = y_test_i[h_learn:]
    theta_i = thetas[i]

    forecasts.append(x_test_i@theta_i)

  forecasts = torch.stack(forecasts, dim=1)
  transform = s_matrix_unscaled@torch.linalg.solve(s_matrix_unscaled.T@s_matrix_unscaled, s_matrix_unscaled.T)
  mse = torch.zeros(n_tot, device=device)

  y_test = y_test[h_learn:]
  n_test = y_test.shape[0]
  se_table=pd.DataFrame()
  for i in range(n_test):
      forecast = forecasts[i]
      forecast_reconcile = transform@forecast
      err = torch.square(forecast_reconcile - s_matrix_unscaled@y_test[i])
      mse+=err
      se_table[len(se_table.columns)] = err.cpu().numpy()

  mse=mse/n_test
  se_by_level=pd.DataFrame()
  mse_tot = mse[0]
  se_by_level["total"]=se_table.iloc[0]
    
  counter=1
  mse_states = torch.sum(mse[counter:counter+n_states])
  se_by_level["states"]=(se_table.iloc[counter:(counter+n_states)]).sum(axis=0)
    
  counter+=n_states
  mse_zones = torch.sum(mse[counter:counter+n_zones])
  se_by_level["zones"]=(se_table.iloc[counter:(counter+n_zones)]).sum(axis=0)
    
  counter+=n_zones
  mse_regions = torch.sum(mse[counter:counter+n_regions])
  se_by_level["regions"]=(se_table.iloc[counter:(counter+n_regions)]).sum(axis=0)
    
  counter+=n_regions
  mse_categories = torch.sum(mse[counter:counter+n_categories])
  se_by_level["categories"]=(se_table.iloc[counter:(counter+n_categories)]).sum(axis=0)
    
  mse_hier = torch.sum(mse)
  se_by_level["hier"]=se_table.sum(axis=0)

  print("MSE total: ", mse_tot)
  print("MSE states: ", mse_states)
  print("MSE zones: ", mse_zones)
  print("MSE regions: ", mse_regions)
  print("MSE categories: ", mse_categories)
  print("MSE hier: ", mse_hier)
  return mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level

# %%
def reconciliation_mint(h_learn, start, end, tourism_data, thetas):
  lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":1}

  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_test = torch.tensor(tourism_data.iloc[start-h_learn:end, 2:].values, device=device)

  J_mat = torch.zeros(n_categories, n_tot, device=device)
  J_mat = J_mat.T
  J_mat[n_tot-n_categories:] = torch.eye(n_categories, device=device)
  J_mat = J_mat.T

  C = s_matrix_unscaled[:n_tot-n_categories]

  U = torch.zeros(n_tot-n_categories, n_tot, device=device)
  U[:,:n_tot-n_categories] = torch.eye(n_tot-n_categories, device=device)
  U[:,n_tot-n_categories:] = -C
  U = U.T

  y_train = torch.tensor(tourism_data.iloc[:start, 2:].values, device=device)

  error_train=[]
  for i in range(n_tot):
    combination = s_matrix_unscaled[i]
    y_train_i = y_train@combination

    lagged_columns = []
    for lag in range(1,h_learn+1):
        lagged_col = torch.roll(y_train_i, shifts=lag)
        lagged_columns.append(lagged_col)

    x_train_i = torch.stack(lagged_columns, dim=1)[h_learn:start]
    y_train_i = y_train_i[h_learn:start]
    error_train.append(y_train_i - x_train_i@thetas[i])

  error_train = torch.stack(error_train, dim=1)
  Cov_mat = error_train.T@error_train/(len(error_train)-1)
  error_standardized = (error_train-torch.mean(error_train, dim=0)) /torch.std(error_train, dim=0)
  Corr_mat = error_standardized.T@error_standardized/(len(error_standardized)-1)
  Corr_var = (torch.square(error_standardized.T)@torch.square(error_standardized)/(len(error_standardized)-1) - torch.square(Corr_mat))/len(error_standardized)
  ones = torch.ones(n_tot, device=device)
  lambda_D = (ones.T@Corr_var@ones-torch.sum(torch.diagonal(Corr_var)))/(ones.T@torch.square(Corr_mat)@ones-torch.sum(torch.diagonal(torch.square(Corr_mat))))
  W_mat = lambda_D*torch.diag(torch.diagonal(Cov_mat)) + (1-lambda_D)*Cov_mat
  print("Lambda_D = ", lambda_D)
  P_mat = J_mat-J_mat@W_mat@U@torch.linalg.solve(U.T@W_mat@U, U.T)

  tourism_tensor = torch.tensor(tourism_data.iloc[:, 2:].values, device=device)
  errors = []
  forecasts = []

  for i in range(n_tot):
    combination = s_matrix_unscaled[i]
    y_test_i = y_test@combination

    lagged_columns = []
    for lag in range(1,h_learn+1):
        lagged_col = torch.roll(y_test_i, shifts=lag)
        lagged_columns.append(lagged_col)

    x_test_i = torch.stack(lagged_columns, dim=1)[h_learn:]
    y_test_i = y_test_i[h_learn:]
    theta_i = thetas[i]

    forecasts.append(x_test_i@theta_i)

  forecasts = torch.stack(forecasts, dim=1)
  transform = s_matrix_unscaled@P_mat
  mse = torch.zeros(n_tot, device=device)

  y_test = y_test[h_learn:]
  n_test = y_test.shape[0]
  se_table=pd.DataFrame()
  for i in range(n_test):
      forecast = forecasts[i]
      forecast_reconcile = transform@forecast
      err = torch.square(forecast_reconcile - s_matrix_unscaled@y_test[i])
      mse+=err
      se_table[len(se_table.columns)] = err.cpu().numpy()

  mse=mse/n_test
  se_by_level=pd.DataFrame()
  mse_tot = mse[0]
  se_by_level["total"]=se_table.iloc[0]
    
  counter=1
  mse_states = torch.sum(mse[counter:counter+n_states])
  se_by_level["states"]=(se_table.iloc[counter:(counter+n_states)]).sum(axis=0)
    
  counter+=n_states
  mse_zones = torch.sum(mse[counter:counter+n_zones])
  se_by_level["zones"]=(se_table.iloc[counter:(counter+n_zones)]).sum(axis=0)
    
  counter+=n_zones
  mse_regions = torch.sum(mse[counter:counter+n_regions])
  se_by_level["regions"]=(se_table.iloc[counter:(counter+n_regions)]).sum(axis=0)
    
  counter+=n_regions
  mse_categories = torch.sum(mse[counter:counter+n_categories])
  se_by_level["categories"]=(se_table.iloc[counter:(counter+n_categories)]).sum(axis=0)
    
  mse_hier = torch.sum(mse)
  se_by_level["hier"]=se_table.sum(axis=0)

  print("MSE total: ", mse_tot)
  print("MSE states: ", mse_states)
  print("MSE zones: ", mse_zones)
  print("MSE regions: ", mse_regions)
  print("MSE categories: ", mse_categories)
  print("MSE hier: ", mse_hier)
  return mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level

# %% [markdown]
# ### WeaKL-G

# %%
def weakl_global(lambdas, h_learn, start, end, tourism_data):
  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_train = torch.tensor(tourism_data.iloc[h_learn:start, 2:].values, device=device)
  y_test = torch.tensor(tourism_data.iloc[start:end, 2:].values, device=device)

  tourism_tensor = torch.tensor(tourism_data.iloc[:, 2:].values, device=device)

  x_train = []
  x_test = []
  for h in range(h_learn):
      x_train.append(tourism_tensor[h:start-h_learn+h].view(-1,n_categories,1))
      x_test.append(tourism_tensor[start-h_learn+h:end-h_learn+h].view(-1,n_categories,1))

  x_train = torch.cat(x_train, dim=2)
  x_test = torch.cat(x_test, dim=2)

  n = x_train.shape[0]
  d = h_learn

  s_matrix = lambda_mat@s_matrix_unscaled

  cov_x = torch.zeros(n_tot*d, n_tot*d, device=device)
  cov_y = torch.zeros(n_tot*d, device=device)
  s_sym = s_matrix.T @ s_matrix

  proj_mat = torch.zeros(n_categories*d, n_tot*d, device=device)
  proj_mat[:, (n_tot-n_categories)*d:] = torch.eye(n_categories*d, device=device)

  for i in range(n):
      X_mat_tot = torch.zeros(n_tot, n_tot*d, device=device)
      for j in range(n_tot):
          X_mat_tot[j, j*h_learn:((j+1)*h_learn)] = x_train[i].T@s_matrix_unscaled[j]

      X_mat = torch.zeros(n_categories, n_categories*d, device=device)

      for j in range(n_categories):
          X_mat[j, j*h_learn:((j+1)*h_learn)] = x_train[i,j]
      cov_y+= X_mat_tot.T@s_matrix_unscaled@y_train[i]
      cov_x+= X_mat_tot.T  @ X_mat_tot
      cov_x+= proj_mat.T @ X_mat.T@s_matrix.T@(s_matrix@X_mat@proj_mat-X_mat_tot)
      cov_x-= X_mat_tot.T@lambda_mat@(s_matrix_unscaled@X_mat@proj_mat-X_mat_tot)
      print("Training: ", i+1, "/", n)

  hat_theta = torch.linalg.solve(cov_x, cov_y)
  mse = torch.zeros(n_tot, device=device)

  n_test = y_test.shape[0]

  se_table=pd.DataFrame()
  for i in range(n_test):
      X_mat_tot = torch.zeros(n_tot, n_tot*d, device=device)
      for j in range(n_tot):
          X_mat_tot[j, j*h_learn:((j+1)*h_learn)] = x_test[i].T@s_matrix_unscaled[j]

      forecast = X_mat_tot@hat_theta
      err = torch.square(forecast - s_matrix_unscaled@y_test[i])
     
      mse+=err
      se_table[len(se_table.columns)] = err.cpu().numpy()

  
  mse=mse/n_test
  se_by_level=pd.DataFrame()
  mse_tot = mse[0]
  se_by_level["total"]=se_table.iloc[0]
    
  counter=1
  mse_states = torch.sum(mse[counter:counter+n_states])
  se_by_level["states"]=(se_table.iloc[counter:(counter+n_states)]).sum(axis=0)
    
  counter+=n_states
  mse_zones = torch.sum(mse[counter:counter+n_zones])
  se_by_level["zones"]=(se_table.iloc[counter:(counter+n_zones)]).sum(axis=0)
    
  counter+=n_zones
  mse_regions = torch.sum(mse[counter:counter+n_regions])
  se_by_level["regions"]=(se_table.iloc[counter:(counter+n_regions)]).sum(axis=0)
    
  counter+=n_regions
  mse_categories = torch.sum(mse[counter:counter+n_categories])
  se_by_level["categories"]=(se_table.iloc[counter:(counter+n_categories)]).sum(axis=0)
    
  mse_hier = torch.sum(mse)
  se_by_level["hier"]=se_table.sum(axis=0)


  print("MSE total: ", mse_tot)
  print("MSE states: ", mse_states)
  print("MSE zones: ", mse_zones)
  print("MSE regions: ", mse_regions)
  print("MSE categories: ", mse_categories)
  print("MSE hier: ", mse_hier)
  return mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, hat_theta, se_by_level

# %% [markdown]
# ### WeaKL-T

# %%
import time as time

def weakl_bu_transfer(lambdas, lambda_r, h_learn, h_list, start, end, tourism_data):
  t1=time.time()

  identifiers = tourism_data.keys()[2:]
  s_matrix_unscaled, lambda_mat, n_tot, n_states, n_zones, n_regions, n_categories = create_sum_matrix(identifiers, lambdas, device)
  y_train = torch.tensor(tourism_data.iloc[h_learn:start, 2:].values, device=device)/10**3
  y_test = torch.tensor(tourism_data.iloc[start:end, 2:].values, device=device)/10**3

  tourism_tensor = torch.tensor(tourism_data.iloc[:, 2:].values, device=device)/10**3

  x_train = []
  x_test = []
  for h in h_list:
      x_train.append(tourism_tensor[h:start-h_learn+h].view(-1,n_categories,1))
      x_test.append(tourism_tensor[start-h_learn+h:end-h_learn+h].view(-1,n_categories,1))

  x_train = torch.cat(x_train, dim=2)
  x_test = torch.cat(x_test, dim=2)

  n = x_train.shape[0]
  d = len(h_list)
  s_matrix = lambda_mat@s_matrix_unscaled

  cov_y = torch.zeros(n_categories*d, device=device)
  s_sym = s_matrix.T @ s_matrix
  ir_mat = torch.eye(n_categories*d, device=device)-torch.kron(torch.ones(n_categories, n_categories, device=device), torch.eye(d, device=device))/n_categories
  cov_x = lambda_r**2*ir_mat

  indices = torch.arange(n_categories) * h_learn

  for i in range(n):
      X_mat = torch.block_diag(*x_train[i])
      cov_y+= X_mat.T@s_sym@y_train[i]
      cov_x+= X_mat.T @ s_sym @ X_mat

  hat_theta = torch.linalg.solve(cov_x, cov_y)

  mse = torch.zeros(n_tot, device=device)

  n_test = y_test.shape[0]

  se_table=pd.DataFrame()
  for i in range(n_test):
      X_mat = torch.zeros(n_categories, n_categories*d, device=device)

      for j in range(n_categories):
          X_mat[j, j*h_learn:((j+1)*h_learn)] = x_test[i,j]

      forecast = s_matrix_unscaled@X_mat@hat_theta
      err = torch.square(forecast - s_matrix_unscaled@y_test[i])
     
      mse+=err
      se_table[len(se_table.columns)] = err.cpu().numpy()

  
  mse=mse/n_test
  se_by_level=pd.DataFrame()
  mse_tot = mse[0]
  se_by_level["total"]=se_table.iloc[0]
    
  counter=1
  mse_states = torch.sum(mse[counter:counter+n_states])
  se_by_level["states"]=(se_table.iloc[counter:(counter+n_states)]).sum(axis=0)
    
  counter+=n_states
  mse_zones = torch.sum(mse[counter:counter+n_zones])
  se_by_level["zones"]=(se_table.iloc[counter:(counter+n_zones)]).sum(axis=0)
    
  counter+=n_zones
  mse_regions = torch.sum(mse[counter:counter+n_regions])
  se_by_level["regions"]=(se_table.iloc[counter:(counter+n_regions)]).sum(axis=0)
    
  counter+=n_regions
  mse_categories = torch.sum(mse[counter:counter+n_categories])
  se_by_level["categories"]=(se_table.iloc[counter:(counter+n_categories)]).sum(axis=0)
    
  mse_hier = torch.sum(mse)
  se_by_level["hier"]=se_table.sum(axis=0)

  print("MSE total: ", mse_tot)
  print("MSE states: ", mse_states)
  print("MSE zones: ", mse_zones)
  print("MSE regions: ", mse_regions)
  print("MSE categories: ", mse_categories)
  print("MSE hier: ", mse_hier)
  return mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, hat_theta, se_by_level

# %% [markdown]
# ### Moving block bootstrap

# %%
def mbb_var(X,l):
    n = len(X)
    N = n-l+1
    U=np.array([(X[i:(i+l)]).mean() for i in range(N)])
    mu = U.mean()
    return l*((U**2).mean()-mu**2)

# %% [markdown]
# ## Linear regression (Indep)

# %%
#Validation

h_learn = 24
start =  12*18*3//5
end =  12*18*4//5

thetas = linear_weights(h_learn, start, tourism_data)
mse_hier, mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level = linear_regression(h_learn, start, end, tourism_data, thetas)

# %%
print("MSE tot: ", mse_tot)
print("MSE states: ", mse_states)
print("MSE zones: ", mse_zones)
print("MSE regions: ", mse_regions)
print("MSE categories: ", mse_categories)
print("MSE hier: ", mse_hier)
# Out:
# MSE tot:  tensor(4856507.0918, device='cuda:0')
# MSE states:  tensor(2383337.4293, device='cuda:0')
# MSE zones:  tensor(1279993.8626, device='cuda:0')
# MSE regions:  tensor(1075122.9813, device='cuda:0')
# MSE categories:  tensor(1089953.4568, device='cuda:0')
# MSE hier:  tensor(10684914.8219, device='cuda:0')

# %%
t_s = mse_states/ mse_tot
s_z = mse_zones/ mse_states
z_r = mse_regions/ mse_zones
r_c = mse_categories/ mse_regions
print("Confidence tot / states: ", t_s)
print("Confidence states / zones: ", s_z)
print("Confidence zones / regions : ", z_r)
print("Confidence regions / categories: ", r_c)
print("The higher the confidence A/B, the more we trust A")
# Out:
# Confidence tot / states:  tensor(0.4908, device='cuda:0')
# Confidence states / zones:  tensor(0.5371, device='cuda:0')
# Confidence zones / regions :  tensor(0.8399, device='cuda:0')
# Confidence regions / categories:  tensor(1.0138, device='cuda:0')
# The higher the confidence A/B, the more we trust A

# %%
#Test

h_learn = 24
start =  12*18*4//5
end =  12*18*5//5

thetas = linear_weights(h_learn, start, tourism_data)
mse_hier, mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level = linear_regression(h_learn, start, end, tourism_data, thetas)

# %%
print("MSE tot: ", mse_tot)
print("MSE states: ", mse_states)
print("MSE zones: ", mse_zones)
print("MSE regions: ", mse_regions)
print("MSE categories: ", mse_categories)
print("MSE hier: ", mse_hier)
# Out:
# MSE tot:  tensor(3567390.3852, device='cuda:0')
# MSE states:  tensor(1774379.2107, device='cuda:0')
# MSE zones:  tensor(1424033.8924, device='cuda:0')
# MSE regions:  tensor(1232454.2508, device='cuda:0')
# MSE categories:  tensor(1173389.5580, device='cuda:0')
# MSE hier:  tensor(9171647.2970, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 3567390.3851640765 -+ 562745.1650101647
# MSE states: 1774379.2107395378 -+ 174709.41150481135
# MSE zones: 1424033.8924129861 -+ 50647.49338762182
# MSE regions: 1232454.2507507883 -+ 27543.84260814793
# MSE categories: 1173389.5579722298 -+ 31060.19196341837
# MSE hier: 9171647.29703962 -+ 686013.2957480351

# %%
thetas_tot = torch.stack(thetas, dim=1)


fig, (fig1, fig2) = plt.subplots(1,2, figsize=(14,7))
fig1.plot(torch.mean(thetas_tot, dim=1).cpu(),  color="darkcyan", label="Means")
fig1.plot(torch.std(thetas_tot, dim=1).cpu(),  color="maroon", label = "Standard deviations")
fig1.legend()
fig2.hist((thetas_tot[11,:]).cpu(), bins=30, color="darkslateblue")
# Out:
# (array([ 1.,  4., 12., 25., 40., 41., 36., 45., 27., 28., 27., 19., 21.,
#         21., 14.,  9., 18.,  8.,  6.,  4.,  3.,  3.,  2.,  0.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([-0.17059859, -0.1324078 , -0.09421701, -0.05602623, -0.01783544,
#          0.02035535,  0.05854614,  0.09673692,  0.13492771,  0.1731185 ,
#          0.21130929,  0.24950007,  0.28769086,  0.32588165,  0.36407244,
#          0.40226322,  0.44045401,  0.4786448 ,  0.51683559,  0.55502637,
#          0.59321716,  0.63140795,  0.66959874,  0.70778952,  0.74598031,
#          0.7841711 ,  0.82236188,  0.86055267,  0.89874346,  0.93693425,
#          0.97512503]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## Bottom-up (BU)

# %% [markdown]
# We check that the BU approach has the same MSE on the categories as the linear regression.

# %%
#validation
h_learn = 24
start =  12*18*3//5
end =  12*18*4//5
lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":1}

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_BU, se_by_level = weakl_bottom(lambdas, h_learn, start, end, tourism_data)
# Out:
# MSE total:  tensor(5925843.0861, device='cuda:0')
# MSE states:  tensor(2436833.0614, device='cuda:0')
# MSE zones:  tensor(1444344.8115, device='cuda:0')
# MSE regions:  tensor(1149683.7038, device='cuda:0')
# MSE categories:  tensor(1089953.4568, device='cuda:0')
# MSE hier:  tensor(12046658.1198, device='cuda:0')

# %%
#test
h_learn = 24
start = 12*18*4//5
end = 12*18
lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":1}

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_BU, se_by_level = weakl_bottom(lambdas, h_learn, start, end, tourism_data)
# Out:
# MSE total:  tensor(5246149.9760, device='cuda:0')
# MSE states:  tensor(2036320.0476, device='cuda:0')
# MSE zones:  tensor(1367516.7105, device='cuda:0')
# MSE regions:  tensor(1194302.0697, device='cuda:0')
# MSE categories:  tensor(1173389.5580, device='cuda:0')
# MSE hier:  tensor(11017678.3616, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 5246149.975955855 -+ 520660.6565193377
# MSE states: 2036320.0475754635 -+ 186509.42134938156
# MSE zones: 1367516.710466954 -+ 49690.80748089177
# MSE regions: 1194302.0696661074 -+ 24819.231674707113
# MSE categories: 1173389.5579722286 -+ 31060.191963416226
# MSE hier: 11017678.361636607 -+ 678352.5742465254

# %% [markdown]
# ## WeaKL-BU

# %%
print(t_s*s_z*z_r*r_c)
print(s_z*z_r*r_c)
print(z_r*r_c)
print(r_c)
# Out:
# tensor(0.2244, device='cuda:0')
# tensor(0.4573, device='cuda:0')
# tensor(0.8515, device='cuda:0')
# tensor(1.0138, device='cuda:0')

# %%
#Validation
h_learn = 24
start = 12*18*3//5
end = 12*18*4//5

lambdas = {
    "lambda_tot": 0.4,
    "lambda_states": 0.6,
    "lambda_zones": 0.9,
    "lambda_regions": 1,
    "lambda_categories":10}

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_WEAKL, se_by_level = weakl_bottom(lambdas, h_learn, start, end, tourism_data)
# Out:
# MSE total:  tensor(5609124.6335, device='cuda:0')
# MSE states:  tensor(2361189.8184, device='cuda:0')
# MSE zones:  tensor(1430857.2802, device='cuda:0')
# MSE regions:  tensor(1148909.6574, device='cuda:0')
# MSE categories:  tensor(1097106.1554, device='cuda:0')
# MSE hier:  tensor(11647187.5449, device='cuda:0')

# %%
#Test
start = 12*18*4//5
end = 12*18

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_WEAKL, se_by_level =  weakl_bottom(lambdas, h_learn, start, end, tourism_data)
# Out:
# MSE total:  tensor(4452257.9507, device='cuda:0')
# MSE states:  tensor(1912435.1968, device='cuda:0')
# MSE zones:  tensor(1339523.7137, device='cuda:0')
# MSE regions:  tensor(1187416.6810, device='cuda:0')
# MSE categories:  tensor(1174179.1024, device='cuda:0')
# MSE hier:  tensor(10065812.6446, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 4452257.950698123 -+ 448187.9030921545
# MSE states: 1912435.1968154474 -+ 187675.9186372014
# MSE zones: 1339523.7136807651 -+ 53376.28609534896
# MSE regions: 1187416.6809949197 -+ 25051.307463751255
# MSE categories: 1174179.1023977315 -+ 30507.266904814995
# MSE hier: 10065812.644586988 -+ 594482.7312874661

# %% [markdown]
# ## OLS reconciliation (Rec_OLS)

# %%
h_learn = 24
start =  12*18*4//5
end =  12*18*5//5

thetas = linear_weights(h_learn, start, tourism_data)
mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level = reconciliation_ols(h_learn, start, end, tourism_data, thetas)
# Out:
# MSE total:  tensor(3486764.0988, device='cuda:0')
# MSE states:  tensor(1748905.4768, device='cuda:0')
# MSE zones:  tensor(1347710.1743, device='cuda:0')
# MSE regions:  tensor(1180297.0491, device='cuda:0')
# MSE categories:  tensor(1169888.3028, device='cuda:0')
# MSE hier:  tensor(8933565.1017, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 3486764.098770368 -+ 522902.11929006164
# MSE states: 1748905.4768160568 -+ 204279.2467614113
# MSE zones: 1347710.1742538335 -+ 50135.812982031195
# MSE regions: 1180297.0490814494 -+ 24028.396800468377
# MSE categories: 1169888.3028260646 -+ 31994.00024323915
# MSE hier: 8933565.101747774 -+ 699585.8007470933

# %% [markdown]
# ## MinT

# %%
h_learn = 24
start =  12*18*4//5
end =  12*18*5

thetas = linear_weights(h_learn, start, tourism_data)
mse_tot, mse_states, mse_zones, mse_regions, mse_categories, se_by_level = reconciliation_mint(h_learn, start, end, tourism_data, thetas)
# Out:
# /tmp/tmp-d07784/ipykernel_62058/444485770.py:47: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3571.)
#   lambda_D = (ones.T@Corr_var@ones-torch.sum(torch.diagonal(Corr_var)))/(ones.T@torch.square(Corr_mat)@ones-torch.sum(torch.diagonal(torch.square(Corr_mat))))
# Lambda_D =  tensor(0.7158, device='cuda:0')
# MSE total:  tensor(3614305.9454, device='cuda:0')
# MSE states:  tensor(1692258.7235, device='cuda:0')
# MSE zones:  tensor(1290891.1613, device='cuda:0')
# MSE regions:  tensor(1152022.0279, device='cuda:0')
# MSE categories:  tensor(1168738.2998, device='cuda:0')
# MSE hier:  tensor(8918216.1579, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 3614305.9454226866 -+ 363829.6953740815
# MSE states: 1692258.7234534677 -+ 149377.90769126322
# MSE zones: 1290891.1612754313 -+ 48110.869637077594
# MSE regions: 1152022.0279023894 -+ 29550.69766741703
# MSE categories: 1168738.2998495821 -+ 27628.425848981118
# MSE hier: 8918216.157903556 -+ 513568.8621769181

# %% [markdown]
# ## WeaKL-G

# %%
h_learn = 24
start = 12*18*3//5
end = 12*18*4//5

lambdas = {
    "lambda_tot": 0,
    "lambda_states": 0,
    "lambda_zones": 0,
    "lambda_regions": 0,
    "lambda_categories":0}

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_WEAKL, se_by_level = weakl_global(lambdas, h_learn, start, end, tourism_data)
# Out:
# Training:  1 / 105
# Training:  2 / 105
# Training:  3 / 105
# Training:  4 / 105
# Training:  5 / 105
# Training:  6 / 105
# Training:  7 / 105
# Training:  8 / 105
# Training:  9 / 105
# Training:  10 / 105
# Training:  11 / 105
# Training:  12 / 105
# Training:  13 / 105
# Training:  14 / 105
# Training:  15 / 105
# Training:  16 / 105
# Training:  17 / 105
# Training:  18 / 105
# Training:  19 / 105
# Training:  20 / 105
# Training:  21 / 105
# Training:  22 / 105
# Training:  23 / 105
# Training:  24 / 105
# Training:  25 / 105
# Training:  26 / 105
# Training:  27 / 105
# Training:  28 / 105
# Training:  29 / 105
# Training:  30 / 105
# Training:  31 / 105
# Training:  32 / 105
# Training:  33 / 105
# Training:  34 / 105
# Training:  35 / 105
# Training:  36 / 105
# Training:  37 / 105
# Training:  38 / 105
# Training:  39 / 105
# Training:  40 / 105
# Training:  41 / 105
# Training:  42 / 105
# Training:  43 / 105
# Training:  44 / 105
# Training:  45 / 105
# Training:  46 / 105
# Training:  47 / 105
# Training:  48 / 105
# Training:  49 / 105
# Training:  50 / 105
# Training:  51 / 105
# Training:  52 / 105
# Training:  53 / 105
# Training:  54 / 105
# Training:  55 / 105
# Training:  56 / 105
# Training:  57 / 105
# Training:  58 / 105
# Training:  59 / 105
# Training:  60 / 105
# Training:  61 / 105
# Training:  62 / 105
# Training:  63 / 105
# Training:  64 / 105
# Training:  65 / 105
# Training:  66 / 105
# Training:  67 / 105
# Training:  68 / 105
# Training:  69 / 105
# Training:  70 / 105
# Training:  71 / 105
# Training:  72 / 105
# Training:  73 / 105
# Training:  74 / 105
# Training:  75 / 105
# Training:  76 / 105
# Training:  77 / 105
# Training:  78 / 105
# Training:  79 / 105
# Training:  80 / 105
# Training:  81 / 105
# Training:  82 / 105
# Training:  83 / 105
# Training:  84 / 105
# Training:  85 / 105
# Training:  86 / 105
# Training:  87 / 105
# Training:  88 / 105
# Training:  89 / 105
# Training:  90 / 105
# Training:  91 / 105
# Training:  92 / 105
# Training:  93 / 105
# Training:  94 / 105
# Training:  95 / 105
# Training:  96 / 105
# Training:  97 / 105
# Training:  98 / 105
# Training:  99 / 105
# Training:  100 / 105
# Training:  101 / 105
# Training:  102 / 105
# Training:  103 / 105
# Training:  104 / 105
# Training:  105 / 105
# MSE total:  tensor(4856507.0918, device='cuda:0')
# MSE states:  tensor(2383337.4293, device='cuda:0')
# MSE zones:  tensor(1279993.8626, device='cuda:0')
# MSE regions:  tensor(1075122.9813, device='cuda:0')
# MSE categories:  tensor(1089953.4568, device='cuda:0')
# MSE hier:  tensor(10684914.8219, device='cuda:0')

# %% [markdown]
# We check that setting $\Lambda = 0$ leads to the standard linear regression.

# %%
#Validation
h_learn = 24
start = 12*18*3//5
end = 12*18*4//5

lambdas = {
    "lambda_tot": 1,
    "lambda_states": 1,
    "lambda_zones": 1,
    "lambda_regions": 1,
    "lambda_categories":0}

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_WEAKL, se_by_level = weakl_global(lambdas, h_learn, start, end, tourism_data)
# Out:
# Training:  1 / 105
# Training:  2 / 105
# Training:  3 / 105
# Training:  4 / 105
# Training:  5 / 105
# Training:  6 / 105
# Training:  7 / 105
# Training:  8 / 105
# Training:  9 / 105
# Training:  10 / 105
# Training:  11 / 105
# Training:  12 / 105
# Training:  13 / 105
# Training:  14 / 105
# Training:  15 / 105
# Training:  16 / 105
# Training:  17 / 105
# Training:  18 / 105
# Training:  19 / 105
# Training:  20 / 105
# Training:  21 / 105
# Training:  22 / 105
# Training:  23 / 105
# Training:  24 / 105
# Training:  25 / 105
# Training:  26 / 105
# Training:  27 / 105
# Training:  28 / 105
# Training:  29 / 105
# Training:  30 / 105
# Training:  31 / 105
# Training:  32 / 105
# Training:  33 / 105
# Training:  34 / 105
# Training:  35 / 105
# Training:  36 / 105
# Training:  37 / 105
# Training:  38 / 105
# Training:  39 / 105
# Training:  40 / 105
# Training:  41 / 105
# Training:  42 / 105
# Training:  43 / 105
# Training:  44 / 105
# Training:  45 / 105
# Training:  46 / 105
# Training:  47 / 105
# Training:  48 / 105
# Training:  49 / 105
# Training:  50 / 105
# Training:  51 / 105
# Training:  52 / 105
# Training:  53 / 105
# Training:  54 / 105
# Training:  55 / 105
# Training:  56 / 105
# Training:  57 / 105
# Training:  58 / 105
# Training:  59 / 105
# Training:  60 / 105
# Training:  61 / 105
# Training:  62 / 105
# Training:  63 / 105
# Training:  64 / 105
# Training:  65 / 105
# Training:  66 / 105
# Training:  67 / 105
# Training:  68 / 105
# Training:  69 / 105
# Training:  70 / 105
# Training:  71 / 105
# Training:  72 / 105
# Training:  73 / 105
# Training:  74 / 105
# Training:  75 / 105
# Training:  76 / 105
# Training:  77 / 105
# Training:  78 / 105
# Training:  79 / 105
# Training:  80 / 105
# Training:  81 / 105
# Training:  82 / 105
# Training:  83 / 105
# Training:  84 / 105
# Training:  85 / 105
# Training:  86 / 105
# Training:  87 / 105
# Training:  88 / 105
# Training:  89 / 105
# Training:  90 / 105
# Training:  91 / 105
# Training:  92 / 105
# Training:  93 / 105
# Training:  94 / 105
# Training:  95 / 105
# Training:  96 / 105
# Training:  97 / 105
# Training:  98 / 105
# Training:  99 / 105
# Training:  100 / 105
# Training:  101 / 105
# Training:  102 / 105
# Training:  103 / 105
# Training:  104 / 105
# Training:  105 / 105
# MSE total:  tensor(4802008.2253, device='cuda:0')
# MSE states:  tensor(2288762.5686, device='cuda:0')
# MSE zones:  tensor(1228760.7705, device='cuda:0')
# MSE regions:  tensor(1025593.8548, device='cuda:0')
# MSE categories:  tensor(1042100.7792, device='cuda:0')
# MSE hier:  tensor(10387226.1983, device='cuda:0')

# %%
#Test
h_learn = 24
start = 12*18*4//5
end = 12*18

lambdas = {
    "lambda_tot": 1,
    "lambda_states": 1,
    "lambda_zones": 1,
    "lambda_regions": 1,
    "lambda_categories":0}

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_WEAKL, se_by_level = weakl_global(lambdas, h_learn, start, end, tourism_data)
# Out:
# Training:  1 / 148
# Training:  2 / 148
# Training:  3 / 148
# Training:  4 / 148
# Training:  5 / 148
# Training:  6 / 148
# Training:  7 / 148
# Training:  8 / 148
# Training:  9 / 148
# Training:  10 / 148
# Training:  11 / 148
# Training:  12 / 148
# Training:  13 / 148
# Training:  14 / 148
# Training:  15 / 148
# Training:  16 / 148
# Training:  17 / 148
# Training:  18 / 148
# Training:  19 / 148
# Training:  20 / 148
# Training:  21 / 148
# Training:  22 / 148
# Training:  23 / 148
# Training:  24 / 148
# Training:  25 / 148
# Training:  26 / 148
# Training:  27 / 148
# Training:  28 / 148
# Training:  29 / 148
# Training:  30 / 148
# Training:  31 / 148
# Training:  32 / 148
# Training:  33 / 148
# Training:  34 / 148
# Training:  35 / 148
# Training:  36 / 148
# Training:  37 / 148
# Training:  38 / 148
# Training:  39 / 148
# Training:  40 / 148
# Training:  41 / 148
# Training:  42 / 148
# Training:  43 / 148
# Training:  44 / 148
# Training:  45 / 148
# Training:  46 / 148
# Training:  47 / 148
# Training:  48 / 148
# Training:  49 / 148
# Training:  50 / 148
# Training:  51 / 148
# Training:  52 / 148
# Training:  53 / 148
# Training:  54 / 148
# Training:  55 / 148
# Training:  56 / 148
# Training:  57 / 148
# Training:  58 / 148
# Training:  59 / 148
# Training:  60 / 148
# Training:  61 / 148
# Training:  62 / 148
# Training:  63 / 148
# Training:  64 / 148
# Training:  65 / 148
# Training:  66 / 148
# Training:  67 / 148
# Training:  68 / 148
# Training:  69 / 148
# Training:  70 / 148
# Training:  71 / 148
# Training:  72 / 148
# Training:  73 / 148
# Training:  74 / 148
# Training:  75 / 148
# Training:  76 / 148
# Training:  77 / 148
# Training:  78 / 148
# Training:  79 / 148
# Training:  80 / 148
# Training:  81 / 148
# Training:  82 / 148
# Training:  83 / 148
# Training:  84 / 148
# Training:  85 / 148
# Training:  86 / 148
# Training:  87 / 148
# Training:  88 / 148
# Training:  89 / 148
# Training:  90 / 148
# Training:  91 / 148
# Training:  92 / 148
# Training:  93 / 148
# Training:  94 / 148
# Training:  95 / 148
# Training:  96 / 148
# Training:  97 / 148
# Training:  98 / 148
# Training:  99 / 148
# Training:  100 / 148
# Training:  101 / 148
# Training:  102 / 148
# Training:  103 / 148
# Training:  104 / 148
# Training:  105 / 148
# Training:  106 / 148
# Training:  107 / 148
# Training:  108 / 148
# Training:  109 / 148
# Training:  110 / 148
# Training:  111 / 148
# Training:  112 / 148
# Training:  113 / 148
# Training:  114 / 148
# Training:  115 / 148
# Training:  116 / 148
# Training:  117 / 148
# Training:  118 / 148
# Training:  119 / 148
# Training:  120 / 148
# Training:  121 / 148
# Training:  122 / 148
# Training:  123 / 148
# Training:  124 / 148
# Training:  125 / 148
# Training:  126 / 148
# Training:  127 / 148
# Training:  128 / 148
# Training:  129 / 148
# Training:  130 / 148
# Training:  131 / 148
# Training:  132 / 148
# Training:  133 / 148
# Training:  134 / 148
# Training:  135 / 148
# Training:  136 / 148
# Training:  137 / 148
# Training:  138 / 148
# Training:  139 / 148
# Training:  140 / 148
# Training:  141 / 148
# Training:  142 / 148
# Training:  143 / 148
# Training:  144 / 148
# Training:  145 / 148
# Training:  146 / 148
# Training:  147 / 148
# Training:  148 / 148
# MSE total:  tensor(3545230.0357, device='cuda:0')
# MSE states:  tensor(1753370.0680, device='cuda:0')
# MSE zones:  tensor(1367720.7359, device='cuda:0')
# MSE regions:  tensor(1188439.5561, device='cuda:0')
# MSE categories:  tensor(1146892.5025, device='cuda:0')
# MSE hier:  tensor(9001652.8982, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 3545230.035747455 -+ 533313.6142251722
# MSE states: 1753370.06800035 -+ 172976.27155825795
# MSE zones: 1367720.7358527044 -+ 50189.78308622349
# MSE regions: 1188439.5560644032 -+ 25802.190265748737
# MSE categories: 1146892.5025209654 -+ 31959.4197924162
# MSE hier: 9001652.898185877 -+ 666244.6262153103

# %% [markdown]
# ## WeaKL-T

# %% [markdown]
# Here, we run two hyperparameter tuning procedures. The second grid is based on the first one but has a finer scale. This aims at saving computational resources, while being able to test a finer grid.

# %% [markdown]
# ### First hyperparameter tuning

# %%
import itertools

grid_cartesian = np.array([[0., 0.1, 1., 10.] for i in range(5)])
grid = list(itertools.product(*grid_cartesian))
l = len(grid)

# %%
h_list = [i for i in range(0, 24)] #h correspond au lag h_learn-h
h_learn=24

start = 12*18*3//5
end = 12*18*4//5

mse_hier_min = torch.inf

counter=0
for (l_r, l_t, l_s, l_z, l_r2) in grid:
  lambdas = {
      "lambda_tot": l_t,
      "lambda_states": l_s,
      "lambda_zones": l_z,
      "lambda_regions": l_r2,
      "lambda_categories":1}
  lambda_r = l_r

  mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_transfer, se_by_level = weakl_bu_transfer(lambdas, lambda_r, h_learn, h_list, start, end, tourism_data)
  if mse_hier_min > mse_hier:
    mse_hier_min = mse_hier
    best_lambdas = lambdas
    best_lr = l_r
  counter+=1
  print(counter/l*100, "% done.")
# Out:
# MSE total:  tensor(5.9258, device='cuda:0')
# MSE states:  tensor(2.4368, device='cuda:0')
# MSE zones:  tensor(1.4443, device='cuda:0')
# MSE regions:  tensor(1.1497, device='cuda:0')
# MSE categories:  tensor(1.0900, device='cuda:0')
# MSE hier:  tensor(12.0467, device='cuda:0')
# 0.09765625 % done.
# MSE total:  tensor(5.9028, device='cuda:0')
# MSE states:  tensor(2.4312, device='cuda:0')
# MSE zones:  tensor(1.4429, device='cuda:0')
# MSE regions:  tensor(1.1490, device='cuda:0')
# MSE categories:  tensor(1.0902, device='cuda:0')
# MSE hier:  tensor(12.0160, device='cuda:0')
# 0.1953125 % done.
# MSE total:  tensor(5.3183, device='cuda:0')
# MSE states:  tensor(2.5008, device='cuda:0')
# MSE zones:  tensor(1.6165, device='cuda:0')
# MSE regions:  tensor(1.3782, device='cuda:0')
# MSE categories:  tensor(1.3669, device='cuda:0')
# MSE hier:  tensor(12.1807, device='cuda:0')
# 0.29296875 % done.
# MSE total:  tensor(7.8907, device='cuda:0')
# MSE states:  tensor(6.7270, device='cuda:0')
# MSE zones:  tensor(6.1980, device='cuda:0')
# MSE regions:  tensor(6.8339, device='cuda:0')
# MSE categories:  tensor(7.7941, device='cuda:0')
# MSE hier:  tensor(35.4438, device='cuda:0')
# 0.390625 % done.
# MSE total:  tensor(5.8597, device='cuda:0')
# MSE states:  tensor(2.4162, device='cuda:0')
# MSE zones:  tensor(1.4380, device='cuda:0')
# MSE regions:  tensor(1.1474, device='cuda:0')
# MSE categories:  tensor(1.0911, device='cuda:0')
# MSE hier:  tensor(11.9525, device='cuda:0')
# 0.48828125 % done.
# MSE total:  tensor(5.8394, device='cuda:0')
# MSE states:  tensor(2.4116, device='cuda:0')
# MSE zones:  tensor(1.4371, device='cuda:0')
# MSE regions:  tensor(1.1470, device='cuda:0')
# MSE categories:  tensor(1.0915, device='cuda:0')
# MSE hier:  tensor(11.9267, device='cuda:0')
# 0.5859375 % done.
# MSE total:  tensor(5.3065, device='cuda:0')
# MSE states:  tensor(2.5000, device='cuda:0')
# MSE zones:  tensor(1.6174, device='cuda:0')
# MSE regions:  tensor(1.3807, device='cuda:0')
# MSE categories:  tensor(1.3701, device='cuda:0')
# MSE hier:  tensor(12.1747, device='cuda:0')
# 0.68359375 % done.
# MSE total:  tensor(7.8908, device='cuda:0')
# MSE states:  tensor(6.7271, device='cuda:0')
# MSE zones:  tensor(6.1982, device='cuda:0')
# MSE regions:  tensor(6.8341, device='cuda:0')
# MSE categories:  tensor(7.7944, device='cuda:0')
# MSE hier:  tensor(35.4446, device='cuda:0')
# 0.78125 % done.
# MSE total:  tensor(4.9797, device='cuda:0')
# MSE states:  tensor(2.4529, device='cuda:0')
# MSE zones:  tensor(1.6697, device='cuda:0')
# MSE regions:  tensor(1.4642, device='cuda:0')
# MSE categories:  tensor(1.4840, device='cuda:0')
# MSE hier:  tensor(12.0505, device='cuda:0')
# 0.87890625 % done.
# MSE total:  tensor(4.9737, device='cuda:0')
# MSE states:  tensor(2.4529, device='cuda:0')
# MSE zones:  tensor(1.6685, device='cuda:0')
# MSE regions:  tensor(1.4630, device='cuda:0')
# MSE categories:  tensor(1.4830, device='cuda:0')
# MSE hier:  tensor(12.0411, device='cuda:0')
# 0.9765625 % done.
# MSE total:  tensor(4.9068, device='cuda:0')
# MSE states:  tensor(2.6212, device='cuda:0')
# MSE zones:  tensor(1.7757, device='cuda:0')
# MSE regions:  tensor(1.6207, device='cuda:0')
# MSE categories:  tensor(1.6510, device='cuda:0')
# MSE hier:  tensor(12.5753, device='cuda:0')
# 1.07421875 % done.
# MSE total:  tensor(7.8957, device='cuda:0')
# MSE states:  tensor(6.7400, device='cuda:0')
# MSE zones:  tensor(6.2161, device='cuda:0')
# MSE regions:  tensor(6.8535, device='cuda:0')
# MSE categories:  tensor(7.8240, device='cuda:0')
# MSE hier:  tensor(35.5294, device='cuda:0')
# 1.171875 % done.
# MSE total:  tensor(4.5971, device='cuda:0')
# MSE states:  tensor(3.4097, device='cuda:0')
# MSE zones:  tensor(2.7966, device='cuda:0')
# MSE regions:  tensor(2.7925, device='cuda:0')
# MSE categories:  tensor(2.9954, device='cuda:0')
# MSE hier:  tensor(16.5913, device='cuda:0')
# 1.26953125 % done.
# MSE total:  tensor(4.5931, device='cuda:0')
# MSE states:  tensor(3.4100, device='cuda:0')
# MSE zones:  tensor(2.7934, device='cuda:0')
# MSE regions:  tensor(2.7889, device='cuda:0')
# MSE categories:  tensor(2.9937, device='cuda:0')
# MSE hier:  tensor(16.5791, device='cuda:0')
# 1.3671875 % done.
# MSE total:  tensor(4.7170, device='cuda:0')
# MSE states:  tensor(3.7041, device='cuda:0')
# MSE zones:  tensor(2.8881, device='cuda:0')
# MSE regions:  tensor(2.9658, device='cuda:0')
# MSE categories:  tensor(3.2346, device='cuda:0')
# MSE hier:  tensor(17.5095, device='cuda:0')
# 1.46484375 % done.
# MSE total:  tensor(8.1837, device='cuda:0')
# MSE states:  tensor(7.4436, device='cuda:0')
# MSE zones:  tensor(7.1939, device='cuda:0')
# MSE regions:  tensor(7.8439, device='cuda:0')
# MSE categories:  tensor(9.3450, device='cuda:0')
# MSE hier:  tensor(40.0102, device='cuda:0')
# 1.5625 % done.
# MSE total:  tensor(5.6829, device='cuda:0')
# MSE states:  tensor(2.3618, device='cuda:0')
# MSE zones:  tensor(1.4335, device='cuda:0')
# MSE regions:  tensor(1.1505, device='cuda:0')
# MSE categories:  tensor(1.0974, device='cuda:0')
# MSE hier:  tensor(11.7261, device='cuda:0')
# 1.66015625 % done.
# MSE total:  tensor(5.6680, device='cuda:0')
# MSE states:  tensor(2.3590, device='cuda:0')
# MSE zones:  tensor(1.4327, device='cuda:0')
# MSE regions:  tensor(1.1500, device='cuda:0')
# MSE categories:  tensor(1.0977, device='cuda:0')
# MSE hier:  tensor(11.7074, device='cuda:0')
# 1.7578125 % done.
# MSE total:  tensor(5.2656, device='cuda:0')
# MSE states:  tensor(2.4875, device='cuda:0')
# MSE zones:  tensor(1.6164, device='cuda:0')
# MSE regions:  tensor(1.3818, device='cuda:0')
# MSE categories:  tensor(1.3722, device='cuda:0')
# MSE hier:  tensor(12.1236, device='cuda:0')
# 1.85546875 % done.
# MSE total:  tensor(7.8909, device='cuda:0')
# MSE states:  tensor(6.7273, device='cuda:0')
# MSE zones:  tensor(6.1983, device='cuda:0')
# MSE regions:  tensor(6.8344, device='cuda:0')
# MSE categories:  tensor(7.7947, device='cuda:0')
# MSE hier:  tensor(35.4455, device='cuda:0')
# 1.953125 % done.
# MSE total:  tensor(5.6449, device='cuda:0')
# MSE states:  tensor(2.3506, device='cuda:0')
# MSE zones:  tensor(1.4299, device='cuda:0')
# MSE regions:  tensor(1.1493, device='cuda:0')
# MSE categories:  tensor(1.0990, device='cuda:0')
# MSE hier:  tensor(11.6738, device='cuda:0')
# 2.05078125 % done.
# MSE total:  tensor(5.6311, device='cuda:0')
# MSE states:  tensor(2.3483, device='cuda:0')
# MSE zones:  tensor(1.4295, device='cuda:0')
# MSE regions:  tensor(1.1491, device='cuda:0')
# MSE categories:  tensor(1.0995, device='cuda:0')
# MSE hier:  tensor(11.6574, device='cuda:0')
# 2.1484375 % done.
# MSE total:  tensor(5.2558, device='cuda:0')
# MSE states:  tensor(2.4873, device='cuda:0')
# MSE zones:  tensor(1.6175, device='cuda:0')
# MSE regions:  tensor(1.3842, device='cuda:0')
# MSE categories:  tensor(1.3754, device='cuda:0')
# MSE hier:  tensor(12.1202, device='cuda:0')
# 2.24609375 % done.
# MSE total:  tensor(7.8909, device='cuda:0')
# MSE states:  tensor(6.7274, device='cuda:0')
# MSE zones:  tensor(6.1985, device='cuda:0')
# MSE regions:  tensor(6.8346, device='cuda:0')
# MSE categories:  tensor(7.7950, device='cuda:0')
# MSE hier:  tensor(35.4463, device='cuda:0')
# 2.34375 % done.
# MSE total:  tensor(4.9695, device='cuda:0')
# MSE states:  tensor(2.4523, device='cuda:0')
# MSE zones:  tensor(1.6724, device='cuda:0')
# MSE regions:  tensor(1.4676, device='cuda:0')
# MSE categories:  tensor(1.4881, device='cuda:0')
# MSE hier:  tensor(12.0500, device='cuda:0')
# 2.44140625 % done.
# MSE total:  tensor(4.9636, device='cuda:0')
# MSE states:  tensor(2.4523, device='cuda:0')
# MSE zones:  tensor(1.6712, device='cuda:0')
# MSE regions:  tensor(1.4664, device='cuda:0')
# MSE categories:  tensor(1.4870, device='cuda:0')
# MSE hier:  tensor(12.0405, device='cuda:0')
# 2.5390625 % done.
# MSE total:  tensor(4.8981, device='cuda:0')
# MSE states:  tensor(2.6204, device='cuda:0')
# MSE zones:  tensor(1.7775, device='cuda:0')
# MSE regions:  tensor(1.6232, device='cuda:0')
# MSE categories:  tensor(1.6541, device='cuda:0')
# MSE hier:  tensor(12.5733, device='cuda:0')
# 2.63671875 % done.
# MSE total:  tensor(7.8959, device='cuda:0')
# MSE states:  tensor(6.7402, device='cuda:0')
# MSE zones:  tensor(6.2164, device='cuda:0')
# MSE regions:  tensor(6.8539, device='cuda:0')
# MSE categories:  tensor(7.8245, device='cuda:0')
# MSE hier:  tensor(35.5310, device='cuda:0')
# 2.734375 % done.
# MSE total:  tensor(4.5971, device='cuda:0')
# MSE states:  tensor(3.4097, device='cuda:0')
# MSE zones:  tensor(2.7966, device='cuda:0')
# MSE regions:  tensor(2.7925, device='cuda:0')
# MSE categories:  tensor(2.9955, device='cuda:0')
# MSE hier:  tensor(16.5914, device='cuda:0')
# 2.83203125 % done.
# MSE total:  tensor(4.5931, device='cuda:0')
# MSE states:  tensor(3.4100, device='cuda:0')
# MSE zones:  tensor(2.7934, device='cuda:0')
# MSE regions:  tensor(2.7889, device='cuda:0')
# MSE categories:  tensor(2.9937, device='cuda:0')
# MSE hier:  tensor(16.5791, device='cuda:0')
# 2.9296875 % done.
# MSE total:  tensor(4.7170, device='cuda:0')
# MSE states:  tensor(3.7041, device='cuda:0')
# MSE zones:  tensor(2.8881, device='cuda:0')
# MSE regions:  tensor(2.9658, device='cuda:0')
# MSE categories:  tensor(3.2346, device='cuda:0')
# MSE hier:  tensor(17.5096, device='cuda:0')
# 3.02734375 % done.
# MSE total:  tensor(8.1837, device='cuda:0')
# MSE states:  tensor(7.4437, device='cuda:0')
# MSE zones:  tensor(7.1940, device='cuda:0')
# MSE regions:  tensor(7.8440, device='cuda:0')
# MSE categories:  tensor(9.3452, device='cuda:0')
# MSE hier:  tensor(40.0105, device='cuda:0')
# 3.125 % done.
# MSE total:  tensor(4.8945, device='cuda:0')
# MSE states:  tensor(2.2908, device='cuda:0')
# MSE zones:  tensor(1.6127, device='cuda:0')
# MSE regions:  tensor(1.3666, device='cuda:0')
# MSE categories:  tensor(1.3462, device='cuda:0')
# MSE hier:  tensor(11.5107, device='cuda:0')
# 3.22265625 % done.
# MSE total:  tensor(4.8862, device='cuda:0')
# MSE states:  tensor(2.2900, device='cuda:0')
# MSE zones:  tensor(1.6111, device='cuda:0')
# MSE regions:  tensor(1.3654, device='cuda:0')
# MSE categories:  tensor(1.3456, device='cuda:0')
# MSE hier:  tensor(11.4982, device='cuda:0')
# 3.3203125 % done.
# MSE total:  tensor(4.7419, device='cuda:0')
# MSE states:  tensor(2.4505, device='cuda:0')
# MSE zones:  tensor(1.7319, device='cuda:0')
# MSE regions:  tensor(1.5517, device='cuda:0')
# MSE categories:  tensor(1.5707, device='cuda:0')
# MSE hier:  tensor(12.0468, device='cuda:0')
# 3.41796875 % done.
# MSE total:  tensor(7.9058, device='cuda:0')
# MSE states:  tensor(6.7522, device='cuda:0')
# MSE zones:  tensor(6.2255, device='cuda:0')
# MSE regions:  tensor(6.8712, device='cuda:0')
# MSE categories:  tensor(7.8439, device='cuda:0')
# MSE hier:  tensor(35.5985, device='cuda:0')
# 3.515625 % done.
# MSE total:  tensor(4.8944, device='cuda:0')
# MSE states:  tensor(2.2913, device='cuda:0')
# MSE zones:  tensor(1.6090, device='cuda:0')
# MSE regions:  tensor(1.3640, device='cuda:0')
# MSE categories:  tensor(1.3452, device='cuda:0')
# MSE hier:  tensor(11.5039, device='cuda:0')
# 3.61328125 % done.
# MSE total:  tensor(4.8860, device='cuda:0')
# MSE states:  tensor(2.2905, device='cuda:0')
# MSE zones:  tensor(1.6076, device='cuda:0')
# MSE regions:  tensor(1.3630, device='cuda:0')
# MSE categories:  tensor(1.3449, device='cuda:0')
# MSE hier:  tensor(11.4920, device='cuda:0')
# 3.7109375 % done.
# MSE total:  tensor(4.7408, device='cuda:0')
# MSE states:  tensor(2.4526, device='cuda:0')
# MSE zones:  tensor(1.7327, device='cuda:0')
# MSE regions:  tensor(1.5532, device='cuda:0')
# MSE categories:  tensor(1.5727, device='cuda:0')
# MSE hier:  tensor(12.0519, device='cuda:0')
# 3.80859375 % done.
# MSE total:  tensor(7.9058, device='cuda:0')
# MSE states:  tensor(6.7523, device='cuda:0')
# MSE zones:  tensor(6.2257, device='cuda:0')
# MSE regions:  tensor(6.8713, device='cuda:0')
# MSE categories:  tensor(7.8442, device='cuda:0')
# MSE hier:  tensor(35.5993, device='cuda:0')
# 3.90625 % done.
# MSE total:  tensor(4.7704, device='cuda:0')
# MSE states:  tensor(2.4937, device='cuda:0')
# MSE zones:  tensor(1.7817, device='cuda:0')
# MSE regions:  tensor(1.5977, device='cuda:0')
# MSE categories:  tensor(1.6343, device='cuda:0')
# MSE hier:  tensor(12.2777, device='cuda:0')
# 4.00390625 % done.
# MSE total:  tensor(4.7637, device='cuda:0')
# MSE states:  tensor(2.4934, device='cuda:0')
# MSE zones:  tensor(1.7800, device='cuda:0')
# MSE regions:  tensor(1.5961, device='cuda:0')
# MSE categories:  tensor(1.6330, device='cuda:0')
# MSE hier:  tensor(12.2661, device='cuda:0')
# 4.1015625 % done.
# MSE total:  tensor(4.6838, device='cuda:0')
# MSE states:  tensor(2.6464, device='cuda:0')
# MSE zones:  tensor(1.8653, device='cuda:0')
# MSE regions:  tensor(1.7404, device='cuda:0')
# MSE categories:  tensor(1.7892, device='cuda:0')
# MSE hier:  tensor(12.7251, device='cuda:0')
# 4.19921875 % done.
# MSE total:  tensor(7.9090, device='cuda:0')
# MSE states:  tensor(6.7640, device='cuda:0')
# MSE zones:  tensor(6.2426, device='cuda:0')
# MSE regions:  tensor(6.8891, device='cuda:0')
# MSE categories:  tensor(7.8719, device='cuda:0')
# MSE hier:  tensor(35.6765, device='cuda:0')
# 4.296875 % done.
# MSE total:  tensor(4.5963, device='cuda:0')
# MSE states:  tensor(3.4117, device='cuda:0')
# MSE zones:  tensor(2.7983, device='cuda:0')
# MSE regions:  tensor(2.7942, device='cuda:0')
# MSE categories:  tensor(2.9987, device='cuda:0')
# MSE hier:  tensor(16.5993, device='cuda:0')
# 4.39453125 % done.
# MSE total:  tensor(4.5923, device='cuda:0')
# MSE states:  tensor(3.4120, device='cuda:0')
# MSE zones:  tensor(2.7951, device='cuda:0')
# MSE regions:  tensor(2.7905, device='cuda:0')
# MSE categories:  tensor(2.9970, device='cuda:0')
# MSE hier:  tensor(16.5870, device='cuda:0')
# 4.4921875 % done.
# MSE total:  tensor(4.7145, device='cuda:0')
# MSE states:  tensor(3.7056, device='cuda:0')
# MSE zones:  tensor(2.8898, device='cuda:0')
# MSE regions:  tensor(2.9675, device='cuda:0')
# MSE categories:  tensor(3.2381, device='cuda:0')
# MSE hier:  tensor(17.5155, device='cuda:0')
# 4.58984375 % done.
# MSE total:  tensor(8.1838, device='cuda:0')
# MSE states:  tensor(7.4490, device='cuda:0')
# MSE zones:  tensor(7.2009, device='cuda:0')
# MSE regions:  tensor(7.8515, device='cuda:0')
# MSE categories:  tensor(9.3566, device='cuda:0')
# MSE hier:  tensor(40.0418, device='cuda:0')
# 4.6875 % done.
# MSE total:  tensor(4.8384, device='cuda:0')
# MSE states:  tensor(2.3340, device='cuda:0')
# MSE zones:  tensor(1.6761, device='cuda:0')
# MSE regions:  tensor(1.4348, device='cuda:0')
# MSE categories:  tensor(1.4180, device='cuda:0')
# MSE hier:  tensor(11.7014, device='cuda:0')
# 4.78515625 % done.
# MSE total:  tensor(4.8293, device='cuda:0')
# MSE states:  tensor(2.3333, device='cuda:0')
# MSE zones:  tensor(1.6748, device='cuda:0')
# MSE regions:  tensor(1.4340, device='cuda:0')
# MSE categories:  tensor(1.4180, device='cuda:0')
# MSE hier:  tensor(11.6893, device='cuda:0')
# 4.8828125 % done.
# MSE total:  tensor(4.6387, device='cuda:0')
# MSE states:  tensor(2.5017, device='cuda:0')
# MSE zones:  tensor(1.8125, device='cuda:0')
# MSE regions:  tensor(1.6516, device='cuda:0')
# MSE categories:  tensor(1.6795, device='cuda:0')
# MSE hier:  tensor(12.2839, device='cuda:0')
# 4.98046875 % done.
# MSE total:  tensor(8.0237, device='cuda:0')
# MSE states:  tensor(7.0150, device='cuda:0')
# MSE zones:  tensor(6.5316, device='cuda:0')
# MSE regions:  tensor(7.2732, device='cuda:0')
# MSE categories:  tensor(8.3959, device='cuda:0')
# MSE hier:  tensor(37.2394, device='cuda:0')
# 5.078125 % done.
# MSE total:  tensor(4.8383, device='cuda:0')
# MSE states:  tensor(2.3347, device='cuda:0')
# MSE zones:  tensor(1.6724, device='cuda:0')
# MSE regions:  tensor(1.4324, device='cuda:0')
# MSE categories:  tensor(1.4174, device='cuda:0')
# MSE hier:  tensor(11.6951, device='cuda:0')
# 5.17578125 % done.
# MSE total:  tensor(4.8290, device='cuda:0')
# MSE states:  tensor(2.3341, device='cuda:0')
# MSE zones:  tensor(1.6712, device='cuda:0')
# MSE regions:  tensor(1.4318, device='cuda:0')
# MSE categories:  tensor(1.4175, device='cuda:0')
# MSE hier:  tensor(11.6836, device='cuda:0')
# 5.2734375 % done.
# MSE total:  tensor(4.6376, device='cuda:0')
# MSE states:  tensor(2.5038, device='cuda:0')
# MSE zones:  tensor(1.8132, device='cuda:0')
# MSE regions:  tensor(1.6532, device='cuda:0')
# MSE categories:  tensor(1.6815, device='cuda:0')
# MSE hier:  tensor(12.2893, device='cuda:0')
# 5.37109375 % done.
# MSE total:  tensor(8.0236, device='cuda:0')
# MSE states:  tensor(7.0151, device='cuda:0')
# MSE zones:  tensor(6.5317, device='cuda:0')
# MSE regions:  tensor(7.2733, device='cuda:0')
# MSE categories:  tensor(8.3962, device='cuda:0')
# MSE hier:  tensor(37.2400, device='cuda:0')
# 5.46875 % done.
# MSE total:  tensor(4.7058, device='cuda:0')
# MSE states:  tensor(2.5455, device='cuda:0')
# MSE zones:  tensor(1.8539, device='cuda:0')
# MSE regions:  tensor(1.6825, device='cuda:0')
# MSE categories:  tensor(1.7276, device='cuda:0')
# MSE hier:  tensor(12.5154, device='cuda:0')
# 5.56640625 % done.
# MSE total:  tensor(4.6985, device='cuda:0')
# MSE states:  tensor(2.5452, device='cuda:0')
# MSE zones:  tensor(1.8523, device='cuda:0')
# MSE regions:  tensor(1.6811, device='cuda:0')
# MSE categories:  tensor(1.7265, device='cuda:0')
# MSE hier:  tensor(12.5036, device='cuda:0')
# 5.6640625 % done.
# MSE total:  tensor(4.5859, device='cuda:0')
# MSE states:  tensor(2.7066, device='cuda:0')
# MSE zones:  tensor(1.9496, device='cuda:0')
# MSE regions:  tensor(1.8473, device='cuda:0')
# MSE categories:  tensor(1.9077, device='cuda:0')
# MSE hier:  tensor(12.9971, device='cuda:0')
# 5.76171875 % done.
# MSE total:  tensor(8.0202, device='cuda:0')
# MSE states:  tensor(7.0243, device='cuda:0')
# MSE zones:  tensor(6.5473, device='cuda:0')
# MSE regions:  tensor(7.2864, device='cuda:0')
# MSE categories:  tensor(8.4186, device='cuda:0')
# MSE hier:  tensor(37.2967, device='cuda:0')
# 5.859375 % done.
# MSE total:  tensor(4.5618, device='cuda:0')
# MSE states:  tensor(3.4602, device='cuda:0')
# MSE zones:  tensor(2.8398, device='cuda:0')
# MSE regions:  tensor(2.8343, device='cuda:0')
# MSE categories:  tensor(3.0724, device='cuda:0')
# MSE hier:  tensor(16.7687, device='cuda:0')
# 5.95703125 % done.
# MSE total:  tensor(4.5573, device='cuda:0')
# MSE states:  tensor(3.4604, device='cuda:0')
# MSE zones:  tensor(2.8366, device='cuda:0')
# MSE regions:  tensor(2.8307, device='cuda:0')
# MSE categories:  tensor(3.0707, device='cuda:0')
# MSE hier:  tensor(16.7557, device='cuda:0')
# 6.0546875 % done.
# MSE total:  tensor(4.6512, device='cuda:0')
# MSE states:  tensor(3.7446, device='cuda:0')
# MSE zones:  tensor(2.9313, device='cuda:0')
# MSE regions:  tensor(3.0103, device='cuda:0')
# MSE categories:  tensor(3.3167, device='cuda:0')
# MSE hier:  tensor(17.6540, device='cuda:0')
# 6.15234375 % done.
# MSE total:  tensor(8.1851, device='cuda:0')
# MSE states:  tensor(7.6080, device='cuda:0')
# MSE zones:  tensor(7.4028, device='cuda:0')
# MSE regions:  tensor(8.0705, device='cuda:0')
# MSE categories:  tensor(9.6841, device='cuda:0')
# MSE hier:  tensor(40.9504, device='cuda:0')
# 6.25 % done.
# MSE total:  tensor(5.3298, device='cuda:0')
# MSE states:  tensor(2.3412, device='cuda:0')
# MSE zones:  tensor(1.4402, device='cuda:0')
# MSE regions:  tensor(1.1637, device='cuda:0')
# MSE categories:  tensor(1.1119, device='cuda:0')
# MSE hier:  tensor(11.3868, device='cuda:0')
# 6.34765625 % done.
# MSE total:  tensor(5.3222, device='cuda:0')
# MSE states:  tensor(2.3386, device='cuda:0')
# MSE zones:  tensor(1.4393, device='cuda:0')
# MSE regions:  tensor(1.1630, device='cuda:0')
# MSE categories:  tensor(1.1119, device='cuda:0')
# MSE hier:  tensor(11.3750, device='cuda:0')
# 6.4453125 % done.
# MSE total:  tensor(5.1513, device='cuda:0')
# MSE states:  tensor(2.4802, device='cuda:0')
# MSE zones:  tensor(1.6190, device='cuda:0')
# MSE regions:  tensor(1.3867, device='cuda:0')
# MSE categories:  tensor(1.3780, device='cuda:0')
# MSE hier:  tensor(12.0153, device='cuda:0')
# 6.54296875 % done.
# MSE total:  tensor(7.8904, device='cuda:0')
# MSE states:  tensor(6.7275, device='cuda:0')
# MSE zones:  tensor(6.1989, device='cuda:0')
# MSE regions:  tensor(6.8350, device='cuda:0')
# MSE categories:  tensor(7.7952, device='cuda:0')
# MSE hier:  tensor(35.4469, device='cuda:0')
# 6.640625 % done.
# MSE total:  tensor(5.3152, device='cuda:0')
# MSE states:  tensor(2.3299, device='cuda:0')
# MSE zones:  tensor(1.4361, device='cuda:0')
# MSE regions:  tensor(1.1618, device='cuda:0')
# MSE categories:  tensor(1.1126, device='cuda:0')
# MSE hier:  tensor(11.3556, device='cuda:0')
# 6.73828125 % done.
# MSE total:  tensor(5.3078, device='cuda:0')
# MSE states:  tensor(2.3279, device='cuda:0')
# MSE zones:  tensor(1.4356, device='cuda:0')
# MSE regions:  tensor(1.1613, device='cuda:0')
# MSE categories:  tensor(1.1129, device='cuda:0')
# MSE hier:  tensor(11.3454, device='cuda:0')
# 6.8359375 % done.
# MSE total:  tensor(5.1446, device='cuda:0')
# MSE states:  tensor(2.4801, device='cuda:0')
# MSE zones:  tensor(1.6200, device='cuda:0')
# MSE regions:  tensor(1.3891, device='cuda:0')
# MSE categories:  tensor(1.3811, device='cuda:0')
# MSE hier:  tensor(12.0150, device='cuda:0')
# 6.93359375 % done.
# MSE total:  tensor(7.8905, device='cuda:0')
# MSE states:  tensor(6.7276, device='cuda:0')
# MSE zones:  tensor(6.1991, device='cuda:0')
# MSE regions:  tensor(6.8352, device='cuda:0')
# MSE categories:  tensor(7.7955, device='cuda:0')
# MSE hier:  tensor(35.4478, device='cuda:0')
# 7.03125 % done.
# MSE total:  tensor(4.9402, device='cuda:0')
# MSE states:  tensor(2.4501, device='cuda:0')
# MSE zones:  tensor(1.6747, device='cuda:0')
# MSE regions:  tensor(1.4713, device='cuda:0')
# MSE categories:  tensor(1.4921, device='cuda:0')
# MSE hier:  tensor(12.0284, device='cuda:0')
# 7.12890625 % done.
# MSE total:  tensor(4.9343, device='cuda:0')
# MSE states:  tensor(2.4501, device='cuda:0')
# MSE zones:  tensor(1.6735, device='cuda:0')
# MSE regions:  tensor(1.4701, device='cuda:0')
# MSE categories:  tensor(1.4910, device='cuda:0')
# MSE hier:  tensor(12.0190, device='cuda:0')
# 7.2265625 % done.
# MSE total:  tensor(4.8741, device='cuda:0')
# MSE states:  tensor(2.6193, device='cuda:0')
# MSE zones:  tensor(1.7795, device='cuda:0')
# MSE regions:  tensor(1.6260, device='cuda:0')
# MSE categories:  tensor(1.6571, device='cuda:0')
# MSE hier:  tensor(12.5560, device='cuda:0')
# 7.32421875 % done.
# MSE total:  tensor(7.8955, device='cuda:0')
# MSE states:  tensor(6.7404, device='cuda:0')
# MSE zones:  tensor(6.2169, device='cuda:0')
# MSE regions:  tensor(6.8545, device='cuda:0')
# MSE categories:  tensor(7.8251, device='cuda:0')
# MSE hier:  tensor(35.5324, device='cuda:0')
# 7.421875 % done.
# MSE total:  tensor(4.5971, device='cuda:0')
# MSE states:  tensor(3.4097, device='cuda:0')
# MSE zones:  tensor(2.7966, device='cuda:0')
# MSE regions:  tensor(2.7926, device='cuda:0')
# MSE categories:  tensor(2.9955, device='cuda:0')
# MSE hier:  tensor(16.5914, device='cuda:0')
# 7.51953125 % done.
# MSE total:  tensor(4.5931, device='cuda:0')
# MSE states:  tensor(3.4100, device='cuda:0')
# MSE zones:  tensor(2.7934, device='cuda:0')
# MSE regions:  tensor(2.7889, device='cuda:0')
# MSE categories:  tensor(2.9937, device='cuda:0')
# MSE hier:  tensor(16.5791, device='cuda:0')
# 7.6171875 % done.
# MSE total:  tensor(4.7169, device='cuda:0')
# MSE states:  tensor(3.7041, device='cuda:0')
# MSE zones:  tensor(2.8881, device='cuda:0')
# MSE regions:  tensor(2.9658, device='cuda:0')
# MSE categories:  tensor(3.2347, device='cuda:0')
# MSE hier:  tensor(17.5096, device='cuda:0')
# 7.71484375 % done.
# MSE total:  tensor(8.1837, device='cuda:0')
# MSE states:  tensor(7.4438, device='cuda:0')
# MSE zones:  tensor(7.1941, device='cuda:0')
# MSE regions:  tensor(7.8441, device='cuda:0')
# MSE categories:  tensor(9.3453, device='cuda:0')
# MSE hier:  tensor(40.0110, device='cuda:0')
# 7.8125 % done.
# MSE total:  tensor(5.2766, device='cuda:0')
# MSE states:  tensor(2.3049, device='cuda:0')
# MSE zones:  tensor(1.4379, device='cuda:0')
# MSE regions:  tensor(1.1664, device='cuda:0')
# MSE categories:  tensor(1.1191, device='cuda:0')
# MSE hier:  tensor(11.3050, device='cuda:0')
# 7.91015625 % done.
# MSE total:  tensor(5.2692, device='cuda:0')
# MSE states:  tensor(2.3034, device='cuda:0')
# MSE zones:  tensor(1.4372, device='cuda:0')
# MSE regions:  tensor(1.1659, device='cuda:0')
# MSE categories:  tensor(1.1192, device='cuda:0')
# MSE hier:  tensor(11.2950, device='cuda:0')
# 8.0078125 % done.
# MSE total:  tensor(5.1216, device='cuda:0')
# MSE states:  tensor(2.4710, device='cuda:0')
# MSE zones:  tensor(1.6197, device='cuda:0')
# MSE regions:  tensor(1.3902, device='cuda:0')
# MSE categories:  tensor(1.3831, device='cuda:0')
# MSE hier:  tensor(11.9856, device='cuda:0')
# 8.10546875 % done.
# MSE total:  tensor(7.8906, device='cuda:0')
# MSE states:  tensor(6.7277, device='cuda:0')
# MSE zones:  tensor(6.1992, device='cuda:0')
# MSE regions:  tensor(6.8354, device='cuda:0')
# MSE categories:  tensor(7.7958, device='cuda:0')
# MSE hier:  tensor(35.4486, device='cuda:0')
# 8.203125 % done.
# MSE total:  tensor(5.2651, device='cuda:0')
# MSE states:  tensor(2.2978, device='cuda:0')
# MSE zones:  tensor(1.4350, device='cuda:0')
# MSE regions:  tensor(1.1652, device='cuda:0')
# MSE categories:  tensor(1.1202, device='cuda:0')
# MSE hier:  tensor(11.2834, device='cuda:0')
# 8.30078125 % done.
# MSE total:  tensor(5.2579, device='cuda:0')
# MSE states:  tensor(2.2967, device='cuda:0')
# MSE zones:  tensor(1.4346, device='cuda:0')
# MSE regions:  tensor(1.1648, device='cuda:0')
# MSE categories:  tensor(1.1205, device='cuda:0')
# MSE hier:  tensor(11.2746, device='cuda:0')
# 8.3984375 % done.
# MSE total:  tensor(5.1157, device='cuda:0')
# MSE states:  tensor(2.4713, device='cuda:0')
# MSE zones:  tensor(1.6208, device='cuda:0')
# MSE regions:  tensor(1.3926, device='cuda:0')
# MSE categories:  tensor(1.3861, device='cuda:0')
# MSE hier:  tensor(11.9866, device='cuda:0')
# 8.49609375 % done.
# MSE total:  tensor(7.8906, device='cuda:0')
# MSE states:  tensor(6.7279, device='cuda:0')
# MSE zones:  tensor(6.1994, device='cuda:0')
# MSE regions:  tensor(6.8356, device='cuda:0')
# MSE categories:  tensor(7.7961, device='cuda:0')
# MSE hier:  tensor(35.4495, device='cuda:0')
# 8.59375 % done.
# MSE total:  tensor(4.9327, device='cuda:0')
# MSE states:  tensor(2.4498, device='cuda:0')
# MSE zones:  tensor(1.6774, device='cuda:0')
# MSE regions:  tensor(1.4745, device='cuda:0')
# MSE categories:  tensor(1.4959, device='cuda:0')
# MSE hier:  tensor(12.0303, device='cuda:0')
# 8.69140625 % done.
# MSE total:  tensor(4.9267, device='cuda:0')
# MSE states:  tensor(2.4499, device='cuda:0')
# MSE zones:  tensor(1.6761, device='cuda:0')
# MSE regions:  tensor(1.4733, device='cuda:0')
# MSE categories:  tensor(1.4948, device='cuda:0')
# MSE hier:  tensor(12.0208, device='cuda:0')
# 8.7890625 % done.
# MSE total:  tensor(4.8671, device='cuda:0')
# MSE states:  tensor(2.6188, device='cuda:0')
# MSE zones:  tensor(1.7812, device='cuda:0')
# MSE regions:  tensor(1.6284, device='cuda:0')
# MSE categories:  tensor(1.6600, device='cuda:0')
# MSE hier:  tensor(12.5555, device='cuda:0')
# 8.88671875 % done.
# MSE total:  tensor(7.8956, device='cuda:0')
# MSE states:  tensor(6.7407, device='cuda:0')
# MSE zones:  tensor(6.2172, device='cuda:0')
# MSE regions:  tensor(6.8549, device='cuda:0')
# MSE categories:  tensor(7.8256, device='cuda:0')
# MSE hier:  tensor(35.5340, device='cuda:0')
# 8.984375 % done.
# MSE total:  tensor(4.5971, device='cuda:0')
# MSE states:  tensor(3.4097, device='cuda:0')
# MSE zones:  tensor(2.7966, device='cuda:0')
# MSE regions:  tensor(2.7926, device='cuda:0')
# MSE categories:  tensor(2.9955, device='cuda:0')
# MSE hier:  tensor(16.5915, device='cuda:0')
# 9.08203125 % done.
# MSE total:  tensor(4.5931, device='cuda:0')
# MSE states:  tensor(3.4100, device='cuda:0')
# MSE zones:  tensor(2.7934, device='cuda:0')
# MSE regions:  tensor(2.7889, device='cuda:0')
# MSE categories:  tensor(2.9938, device='cuda:0')
# MSE hier:  tensor(16.5792, device='cuda:0')
# 9.1796875 % done.
# MSE total:  tensor(4.7169, device='cuda:0')
# MSE states:  tensor(3.7041, device='cuda:0')
# MSE zones:  tensor(2.8881, device='cuda:0')
# MSE regions:  tensor(2.9658, device='cuda:0')
# MSE categories:  tensor(3.2347, device='cuda:0')
# MSE hier:  tensor(17.5096, device='cuda:0')
# 9.27734375 % done.
# MSE total:  tensor(8.1837, device='cuda:0')
# MSE states:  tensor(7.4438, device='cuda:0')
# MSE zones:  tensor(7.1942, device='cuda:0')
# MSE regions:  tensor(7.8442, device='cuda:0')
# MSE categories:  tensor(9.3454, device='cuda:0')
# MSE hier:  tensor(40.0113, device='cuda:0')
# 9.375 % done.
# MSE total:  tensor(4.8918, device='cuda:0')
# MSE states:  tensor(2.2914, device='cuda:0')
# MSE zones:  tensor(1.6136, device='cuda:0')
# MSE regions:  tensor(1.3676, device='cuda:0')
# MSE categories:  tensor(1.3472, device='cuda:0')
# MSE hier:  tensor(11.5116, device='cuda:0')
# 9.47265625 % done.
# MSE total:  tensor(4.8834, device='cuda:0')
# MSE states:  tensor(2.2906, device='cuda:0')
# MSE zones:  tensor(1.6120, device='cuda:0')
# MSE regions:  tensor(1.3664, device='cuda:0')
# MSE categories:  tensor(1.3467, device='cuda:0')
# MSE hier:  tensor(11.4991, device='cuda:0')
# 9.5703125 % done.
# MSE total:  tensor(4.7380, device='cuda:0')
# MSE states:  tensor(2.4511, device='cuda:0')
# MSE zones:  tensor(1.7329, device='cuda:0')
# MSE regions:  tensor(1.5529, device='cuda:0')
# MSE categories:  tensor(1.5721, device='cuda:0')
# MSE hier:  tensor(12.0471, device='cuda:0')
# 9.66796875 % done.
# MSE total:  tensor(7.9055, device='cuda:0')
# MSE states:  tensor(6.7526, device='cuda:0')
# MSE zones:  tensor(6.2262, device='cuda:0')
# MSE regions:  tensor(6.8720, device='cuda:0')
# MSE categories:  tensor(7.8448, device='cuda:0')
# MSE hier:  tensor(35.6011, device='cuda:0')
# 9.765625 % done.
# MSE total:  tensor(4.8917, device='cuda:0')
# MSE states:  tensor(2.2919, device='cuda:0')
# MSE zones:  tensor(1.6099, device='cuda:0')
# MSE regions:  tensor(1.3650, device='cuda:0')
# MSE categories:  tensor(1.3463, device='cuda:0')
# MSE hier:  tensor(11.5048, device='cuda:0')
# 9.86328125 % done.
# MSE total:  tensor(4.8833, device='cuda:0')
# MSE states:  tensor(2.2911, device='cuda:0')
# MSE zones:  tensor(1.6085, device='cuda:0')
# MSE regions:  tensor(1.3640, device='cuda:0')
# MSE categories:  tensor(1.3460, device='cuda:0')
# MSE hier:  tensor(11.4929, device='cuda:0')
# 9.9609375 % done.
# MSE total:  tensor(4.7369, device='cuda:0')
# MSE states:  tensor(2.4531, device='cuda:0')
# MSE zones:  tensor(1.7337, device='cuda:0')
# MSE regions:  tensor(1.5544, device='cuda:0')
# MSE categories:  tensor(1.5741, device='cuda:0')
# MSE hier:  tensor(12.0521, device='cuda:0')
# 10.05859375 % done.
# MSE total:  tensor(7.9055, device='cuda:0')
# MSE states:  tensor(6.7527, device='cuda:0')
# MSE zones:  tensor(6.2264, device='cuda:0')
# MSE regions:  tensor(6.8722, device='cuda:0')
# MSE categories:  tensor(7.8451, device='cuda:0')
# MSE hier:  tensor(35.6019, device='cuda:0')
# 10.15625 % done.
# MSE total:  tensor(4.7676, device='cuda:0')
# MSE states:  tensor(2.4941, device='cuda:0')
# MSE zones:  tensor(1.7825, device='cuda:0')
# MSE regions:  tensor(1.5988, device='cuda:0')
# MSE categories:  tensor(1.6355, device='cuda:0')
# MSE hier:  tensor(12.2784, device='cuda:0')
# 10.25390625 % done.
# MSE total:  tensor(4.7609, device='cuda:0')
# MSE states:  tensor(2.4937, device='cuda:0')
# MSE zones:  tensor(1.7809, device='cuda:0')
# MSE regions:  tensor(1.5972, device='cuda:0')
# MSE categories:  tensor(1.6341, device='cuda:0')
# MSE hier:  tensor(12.2668, device='cuda:0')
# 10.3515625 % done.
# MSE total:  tensor(4.6803, device='cuda:0')
# MSE states:  tensor(2.6468, device='cuda:0')
# MSE zones:  tensor(1.8663, device='cuda:0')
# MSE regions:  tensor(1.7416, device='cuda:0')
# MSE categories:  tensor(1.7905, device='cuda:0')
# MSE hier:  tensor(12.7254, device='cuda:0')
# 10.44921875 % done.
# MSE total:  tensor(7.9087, device='cuda:0')
# MSE states:  tensor(6.7644, device='cuda:0')
# MSE zones:  tensor(6.2433, device='cuda:0')
# MSE regions:  tensor(6.8899, device='cuda:0')
# MSE categories:  tensor(7.8727, device='cuda:0')
# MSE hier:  tensor(35.6791, device='cuda:0')
# 10.546875 % done.
# MSE total:  tensor(4.5963, device='cuda:0')
# MSE states:  tensor(3.4117, device='cuda:0')
# MSE zones:  tensor(2.7983, device='cuda:0')
# MSE regions:  tensor(2.7942, device='cuda:0')
# MSE categories:  tensor(2.9988, device='cuda:0')
# MSE hier:  tensor(16.5993, device='cuda:0')
# 10.64453125 % done.
# MSE total:  tensor(4.5923, device='cuda:0')
# MSE states:  tensor(3.4120, device='cuda:0')
# MSE zones:  tensor(2.7951, device='cuda:0')
# MSE regions:  tensor(2.7906, device='cuda:0')
# MSE categories:  tensor(2.9970, device='cuda:0')
# MSE hier:  tensor(16.5870, device='cuda:0')
# 10.7421875 % done.
# MSE total:  tensor(4.7145, device='cuda:0')
# MSE states:  tensor(3.7056, device='cuda:0')
# MSE zones:  tensor(2.8898, device='cuda:0')
# MSE regions:  tensor(2.9675, device='cuda:0')
# MSE categories:  tensor(3.2382, device='cuda:0')
# MSE hier:  tensor(17.5156, device='cuda:0')
# 10.83984375 % done.
# MSE total:  tensor(8.1839, device='cuda:0')
# MSE states:  tensor(7.4491, device='cuda:0')
# MSE zones:  tensor(7.2011, device='cuda:0')
# MSE regions:  tensor(7.8517, device='cuda:0')
# MSE categories:  tensor(9.3568, device='cuda:0')
# MSE hier:  tensor(40.0426, device='cuda:0')
# 10.9375 % done.
# MSE total:  tensor(4.8384, device='cuda:0')
# MSE states:  tensor(2.3340, device='cuda:0')
# MSE zones:  tensor(1.6761, device='cuda:0')
# MSE regions:  tensor(1.4348, device='cuda:0')
# MSE categories:  tensor(1.4180, device='cuda:0')
# MSE hier:  tensor(11.7014, device='cuda:0')
# 11.03515625 % done.
# MSE total:  tensor(4.8293, device='cuda:0')
# MSE states:  tensor(2.3333, device='cuda:0')
# MSE zones:  tensor(1.6748, device='cuda:0')
# MSE regions:  tensor(1.4340, device='cuda:0')
# MSE categories:  tensor(1.4180, device='cuda:0')
# MSE hier:  tensor(11.6893, device='cuda:0')
# 11.1328125 % done.
# MSE total:  tensor(4.6386, device='cuda:0')
# MSE states:  tensor(2.5017, device='cuda:0')
# MSE zones:  tensor(1.8125, device='cuda:0')
# MSE regions:  tensor(1.6516, device='cuda:0')
# MSE categories:  tensor(1.6795, device='cuda:0')
# MSE hier:  tensor(12.2839, device='cuda:0')
# 11.23046875 % done.
# MSE total:  tensor(8.0237, device='cuda:0')
# MSE states:  tensor(7.0150, device='cuda:0')
# MSE zones:  tensor(6.5316, device='cuda:0')
# MSE regions:  tensor(7.2732, device='cuda:0')
# MSE categories:  tensor(8.3959, device='cuda:0')
# MSE hier:  tensor(37.2394, device='cuda:0')
# 11.328125 % done.
# MSE total:  tensor(4.8383, device='cuda:0')
# MSE states:  tensor(2.3347, device='cuda:0')
# MSE zones:  tensor(1.6724, device='cuda:0')
# MSE regions:  tensor(1.4324, device='cuda:0')
# MSE categories:  tensor(1.4174, device='cuda:0')
# MSE hier:  tensor(11.6951, device='cuda:0')
# 11.42578125 % done.
# MSE total:  tensor(4.8290, device='cuda:0')
# MSE states:  tensor(2.3341, device='cuda:0')
# MSE zones:  tensor(1.6712, device='cuda:0')
# MSE regions:  tensor(1.4318, device='cuda:0')
# MSE categories:  tensor(1.4175, device='cuda:0')
# MSE hier:  tensor(11.6836, device='cuda:0')
# 11.5234375 % done.
# MSE total:  tensor(4.6376, device='cuda:0')
# MSE states:  tensor(2.5038, device='cuda:0')
# MSE zones:  tensor(1.8132, device='cuda:0')
# MSE regions:  tensor(1.6532, device='cuda:0')
# MSE categories:  tensor(1.6815, device='cuda:0')
# MSE hier:  tensor(12.2893, device='cuda:0')
# 11.62109375 % done.
# MSE total:  tensor(8.0236, device='cuda:0')
# MSE states:  tensor(7.0151, device='cuda:0')
# MSE zones:  tensor(6.5317, device='cuda:0')
# MSE regions:  tensor(7.2734, device='cuda:0')
# MSE categories:  tensor(8.3962, device='cuda:0')
# MSE hier:  tensor(37.2400, device='cuda:0')
# 11.71875 % done.
# MSE total:  tensor(4.7058, device='cuda:0')
# MSE states:  tensor(2.5455, device='cuda:0')
# MSE zones:  tensor(1.8539, device='cuda:0')
# MSE regions:  tensor(1.6825, device='cuda:0')
# MSE categories:  tensor(1.7276, device='cuda:0')
# MSE hier:  tensor(12.5154, device='cuda:0')
# 11.81640625 % done.
# MSE total:  tensor(4.6985, device='cuda:0')
# MSE states:  tensor(2.5452, device='cuda:0')
# MSE zones:  tensor(1.8523, device='cuda:0')
# MSE regions:  tensor(1.6811, device='cuda:0')
# MSE categories:  tensor(1.7265, device='cuda:0')
# MSE hier:  tensor(12.5036, device='cuda:0')
# 11.9140625 % done.
# MSE total:  tensor(4.5859, device='cuda:0')
# MSE states:  tensor(2.7066, device='cuda:0')
# MSE zones:  tensor(1.9496, device='cuda:0')
# MSE regions:  tensor(1.8473, device='cuda:0')
# MSE categories:  tensor(1.9077, device='cuda:0')
# MSE hier:  tensor(12.9971, device='cuda:0')
# 12.01171875 % done.
# MSE total:  tensor(8.0202, device='cuda:0')
# MSE states:  tensor(7.0243, device='cuda:0')
# MSE zones:  tensor(6.5473, device='cuda:0')
# MSE regions:  tensor(7.2864, device='cuda:0')
# MSE categories:  tensor(8.4186, device='cuda:0')
# MSE hier:  tensor(37.2967, device='cuda:0')
# 12.109375 % done.
# MSE total:  tensor(4.5618, device='cuda:0')
# MSE states:  tensor(3.4602, device='cuda:0')
# MSE zones:  tensor(2.8398, device='cuda:0')
# MSE regions:  tensor(2.8343, device='cuda:0')
# MSE categories:  tensor(3.0724, device='cuda:0')
# MSE hier:  tensor(16.7687, device='cuda:0')
# 12.20703125 % done.
# MSE total:  tensor(4.5573, device='cuda:0')
# MSE states:  tensor(3.4604, device='cuda:0')
# MSE zones:  tensor(2.8366, device='cuda:0')
# MSE regions:  tensor(2.8307, device='cuda:0')
# MSE categories:  tensor(3.0707, device='cuda:0')
# MSE hier:  tensor(16.7557, device='cuda:0')
# 12.3046875 % done.
# MSE total:  tensor(4.6512, device='cuda:0')
# MSE states:  tensor(3.7446, device='cuda:0')
# MSE zones:  tensor(2.9313, device='cuda:0')
# MSE regions:  tensor(3.0103, device='cuda:0')
# MSE categories:  tensor(3.3167, device='cuda:0')
# MSE hier:  tensor(17.6540, device='cuda:0')
# 12.40234375 % done.
# MSE total:  tensor(8.1851, device='cuda:0')
# MSE states:  tensor(7.6080, device='cuda:0')
# MSE zones:  tensor(7.4028, device='cuda:0')
# MSE regions:  tensor(8.0705, device='cuda:0')
# MSE categories:  tensor(9.6841, device='cuda:0')
# MSE hier:  tensor(40.9504, device='cuda:0')
# 12.5 % done.
# MSE total:  tensor(4.9578, device='cuda:0')
# MSE states:  tensor(2.3453, device='cuda:0')
# MSE zones:  tensor(1.4997, device='cuda:0')
# MSE regions:  tensor(1.2351, device='cuda:0')
# MSE categories:  tensor(1.1922, device='cuda:0')
# MSE hier:  tensor(11.2301, device='cuda:0')
# 12.59765625 % done.
# MSE total:  tensor(4.9510, device='cuda:0')
# MSE states:  tensor(2.3429, device='cuda:0')
# MSE zones:  tensor(1.4987, device='cuda:0')
# MSE regions:  tensor(1.2344, device='cuda:0')
# MSE categories:  tensor(1.1923, device='cuda:0')
# MSE hier:  tensor(11.2193, device='cuda:0')
# 12.6953125 % done.
# MSE total:  tensor(4.8137, device='cuda:0')
# MSE states:  tensor(2.4793, device='cuda:0')
# MSE zones:  tensor(1.6677, device='cuda:0')
# MSE regions:  tensor(1.4518, device='cuda:0')
# MSE categories:  tensor(1.4534, device='cuda:0')
# MSE hier:  tensor(11.8658, device='cuda:0')
# 12.79296875 % done.
# MSE total:  tensor(7.8780, device='cuda:0')
# MSE states:  tensor(6.7609, device='cuda:0')
# MSE zones:  tensor(6.2560, device='cuda:0')
# MSE regions:  tensor(6.9016, device='cuda:0')
# MSE categories:  tensor(7.8656, device='cuda:0')
# MSE hier:  tensor(35.6621, device='cuda:0')
# 12.890625 % done.
# MSE total:  tensor(4.9484, device='cuda:0')
# MSE states:  tensor(2.3322, device='cuda:0')
# MSE zones:  tensor(1.4942, device='cuda:0')
# MSE regions:  tensor(1.2319, device='cuda:0')
# MSE categories:  tensor(1.1917, device='cuda:0')
# MSE hier:  tensor(11.1983, device='cuda:0')
# 12.98828125 % done.
# MSE total:  tensor(4.9418, device='cuda:0')
# MSE states:  tensor(2.3304, device='cuda:0')
# MSE zones:  tensor(1.4935, device='cuda:0')
# MSE regions:  tensor(1.2315, device='cuda:0')
# MSE categories:  tensor(1.1919, device='cuda:0')
# MSE hier:  tensor(11.1891, device='cuda:0')
# 13.0859375 % done.
# MSE total:  tensor(4.8092, device='cuda:0')
# MSE states:  tensor(2.4790, device='cuda:0')
# MSE zones:  tensor(1.6684, device='cuda:0')
# MSE regions:  tensor(1.4539, device='cuda:0')
# MSE categories:  tensor(1.4562, device='cuda:0')
# MSE hier:  tensor(11.8667, device='cuda:0')
# 13.18359375 % done.
# MSE total:  tensor(7.8780, device='cuda:0')
# MSE states:  tensor(6.7610, device='cuda:0')
# MSE zones:  tensor(6.2562, device='cuda:0')
# MSE regions:  tensor(6.9018, device='cuda:0')
# MSE categories:  tensor(7.8659, device='cuda:0')
# MSE hier:  tensor(35.6629, device='cuda:0')
# 13.28125 % done.
# MSE total:  tensor(4.7437, device='cuda:0')
# MSE states:  tensor(2.4513, device='cuda:0')
# MSE zones:  tensor(1.7177, device='cuda:0')
# MSE regions:  tensor(1.5279, device='cuda:0')
# MSE categories:  tensor(1.5555, device='cuda:0')
# MSE hier:  tensor(11.9960, device='cuda:0')
# 13.37890625 % done.
# MSE total:  tensor(4.7371, device='cuda:0')
# MSE states:  tensor(2.4514, device='cuda:0')
# MSE zones:  tensor(1.7165, device='cuda:0')
# MSE regions:  tensor(1.5266, device='cuda:0')
# MSE categories:  tensor(1.5544, device='cuda:0')
# MSE hier:  tensor(11.9859, device='cuda:0')
# 13.4765625 % done.
# MSE total:  tensor(4.6597, device='cuda:0')
# MSE states:  tensor(2.6236, device='cuda:0')
# MSE zones:  tensor(1.8232, device='cuda:0')
# MSE regions:  tensor(1.6830, device='cuda:0')
# MSE categories:  tensor(1.7222, device='cuda:0')
# MSE hier:  tensor(12.5116, device='cuda:0')
# 13.57421875 % done.
# MSE total:  tensor(7.8847, device='cuda:0')
# MSE states:  tensor(6.7731, device='cuda:0')
# MSE zones:  tensor(6.2727, device='cuda:0')
# MSE regions:  tensor(6.9190, device='cuda:0')
# MSE categories:  tensor(7.8933, device='cuda:0')
# MSE hier:  tensor(35.7428, device='cuda:0')
# 13.671875 % done.
# MSE total:  tensor(4.5945, device='cuda:0')
# MSE states:  tensor(3.4102, device='cuda:0')
# MSE zones:  tensor(2.7983, device='cuda:0')
# MSE regions:  tensor(2.7946, device='cuda:0')
# MSE categories:  tensor(2.9992, device='cuda:0')
# MSE hier:  tensor(16.5969, device='cuda:0')
# 13.76953125 % done.
# MSE total:  tensor(4.5904, device='cuda:0')
# MSE states:  tensor(3.4105, device='cuda:0')
# MSE zones:  tensor(2.7951, device='cuda:0')
# MSE regions:  tensor(2.7910, device='cuda:0')
# MSE categories:  tensor(2.9975, device='cuda:0')
# MSE hier:  tensor(16.5845, device='cuda:0')
# 13.8671875 % done.
# MSE total:  tensor(4.7117, device='cuda:0')
# MSE states:  tensor(3.7043, device='cuda:0')
# MSE zones:  tensor(2.8905, device='cuda:0')
# MSE regions:  tensor(2.9683, device='cuda:0')
# MSE categories:  tensor(3.2389, device='cuda:0')
# MSE hier:  tensor(17.5137, device='cuda:0')
# 13.96484375 % done.
# MSE total:  tensor(8.1911, device='cuda:0')
# MSE states:  tensor(7.4559, device='cuda:0')
# MSE zones:  tensor(7.2114, device='cuda:0')
# MSE regions:  tensor(7.8604, device='cuda:0')
# MSE categories:  tensor(9.3644, device='cuda:0')
# MSE hier:  tensor(40.0832, device='cuda:0')
# 14.0625 % done.
# MSE total:  tensor(4.9357, device='cuda:0')
# MSE states:  tensor(2.3107, device='cuda:0')
# MSE zones:  tensor(1.4948, device='cuda:0')
# MSE regions:  tensor(1.2342, device='cuda:0')
# MSE categories:  tensor(1.1954, device='cuda:0')
# MSE hier:  tensor(11.1708, device='cuda:0')
# 14.16015625 % done.
# MSE total:  tensor(4.9290, device='cuda:0')
# MSE states:  tensor(2.3095, device='cuda:0')
# MSE zones:  tensor(1.4941, device='cuda:0')
# MSE regions:  tensor(1.2336, device='cuda:0')
# MSE categories:  tensor(1.1955, device='cuda:0')
# MSE hier:  tensor(11.1617, device='cuda:0')
# 14.2578125 % done.
# MSE total:  tensor(4.8012, device='cuda:0')
# MSE states:  tensor(2.4720, device='cuda:0')
# MSE zones:  tensor(1.6675, device='cuda:0')
# MSE regions:  tensor(1.4537, device='cuda:0')
# MSE categories:  tensor(1.4566, device='cuda:0')
# MSE hier:  tensor(11.8511, device='cuda:0')
# 14.35546875 % done.
# MSE total:  tensor(7.8781, device='cuda:0')
# MSE states:  tensor(6.7611, device='cuda:0')
# MSE zones:  tensor(6.2562, device='cuda:0')
# MSE regions:  tensor(6.9019, device='cuda:0')
# MSE categories:  tensor(7.8660, device='cuda:0')
# MSE hier:  tensor(35.6634, device='cuda:0')
# 14.453125 % done.
# MSE total:  tensor(4.9288, device='cuda:0')
# MSE states:  tensor(2.3025, device='cuda:0')
# MSE zones:  tensor(1.4908, device='cuda:0')
# MSE regions:  tensor(1.2320, device='cuda:0')
# MSE categories:  tensor(1.1954, device='cuda:0')
# MSE hier:  tensor(11.1495, device='cuda:0')
# 14.55078125 % done.
# MSE total:  tensor(4.9222, device='cuda:0')
# MSE states:  tensor(2.3017, device='cuda:0')
# MSE zones:  tensor(1.4903, device='cuda:0')
# MSE regions:  tensor(1.2316, device='cuda:0')
# MSE categories:  tensor(1.1957, device='cuda:0')
# MSE hier:  tensor(11.1415, device='cuda:0')
# 14.6484375 % done.
# MSE total:  tensor(4.7972, device='cuda:0')
# MSE states:  tensor(2.4721, device='cuda:0')
# MSE zones:  tensor(1.6683, device='cuda:0')
# MSE regions:  tensor(1.4559, device='cuda:0')
# MSE categories:  tensor(1.4594, device='cuda:0')
# MSE hier:  tensor(11.8529, device='cuda:0')
# 14.74609375 % done.
# MSE total:  tensor(7.8782, device='cuda:0')
# MSE states:  tensor(6.7612, device='cuda:0')
# MSE zones:  tensor(6.2564, device='cuda:0')
# MSE regions:  tensor(6.9021, device='cuda:0')
# MSE categories:  tensor(7.8663, device='cuda:0')
# MSE hier:  tensor(35.6642, device='cuda:0')
# 14.84375 % done.
# MSE total:  tensor(4.7419, device='cuda:0')
# MSE states:  tensor(2.4519, device='cuda:0')
# MSE zones:  tensor(1.7196, device='cuda:0')
# MSE regions:  tensor(1.5302, device='cuda:0')
# MSE categories:  tensor(1.5581, device='cuda:0')
# MSE hier:  tensor(12.0017, device='cuda:0')
# 14.94140625 % done.
# MSE total:  tensor(4.7353, device='cuda:0')
# MSE states:  tensor(2.4519, device='cuda:0')
# MSE zones:  tensor(1.7184, device='cuda:0')
# MSE regions:  tensor(1.5289, device='cuda:0')
# MSE categories:  tensor(1.5570, device='cuda:0')
# MSE hier:  tensor(11.9916, device='cuda:0')
# 15.0390625 % done.
# MSE total:  tensor(4.6574, device='cuda:0')
# MSE states:  tensor(2.6237, device='cuda:0')
# MSE zones:  tensor(1.8243, device='cuda:0')
# MSE regions:  tensor(1.6847, device='cuda:0')
# MSE categories:  tensor(1.7242, device='cuda:0')
# MSE hier:  tensor(12.5143, device='cuda:0')
# 15.13671875 % done.
# MSE total:  tensor(7.8848, device='cuda:0')
# MSE states:  tensor(6.7733, device='cuda:0')
# MSE zones:  tensor(6.2729, device='cuda:0')
# MSE regions:  tensor(6.9192, device='cuda:0')
# MSE categories:  tensor(7.8937, device='cuda:0')
# MSE hier:  tensor(35.7440, device='cuda:0')
# 15.234375 % done.
# MSE total:  tensor(4.5945, device='cuda:0')
# MSE states:  tensor(3.4103, device='cuda:0')
# MSE zones:  tensor(2.7983, device='cuda:0')
# MSE regions:  tensor(2.7946, device='cuda:0')
# MSE categories:  tensor(2.9993, device='cuda:0')
# MSE hier:  tensor(16.5970, device='cuda:0')
# 15.33203125 % done.
# MSE total:  tensor(4.5904, device='cuda:0')
# MSE states:  tensor(3.4106, device='cuda:0')
# MSE zones:  tensor(2.7951, device='cuda:0')
# MSE regions:  tensor(2.7910, device='cuda:0')
# MSE categories:  tensor(2.9975, device='cuda:0')
# MSE hier:  tensor(16.5846, device='cuda:0')
# 15.4296875 % done.
# MSE total:  tensor(4.7117, device='cuda:0')
# MSE states:  tensor(3.7044, device='cuda:0')
# MSE zones:  tensor(2.8905, device='cuda:0')
# MSE regions:  tensor(2.9683, device='cuda:0')
# MSE categories:  tensor(3.2389, device='cuda:0')
# MSE hier:  tensor(17.5138, device='cuda:0')
# 15.52734375 % done.
# MSE total:  tensor(8.1911, device='cuda:0')
# MSE states:  tensor(7.4559, device='cuda:0')
# MSE zones:  tensor(7.2114, device='cuda:0')
# MSE regions:  tensor(7.8605, device='cuda:0')
# MSE categories:  tensor(9.3645, device='cuda:0')
# MSE hier:  tensor(40.0835, device='cuda:0')
# 15.625 % done.
# MSE total:  tensor(4.8478, device='cuda:0')
# MSE states:  tensor(2.3003, device='cuda:0')
# MSE zones:  tensor(1.6276, device='cuda:0')
# MSE regions:  tensor(1.3835, device='cuda:0')
# MSE categories:  tensor(1.3638, device='cuda:0')
# MSE hier:  tensor(11.5229, device='cuda:0')
# 15.72265625 % done.
# MSE total:  tensor(4.8391, device='cuda:0')
# MSE states:  tensor(2.2995, device='cuda:0')
# MSE zones:  tensor(1.6260, device='cuda:0')
# MSE regions:  tensor(1.3823, device='cuda:0')
# MSE categories:  tensor(1.3634, device='cuda:0')
# MSE hier:  tensor(11.5103, device='cuda:0')
# 15.8203125 % done.
# MSE total:  tensor(4.6705, device='cuda:0')
# MSE states:  tensor(2.4607, device='cuda:0')
# MSE zones:  tensor(1.7505, device='cuda:0')
# MSE regions:  tensor(1.5749, device='cuda:0')
# MSE categories:  tensor(1.5963, device='cuda:0')
# MSE hier:  tensor(12.0529, device='cuda:0')
# 15.91796875 % done.
# MSE total:  tensor(7.8932, device='cuda:0')
# MSE states:  tensor(6.7809, device='cuda:0')
# MSE zones:  tensor(6.2753, device='cuda:0')
# MSE regions:  tensor(6.9286, device='cuda:0')
# MSE categories:  tensor(7.9049, device='cuda:0')
# MSE hier:  tensor(35.7830, device='cuda:0')
# 16.015625 % done.
# MSE total:  tensor(4.8475, device='cuda:0')
# MSE states:  tensor(2.3007, device='cuda:0')
# MSE zones:  tensor(1.6238, device='cuda:0')
# MSE regions:  tensor(1.3809, device='cuda:0')
# MSE categories:  tensor(1.3629, device='cuda:0')
# MSE hier:  tensor(11.5157, device='cuda:0')
# 16.11328125 % done.
# MSE total:  tensor(4.8387, device='cuda:0')
# ...
# MSE states:  tensor(2.4375, device='cuda:0')
# MSE zones:  tensor(1.5580, device='cuda:0')
# MSE regions:  tensor(1.3608, device='cuda:0')
# MSE categories:  tensor(1.3112, device='cuda:0')
# MSE hier:  tensor(11.4193, device='cuda:0')
# 94.7265625 % done.
# MSE total:  tensor(4.6998, device='cuda:0')
# MSE states:  tensor(2.3945, device='cuda:0')
# MSE zones:  tensor(1.5150, device='cuda:0')
# MSE regions:  tensor(1.2817, device='cuda:0')
# MSE categories:  tensor(1.2735, device='cuda:0')
# MSE hier:  tensor(11.1645, device='cuda:0')
# 94.82421875 % done.
# MSE total:  tensor(4.2248, device='cuda:0')
# MSE states:  tensor(2.0583, device='cuda:0')
# MSE zones:  tensor(1.3079, device='cuda:0')
# MSE regions:  tensor(1.0923, device='cuda:0')
# MSE categories:  tensor(1.4610, device='cuda:0')
# MSE hier:  tensor(10.1443, device='cuda:0')
# 94.921875 % done.
# MSE total:  tensor(4.4902, device='cuda:0')
# MSE states:  tensor(2.2205, device='cuda:0')
# MSE zones:  tensor(1.4421, device='cuda:0')
# MSE regions:  tensor(1.5828, device='cuda:0')
# MSE categories:  tensor(1.8223, device='cuda:0')
# MSE hier:  tensor(11.5580, device='cuda:0')
# 95.01953125 % done.
# MSE total:  tensor(4.4899, device='cuda:0')
# MSE states:  tensor(2.2206, device='cuda:0')
# MSE zones:  tensor(1.4421, device='cuda:0')
# MSE regions:  tensor(1.5754, device='cuda:0')
# MSE categories:  tensor(1.8208, device='cuda:0')
# MSE hier:  tensor(11.5488, device='cuda:0')
# 95.1171875 % done.
# MSE total:  tensor(4.4684, device='cuda:0')
# MSE states:  tensor(2.2187, device='cuda:0')
# MSE zones:  tensor(1.4410, device='cuda:0')
# MSE regions:  tensor(1.3564, device='cuda:0')
# MSE categories:  tensor(1.7804, device='cuda:0')
# MSE hier:  tensor(11.2650, device='cuda:0')
# 95.21484375 % done.
# MSE total:  tensor(4.2258, device='cuda:0')
# MSE states:  tensor(2.1830, device='cuda:0')
# MSE zones:  tensor(1.4188, device='cuda:0')
# MSE regions:  tensor(1.1836, device='cuda:0')
# MSE categories:  tensor(1.9070, device='cuda:0')
# MSE hier:  tensor(10.9181, device='cuda:0')
# 95.3125 % done.
# MSE total:  tensor(4.8014, device='cuda:0')
# MSE states:  tensor(2.5543, device='cuda:0')
# MSE zones:  tensor(1.6887, device='cuda:0')
# MSE regions:  tensor(1.4677, device='cuda:0')
# MSE categories:  tensor(1.3697, device='cuda:0')
# MSE hier:  tensor(11.8818, device='cuda:0')
# 95.41015625 % done.
# MSE total:  tensor(4.8007, device='cuda:0')
# MSE states:  tensor(2.5519, device='cuda:0')
# MSE zones:  tensor(1.6854, device='cuda:0')
# MSE regions:  tensor(1.4635, device='cuda:0')
# MSE categories:  tensor(1.3682, device='cuda:0')
# MSE hier:  tensor(11.8697, device='cuda:0')
# 95.5078125 % done.
# MSE total:  tensor(4.7395, device='cuda:0')
# MSE states:  tensor(2.4569, device='cuda:0')
# MSE zones:  tensor(1.5741, device='cuda:0')
# MSE regions:  tensor(1.3261, device='cuda:0')
# MSE categories:  tensor(1.3044, device='cuda:0')
# MSE hier:  tensor(11.4009, device='cuda:0')
# 95.60546875 % done.
# MSE total:  tensor(4.2249, device='cuda:0')
# MSE states:  tensor(2.0572, device='cuda:0')
# MSE zones:  tensor(1.3068, device='cuda:0')
# MSE regions:  tensor(1.0915, device='cuda:0')
# MSE categories:  tensor(1.4558, device='cuda:0')
# MSE hier:  tensor(10.1362, device='cuda:0')
# 95.703125 % done.
# MSE total:  tensor(4.8007, device='cuda:0')
# MSE states:  tensor(2.5504, device='cuda:0')
# MSE zones:  tensor(1.6844, device='cuda:0')
# MSE regions:  tensor(1.4644, device='cuda:0')
# MSE categories:  tensor(1.3685, device='cuda:0')
# MSE hier:  tensor(11.8684, device='cuda:0')
# 95.80078125 % done.
# MSE total:  tensor(4.8001, device='cuda:0')
# MSE states:  tensor(2.5481, device='cuda:0')
# MSE zones:  tensor(1.6813, device='cuda:0')
# MSE regions:  tensor(1.4604, device='cuda:0')
# MSE categories:  tensor(1.3671, device='cuda:0')
# MSE hier:  tensor(11.8569, device='cuda:0')
# 95.8984375 % done.
# MSE total:  tensor(4.7390, device='cuda:0')
# MSE states:  tensor(2.4560, device='cuda:0')
# MSE zones:  tensor(1.5732, device='cuda:0')
# MSE regions:  tensor(1.3255, device='cuda:0')
# MSE categories:  tensor(1.3039, device='cuda:0')
# MSE hier:  tensor(11.3977, device='cuda:0')
# 95.99609375 % done.
# MSE total:  tensor(4.2249, device='cuda:0')
# MSE states:  tensor(2.0572, device='cuda:0')
# MSE zones:  tensor(1.3068, device='cuda:0')
# MSE regions:  tensor(1.0915, device='cuda:0')
# MSE categories:  tensor(1.4559, device='cuda:0')
# MSE hier:  tensor(10.1363, device='cuda:0')
# 96.09375 % done.
# MSE total:  tensor(4.7525, device='cuda:0')
# MSE states:  tensor(2.4370, device='cuda:0')
# MSE zones:  tensor(1.5581, device='cuda:0')
# MSE regions:  tensor(1.3621, device='cuda:0')
# MSE categories:  tensor(1.3116, device='cuda:0')
# MSE hier:  tensor(11.4213, device='cuda:0')
# 96.19140625 % done.
# MSE total:  tensor(4.7519, device='cuda:0')
# MSE states:  tensor(2.4365, device='cuda:0')
# MSE zones:  tensor(1.5575, device='cuda:0')
# MSE regions:  tensor(1.3604, device='cuda:0')
# MSE categories:  tensor(1.3109, device='cuda:0')
# MSE hier:  tensor(11.4173, device='cuda:0')
# 96.2890625 % done.
# MSE total:  tensor(4.6999, device='cuda:0')
# MSE states:  tensor(2.3938, device='cuda:0')
# MSE zones:  tensor(1.5146, device='cuda:0')
# MSE regions:  tensor(1.2814, device='cuda:0')
# MSE categories:  tensor(1.2733, device='cuda:0')
# MSE hier:  tensor(11.1630, device='cuda:0')
# 96.38671875 % done.
# MSE total:  tensor(4.2248, device='cuda:0')
# MSE states:  tensor(2.0582, device='cuda:0')
# MSE zones:  tensor(1.3079, device='cuda:0')
# MSE regions:  tensor(1.0923, device='cuda:0')
# MSE categories:  tensor(1.4610, device='cuda:0')
# MSE hier:  tensor(10.1444, device='cuda:0')
# 96.484375 % done.
# MSE total:  tensor(4.4902, device='cuda:0')
# MSE states:  tensor(2.2206, device='cuda:0')
# MSE zones:  tensor(1.4421, device='cuda:0')
# MSE regions:  tensor(1.5829, device='cuda:0')
# MSE categories:  tensor(1.8224, device='cuda:0')
# MSE hier:  tensor(11.5581, device='cuda:0')
# 96.58203125 % done.
# MSE total:  tensor(4.4899, device='cuda:0')
# MSE states:  tensor(2.2206, device='cuda:0')
# MSE zones:  tensor(1.4421, device='cuda:0')
# MSE regions:  tensor(1.5755, device='cuda:0')
# MSE categories:  tensor(1.8209, device='cuda:0')
# MSE hier:  tensor(11.5489, device='cuda:0')
# 96.6796875 % done.
# MSE total:  tensor(4.4684, device='cuda:0')
# MSE states:  tensor(2.2187, device='cuda:0')
# MSE zones:  tensor(1.4411, device='cuda:0')
# MSE regions:  tensor(1.3564, device='cuda:0')
# MSE categories:  tensor(1.7804, device='cuda:0')
# MSE hier:  tensor(11.2650, device='cuda:0')
# 96.77734375 % done.
# MSE total:  tensor(4.2258, device='cuda:0')
# MSE states:  tensor(2.1830, device='cuda:0')
# MSE zones:  tensor(1.4188, device='cuda:0')
# MSE regions:  tensor(1.1836, device='cuda:0')
# MSE categories:  tensor(1.9070, device='cuda:0')
# MSE hier:  tensor(10.9182, device='cuda:0')
# 96.875 % done.
# MSE total:  tensor(4.7982, device='cuda:0')
# MSE states:  tensor(2.4170, device='cuda:0')
# MSE zones:  tensor(1.6232, device='cuda:0')
# MSE regions:  tensor(1.4210, device='cuda:0')
# MSE categories:  tensor(1.3410, device='cuda:0')
# MSE hier:  tensor(11.6004, device='cuda:0')
# 96.97265625 % done.
# MSE total:  tensor(4.7975, device='cuda:0')
# MSE states:  tensor(2.4165, device='cuda:0')
# MSE zones:  tensor(1.6207, device='cuda:0')
# MSE regions:  tensor(1.4176, device='cuda:0')
# MSE categories:  tensor(1.3398, device='cuda:0')
# MSE hier:  tensor(11.5921, device='cuda:0')
# 97.0703125 % done.
# MSE total:  tensor(4.7349, device='cuda:0')
# MSE states:  tensor(2.3751, device='cuda:0')
# MSE zones:  tensor(1.5301, device='cuda:0')
# MSE regions:  tensor(1.2996, device='cuda:0')
# MSE categories:  tensor(1.2864, device='cuda:0')
# MSE hier:  tensor(11.2262, device='cuda:0')
# 97.16796875 % done.
# MSE total:  tensor(4.2263, device='cuda:0')
# MSE states:  tensor(2.0556, device='cuda:0')
# MSE zones:  tensor(1.3079, device='cuda:0')
# MSE regions:  tensor(1.0929, device='cuda:0')
# MSE categories:  tensor(1.4606, device='cuda:0')
# MSE hier:  tensor(10.1433, device='cuda:0')
# 97.265625 % done.
# MSE total:  tensor(4.7975, device='cuda:0')
# MSE states:  tensor(2.4164, device='cuda:0')
# MSE zones:  tensor(1.6203, device='cuda:0')
# MSE regions:  tensor(1.4188, device='cuda:0')
# MSE categories:  tensor(1.3401, device='cuda:0')
# MSE hier:  tensor(11.5931, device='cuda:0')
# 97.36328125 % done.
# MSE total:  tensor(4.7967, device='cuda:0')
# MSE states:  tensor(2.4159, device='cuda:0')
# MSE zones:  tensor(1.6179, device='cuda:0')
# MSE regions:  tensor(1.4155, device='cuda:0')
# MSE categories:  tensor(1.3390, device='cuda:0')
# MSE hier:  tensor(11.5851, device='cuda:0')
# 97.4609375 % done.
# MSE total:  tensor(4.7344, device='cuda:0')
# MSE states:  tensor(2.3747, device='cuda:0')
# MSE zones:  tensor(1.5295, device='cuda:0')
# MSE regions:  tensor(1.2992, device='cuda:0')
# MSE categories:  tensor(1.2861, device='cuda:0')
# MSE hier:  tensor(11.2239, device='cuda:0')
# 97.55859375 % done.
# MSE total:  tensor(4.2263, device='cuda:0')
# MSE states:  tensor(2.0556, device='cuda:0')
# MSE zones:  tensor(1.3079, device='cuda:0')
# MSE regions:  tensor(1.0929, device='cuda:0')
# MSE categories:  tensor(1.4606, device='cuda:0')
# MSE hier:  tensor(10.1433, device='cuda:0')
# 97.65625 % done.
# MSE total:  tensor(4.7488, device='cuda:0')
# MSE states:  tensor(2.3717, device='cuda:0')
# MSE zones:  tensor(1.5227, device='cuda:0')
# MSE regions:  tensor(1.3408, device='cuda:0')
# MSE categories:  tensor(1.2971, device='cuda:0')
# MSE hier:  tensor(11.2811, device='cuda:0')
# 97.75390625 % done.
# MSE total:  tensor(4.7483, device='cuda:0')
# MSE states:  tensor(2.3714, device='cuda:0')
# MSE zones:  tensor(1.5222, device='cuda:0')
# MSE regions:  tensor(1.3391, device='cuda:0')
# MSE categories:  tensor(1.2965, device='cuda:0')
# MSE hier:  tensor(11.2775, device='cuda:0')
# 97.8515625 % done.
# MSE total:  tensor(4.6988, device='cuda:0')
# MSE states:  tensor(2.3398, device='cuda:0')
# MSE zones:  tensor(1.4856, device='cuda:0')
# MSE regions:  tensor(1.2643, device='cuda:0')
# MSE categories:  tensor(1.2635, device='cuda:0')
# MSE hier:  tensor(11.0519, device='cuda:0')
# 97.94921875 % done.
# MSE total:  tensor(4.2262, device='cuda:0')
# MSE states:  tensor(2.0568, device='cuda:0')
# MSE zones:  tensor(1.3091, device='cuda:0')
# MSE regions:  tensor(1.0937, device='cuda:0')
# MSE categories:  tensor(1.4657, device='cuda:0')
# MSE hier:  tensor(10.1515, device='cuda:0')
# 98.046875 % done.
# MSE total:  tensor(4.4900, device='cuda:0')
# MSE states:  tensor(2.2212, device='cuda:0')
# MSE zones:  tensor(1.4432, device='cuda:0')
# MSE regions:  tensor(1.5857, device='cuda:0')
# MSE categories:  tensor(1.8264, device='cuda:0')
# MSE hier:  tensor(11.5665, device='cuda:0')
# 98.14453125 % done.
# MSE total:  tensor(4.4897, device='cuda:0')
# MSE states:  tensor(2.2212, device='cuda:0')
# MSE zones:  tensor(1.4432, device='cuda:0')
# MSE regions:  tensor(1.5783, device='cuda:0')
# MSE categories:  tensor(1.8249, device='cuda:0')
# MSE hier:  tensor(11.5573, device='cuda:0')
# 98.2421875 % done.
# MSE total:  tensor(4.4681, device='cuda:0')
# MSE states:  tensor(2.2194, device='cuda:0')
# MSE zones:  tensor(1.4422, device='cuda:0')
# MSE regions:  tensor(1.3585, device='cuda:0')
# MSE categories:  tensor(1.7843, device='cuda:0')
# MSE hier:  tensor(11.2724, device='cuda:0')
# 98.33984375 % done.
# MSE total:  tensor(4.2253, device='cuda:0')
# MSE states:  tensor(2.1835, device='cuda:0')
# MSE zones:  tensor(1.4198, device='cuda:0')
# MSE regions:  tensor(1.1846, device='cuda:0')
# MSE categories:  tensor(1.9099, device='cuda:0')
# MSE hier:  tensor(10.9230, device='cuda:0')
# 98.4375 % done.
# MSE total:  tensor(4.7991, device='cuda:0')
# MSE states:  tensor(2.3373, device='cuda:0')
# MSE zones:  tensor(1.8615, device='cuda:0')
# MSE regions:  tensor(1.7060, device='cuda:0')
# MSE categories:  tensor(1.7460, device='cuda:0')
# MSE hier:  tensor(12.4500, device='cuda:0')
# 98.53515625 % done.
# MSE total:  tensor(4.7989, device='cuda:0')
# MSE states:  tensor(2.3372, device='cuda:0')
# MSE zones:  tensor(1.8571, device='cuda:0')
# MSE regions:  tensor(1.7000, device='cuda:0')
# MSE categories:  tensor(1.7440, device='cuda:0')
# MSE hier:  tensor(12.4372, device='cuda:0')
# 98.6328125 % done.
# MSE total:  tensor(4.7745, device='cuda:0')
# MSE states:  tensor(2.3278, device='cuda:0')
# MSE zones:  tensor(1.6888, device='cuda:0')
# MSE regions:  tensor(1.4893, device='cuda:0')
# MSE categories:  tensor(1.6521, device='cuda:0')
# MSE hier:  tensor(11.9325, device='cuda:0')
# 98.73046875 % done.
# MSE total:  tensor(4.2047, device='cuda:0')
# MSE states:  tensor(2.1211, device='cuda:0')
# MSE zones:  tensor(1.3963, device='cuda:0')
# MSE regions:  tensor(1.1807, device='cuda:0')
# MSE categories:  tensor(1.7058, device='cuda:0')
# MSE hier:  tensor(10.6087, device='cuda:0')
# 98.828125 % done.
# MSE total:  tensor(4.7984, device='cuda:0')
# MSE states:  tensor(2.3371, device='cuda:0')
# MSE zones:  tensor(1.8555, device='cuda:0')
# MSE regions:  tensor(1.7019, device='cuda:0')
# MSE categories:  tensor(1.7444, device='cuda:0')
# MSE hier:  tensor(12.4373, device='cuda:0')
# 98.92578125 % done.
# MSE total:  tensor(4.7982, device='cuda:0')
# MSE states:  tensor(2.3370, device='cuda:0')
# MSE zones:  tensor(1.8513, device='cuda:0')
# MSE regions:  tensor(1.6961, device='cuda:0')
# MSE categories:  tensor(1.7424, device='cuda:0')
# MSE hier:  tensor(12.4249, device='cuda:0')
# 99.0234375 % done.
# MSE total:  tensor(4.7742, device='cuda:0')
# MSE states:  tensor(2.3277, device='cuda:0')
# MSE zones:  tensor(1.6875, device='cuda:0')
# MSE regions:  tensor(1.4885, device='cuda:0')
# MSE categories:  tensor(1.6516, device='cuda:0')
# MSE hier:  tensor(11.9294, device='cuda:0')
# 99.12109375 % done.
# MSE total:  tensor(4.2047, device='cuda:0')
# MSE states:  tensor(2.1212, device='cuda:0')
# MSE zones:  tensor(1.3963, device='cuda:0')
# MSE regions:  tensor(1.1807, device='cuda:0')
# MSE categories:  tensor(1.7059, device='cuda:0')
# MSE hier:  tensor(10.6088, device='cuda:0')
# 99.21875 % done.
# MSE total:  tensor(4.7704, device='cuda:0')
# MSE states:  tensor(2.3292, device='cuda:0')
# MSE zones:  tensor(1.6617, device='cuda:0')
# MSE regions:  tensor(1.5610, device='cuda:0')
# MSE categories:  tensor(1.6660, device='cuda:0')
# MSE hier:  tensor(11.9883, device='cuda:0')
# 99.31640625 % done.
# MSE total:  tensor(4.7703, device='cuda:0')
# MSE states:  tensor(2.3292, device='cuda:0')
# MSE zones:  tensor(1.6609, device='cuda:0')
# MSE regions:  tensor(1.5581, device='cuda:0')
# MSE categories:  tensor(1.6650, device='cuda:0')
# MSE hier:  tensor(11.9834, device='cuda:0')
# 99.4140625 % done.
# MSE total:  tensor(4.7525, device='cuda:0')
# MSE states:  tensor(2.3216, device='cuda:0')
# MSE zones:  tensor(1.6104, device='cuda:0')
# MSE regions:  tensor(1.4345, device='cuda:0')
# MSE categories:  tensor(1.6138, device='cuda:0')
# MSE hier:  tensor(11.7329, device='cuda:0')
# 99.51171875 % done.
# MSE total:  tensor(4.2037, device='cuda:0')
# MSE states:  tensor(2.1224, device='cuda:0')
# MSE zones:  tensor(1.3971, device='cuda:0')
# MSE regions:  tensor(1.1812, device='cuda:0')
# MSE categories:  tensor(1.7098, device='cuda:0')
# MSE hier:  tensor(10.6141, device='cuda:0')
# 99.609375 % done.
# MSE total:  tensor(4.4450, device='cuda:0')
# MSE states:  tensor(2.2761, device='cuda:0')
# MSE zones:  tensor(1.5075, device='cuda:0')
# MSE regions:  tensor(1.7312, device='cuda:0')
# MSE categories:  tensor(2.0378, device='cuda:0')
# MSE hier:  tensor(11.9977, device='cuda:0')
# 99.70703125 % done.
# MSE total:  tensor(4.4446, device='cuda:0')
# MSE states:  tensor(2.2761, device='cuda:0')
# MSE zones:  tensor(1.5075, device='cuda:0')
# MSE regions:  tensor(1.7229, device='cuda:0')
# MSE categories:  tensor(2.0361, device='cuda:0')
# MSE hier:  tensor(11.9872, device='cuda:0')
# 99.8046875 % done.
# MSE total:  tensor(4.4199, device='cuda:0')
# MSE states:  tensor(2.2733, device='cuda:0')
# MSE zones:  tensor(1.5059, device='cuda:0')
# MSE regions:  tensor(1.4721, device='cuda:0')
# MSE categories:  tensor(1.9876, device='cuda:0')
# MSE hier:  tensor(11.6587, device='cuda:0')
# 99.90234375 % done.
# MSE total:  tensor(4.1788, device='cuda:0')
# MSE states:  tensor(2.2371, device='cuda:0')
# MSE zones:  tensor(1.4798, device='cuda:0')
# MSE regions:  tensor(1.2471, device='cuda:0')
# MSE categories:  tensor(2.0795, device='cuda:0')
# MSE hier:  tensor(11.2223, device='cuda:0')
# 100.0 % done.

# %%
print(best_lambdas)
print(best_lr)
# Out:
# {'lambda_tot': 1.0, 'lambda_states': 0.1, 'lambda_zones': 0.1, 'lambda_regions': 0.1, 'lambda_categories': 1}
# 1.0

# %%
# best_lr =1.0
# best_lambdas = {'lambda_tot': 1.0, 'lambda_states': 0.1, 'lambda_zones': 0.1, 'lambda_regions': 0.1, 'lambda_categories': 1}

lambda_r = best_lr
lambdas = best_lambdas
start = 12*18*4//5
end = 12*18

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_transfer, se_by_level = weakl_bu_transfer(lambdas, lambda_r, h_learn, h_list, start, end, tourism_data)
# Out:
# MSE total:  tensor(2.6906, device='cuda:0')
# MSE states:  tensor(1.7233, device='cuda:0')
# MSE zones:  tensor(1.3975, device='cuda:0')
# MSE regions:  tensor(1.2725, device='cuda:0')
# MSE categories:  tensor(1.2481, device='cuda:0')
# MSE hier:  tensor(8.3319, device='cuda:0')

# %% [markdown]
# ### Second tuning

# %%
import itertools

grid_cartesian = np.array([[0.3, 1., 3.],
                           [0.3, 1., 3.],
                           [0.03, 0.1, 0.3],
                           [0.03, 0.1, 0.3],
                           [0.03, 0.1, 0.3]])
grid = list(itertools.product(*grid_cartesian))
l = len(grid)

h_list = [i for i in range(0, 24)] #h correspond au lag h_learn-h
h_learn=24

start = 12*18*3//5
end = 12*18*4//5

mse_hier_min = torch.inf

counter=0
for (l_r, l_t, l_s, l_z, l_r2) in grid:
  lambdas = {
      "lambda_tot": l_t,
      "lambda_states": l_s,
      "lambda_zones": l_z,
      "lambda_regions": l_r2,
      "lambda_categories":1}
  lambda_r = l_r

  mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_transfer, se_by_level = weakl_bu_transfer(lambdas, lambda_r, h_learn, h_list, start, end, tourism_data)
  if mse_hier_min > mse_hier:
    mse_hier_min = mse_hier
    best_lambdas = lambdas
    best_lr = l_r
  counter+=1
  print(counter/l*100, "% done.")
# Out:
# MSE total:  tensor(4.6163, device='cuda:0')
# MSE states:  tensor(2.1095, device='cuda:0')
# MSE zones:  tensor(1.2951, device='cuda:0')
# MSE regions:  tensor(1.0545, device='cuda:0')
# MSE categories:  tensor(1.0142, device='cuda:0')
# MSE hier:  tensor(10.0895, device='cuda:0')
# 0.411522633744856 % done.
# MSE total:  tensor(4.6174, device='cuda:0')
# MSE states:  tensor(2.1091, device='cuda:0')
# MSE zones:  tensor(1.2951, device='cuda:0')
# MSE regions:  tensor(1.0544, device='cuda:0')
# MSE categories:  tensor(1.0148, device='cuda:0')
# MSE hier:  tensor(10.0909, device='cuda:0')
# 0.823045267489712 % done.
# MSE total:  tensor(4.6268, device='cuda:0')
# MSE states:  tensor(2.1084, device='cuda:0')
# MSE zones:  tensor(1.2976, device='cuda:0')
# MSE regions:  tensor(1.0556, device='cuda:0')
# MSE categories:  tensor(1.0220, device='cuda:0')
# MSE hier:  tensor(10.1104, device='cuda:0')
# 1.2345679012345678 % done.
# MSE total:  tensor(4.6139, device='cuda:0')
# MSE states:  tensor(2.1058, device='cuda:0')
# MSE zones:  tensor(1.2946, device='cuda:0')
# MSE regions:  tensor(1.0543, device='cuda:0')
# MSE categories:  tensor(1.0157, device='cuda:0')
# MSE hier:  tensor(10.0843, device='cuda:0')
# 1.646090534979424 % done.
# MSE total:  tensor(4.6150, device='cuda:0')
# MSE states:  tensor(2.1056, device='cuda:0')
# MSE zones:  tensor(1.2947, device='cuda:0')
# MSE regions:  tensor(1.0543, device='cuda:0')
# MSE categories:  tensor(1.0163, device='cuda:0')
# MSE hier:  tensor(10.0859, device='cuda:0')
# 2.05761316872428 % done.
# MSE total:  tensor(4.6241, device='cuda:0')
# MSE states:  tensor(2.1060, device='cuda:0')
# MSE zones:  tensor(1.2977, device='cuda:0')
# MSE regions:  tensor(1.0560, device='cuda:0')
# MSE categories:  tensor(1.0238, device='cuda:0')
# MSE hier:  tensor(10.1076, device='cuda:0')
# 2.4691358024691357 % done.
# MSE total:  tensor(4.5941, device='cuda:0')
# MSE states:  tensor(2.0894, device='cuda:0')
# MSE zones:  tensor(1.2977, device='cuda:0')
# MSE regions:  tensor(1.0593, device='cuda:0')
# MSE categories:  tensor(1.0324, device='cuda:0')
# MSE hier:  tensor(10.0728, device='cuda:0')
# 2.880658436213992 % done.
# MSE total:  tensor(4.5951, device='cuda:0')
# MSE states:  tensor(2.0899, device='cuda:0')
# MSE zones:  tensor(1.2981, device='cuda:0')
# MSE regions:  tensor(1.0595, device='cuda:0')
# MSE categories:  tensor(1.0332, device='cuda:0')
# MSE hier:  tensor(10.0759, device='cuda:0')
# 3.292181069958848 % done.
# MSE total:  tensor(4.6033, device='cuda:0')
# MSE states:  tensor(2.0952, device='cuda:0')
# MSE zones:  tensor(1.3031, device='cuda:0')
# MSE regions:  tensor(1.0635, device='cuda:0')
# MSE categories:  tensor(1.0417, device='cuda:0')
# MSE hier:  tensor(10.1068, device='cuda:0')
# 3.7037037037037033 % done.
# MSE total:  tensor(4.6164, device='cuda:0')
# MSE states:  tensor(2.0944, device='cuda:0')
# MSE zones:  tensor(1.2944, device='cuda:0')
# MSE regions:  tensor(1.0559, device='cuda:0')
# MSE categories:  tensor(1.0175, device='cuda:0')
# MSE hier:  tensor(10.0787, device='cuda:0')
# 4.11522633744856 % done.
# MSE total:  tensor(4.6173, device='cuda:0')
# MSE states:  tensor(2.0945, device='cuda:0')
# MSE zones:  tensor(1.2945, device='cuda:0')
# MSE regions:  tensor(1.0558, device='cuda:0')
# MSE categories:  tensor(1.0181, device='cuda:0')
# MSE hier:  tensor(10.0803, device='cuda:0')
# 4.526748971193416 % done.
# MSE total:  tensor(4.6250, device='cuda:0')
# MSE states:  tensor(2.0966, device='cuda:0')
# MSE zones:  tensor(1.2976, device='cuda:0')
# MSE regions:  tensor(1.0572, device='cuda:0')
# MSE categories:  tensor(1.0254, device='cuda:0')
# MSE hier:  tensor(10.1017, device='cuda:0')
# 4.938271604938271 % done.
# MSE total:  tensor(4.6137, device='cuda:0')
# MSE states:  tensor(2.0922, device='cuda:0')
# MSE zones:  tensor(1.2942, device='cuda:0')
# MSE regions:  tensor(1.0558, device='cuda:0')
# MSE categories:  tensor(1.0190, device='cuda:0')
# MSE hier:  tensor(10.0749, device='cuda:0')
# 5.349794238683128 % done.
# MSE total:  tensor(4.6146, device='cuda:0')
# MSE states:  tensor(2.0923, device='cuda:0')
# MSE zones:  tensor(1.2944, device='cuda:0')
# MSE regions:  tensor(1.0558, device='cuda:0')
# MSE categories:  tensor(1.0197, device='cuda:0')
# MSE hier:  tensor(10.0768, device='cuda:0')
# 5.761316872427984 % done.
# MSE total:  tensor(4.6222, device='cuda:0')
# MSE states:  tensor(2.0951, device='cuda:0')
# MSE zones:  tensor(1.2978, device='cuda:0')
# MSE regions:  tensor(1.0577, device='cuda:0')
# MSE categories:  tensor(1.0271, device='cuda:0')
# MSE hier:  tensor(10.1000, device='cuda:0')
# 6.172839506172839 % done.
# MSE total:  tensor(4.5926, device='cuda:0')
# MSE states:  tensor(2.0825, device='cuda:0')
# MSE zones:  tensor(1.2986, device='cuda:0')
# MSE regions:  tensor(1.0613, device='cuda:0')
# MSE categories:  tensor(1.0357, device='cuda:0')
# MSE hier:  tensor(10.0707, device='cuda:0')
# 6.584362139917696 % done.
# MSE total:  tensor(4.5935, device='cuda:0')
# MSE states:  tensor(2.0831, device='cuda:0')
# MSE zones:  tensor(1.2990, device='cuda:0')
# MSE regions:  tensor(1.0615, device='cuda:0')
# MSE categories:  tensor(1.0365, device='cuda:0')
# MSE hier:  tensor(10.0737, device='cuda:0')
# 6.995884773662551 % done.
# MSE total:  tensor(4.6007, device='cuda:0')
# MSE states:  tensor(2.0894, device='cuda:0')
# MSE zones:  tensor(1.3041, device='cuda:0')
# MSE regions:  tensor(1.0655, device='cuda:0')
# MSE categories:  tensor(1.0449, device='cuda:0')
# MSE hier:  tensor(10.1046, device='cuda:0')
# 7.4074074074074066 % done.
# MSE total:  tensor(4.6064, device='cuda:0')
# MSE states:  tensor(2.0616, device='cuda:0')
# MSE zones:  tensor(1.3091, device='cuda:0')
# MSE regions:  tensor(1.0764, device='cuda:0')
# MSE categories:  tensor(1.0464, device='cuda:0')
# MSE hier:  tensor(10.0999, device='cuda:0')
# 7.818930041152264 % done.
# MSE total:  tensor(4.6062, device='cuda:0')
# MSE states:  tensor(2.0621, device='cuda:0')
# MSE zones:  tensor(1.3092, device='cuda:0')
# MSE regions:  tensor(1.0763, device='cuda:0')
# MSE categories:  tensor(1.0469, device='cuda:0')
# MSE hier:  tensor(10.1007, device='cuda:0')
# 8.23045267489712 % done.
# MSE total:  tensor(4.6065, device='cuda:0')
# MSE states:  tensor(2.0678, device='cuda:0')
# MSE zones:  tensor(1.3118, device='cuda:0')
# MSE regions:  tensor(1.0772, device='cuda:0')
# MSE categories:  tensor(1.0533, device='cuda:0')
# MSE hier:  tensor(10.1166, device='cuda:0')
# 8.641975308641975 % done.
# MSE total:  tensor(4.6030, device='cuda:0')
# MSE states:  tensor(2.0618, device='cuda:0')
# MSE zones:  tensor(1.3091, device='cuda:0')
# MSE regions:  tensor(1.0764, device='cuda:0')
# MSE categories:  tensor(1.0476, device='cuda:0')
# MSE hier:  tensor(10.0978, device='cuda:0')
# 9.053497942386832 % done.
# MSE total:  tensor(4.6029, device='cuda:0')
# MSE states:  tensor(2.0623, device='cuda:0')
# MSE zones:  tensor(1.3093, device='cuda:0')
# MSE regions:  tensor(1.0763, device='cuda:0')
# MSE categories:  tensor(1.0482, device='cuda:0')
# MSE hier:  tensor(10.0989, device='cuda:0')
# 9.465020576131687 % done.
# MSE total:  tensor(4.6034, device='cuda:0')
# MSE states:  tensor(2.0682, device='cuda:0')
# MSE zones:  tensor(1.3122, device='cuda:0')
# MSE regions:  tensor(1.0776, device='cuda:0')
# MSE categories:  tensor(1.0548, device='cuda:0')
# MSE hier:  tensor(10.1162, device='cuda:0')
# 9.876543209876543 % done.
# MSE total:  tensor(4.5777, device='cuda:0')
# MSE states:  tensor(2.0661, device='cuda:0')
# MSE zones:  tensor(1.3138, device='cuda:0')
# MSE regions:  tensor(1.0810, device='cuda:0')
# MSE categories:  tensor(1.0619, device='cuda:0')
# MSE hier:  tensor(10.1005, device='cuda:0')
# 10.2880658436214 % done.
# MSE total:  tensor(4.5778, device='cuda:0')
# MSE states:  tensor(2.0668, device='cuda:0')
# MSE zones:  tensor(1.3141, device='cuda:0')
# MSE regions:  tensor(1.0812, device='cuda:0')
# MSE categories:  tensor(1.0627, device='cuda:0')
# MSE hier:  tensor(10.1027, device='cuda:0')
# 10.699588477366255 % done.
# MSE total:  tensor(4.5802, device='cuda:0')
# MSE states:  tensor(2.0740, device='cuda:0')
# MSE zones:  tensor(1.3185, device='cuda:0')
# MSE regions:  tensor(1.0846, device='cuda:0')
# MSE categories:  tensor(1.0703, device='cuda:0')
# MSE hier:  tensor(10.1277, device='cuda:0')
# 11.11111111111111 % done.
# MSE total:  tensor(4.5366, device='cuda:0')
# MSE states:  tensor(2.1268, device='cuda:0')
# MSE zones:  tensor(1.3199, device='cuda:0')
# MSE regions:  tensor(1.0833, device='cuda:0')
# MSE categories:  tensor(1.0454, device='cuda:0')
# MSE hier:  tensor(10.1120, device='cuda:0')
# 11.522633744855968 % done.
# MSE total:  tensor(4.5375, device='cuda:0')
# MSE states:  tensor(2.1265, device='cuda:0')
# MSE zones:  tensor(1.3199, device='cuda:0')
# MSE regions:  tensor(1.0832, device='cuda:0')
# MSE categories:  tensor(1.0461, device='cuda:0')
# MSE hier:  tensor(10.1133, device='cuda:0')
# 11.934156378600823 % done.
# MSE total:  tensor(4.5449, device='cuda:0')
# MSE states:  tensor(2.1261, device='cuda:0')
# MSE zones:  tensor(1.3226, device='cuda:0')
# MSE regions:  tensor(1.0849, device='cuda:0')
# MSE categories:  tensor(1.0541, device='cuda:0')
# MSE hier:  tensor(10.1325, device='cuda:0')
# 12.345679012345679 % done.
# MSE total:  tensor(4.5342, device='cuda:0')
# MSE states:  tensor(2.1229, device='cuda:0')
# MSE zones:  tensor(1.3192, device='cuda:0')
# MSE regions:  tensor(1.0831, device='cuda:0')
# MSE categories:  tensor(1.0469, device='cuda:0')
# MSE hier:  tensor(10.1063, device='cuda:0')
# 12.757201646090536 % done.
# MSE total:  tensor(4.5351, device='cuda:0')
# MSE states:  tensor(2.1227, device='cuda:0')
# MSE zones:  tensor(1.3194, device='cuda:0')
# MSE regions:  tensor(1.0831, device='cuda:0')
# MSE categories:  tensor(1.0476, device='cuda:0')
# MSE hier:  tensor(10.1080, device='cuda:0')
# 13.168724279835391 % done.
# MSE total:  tensor(4.5423, device='cuda:0')
# MSE states:  tensor(2.1234, device='cuda:0')
# MSE zones:  tensor(1.3226, device='cuda:0')
# MSE regions:  tensor(1.0853, device='cuda:0')
# MSE categories:  tensor(1.0559, device='cuda:0')
# MSE hier:  tensor(10.1294, device='cuda:0')
# 13.580246913580247 % done.
# MSE total:  tensor(4.5150, device='cuda:0')
# MSE states:  tensor(2.1048, device='cuda:0')
# MSE zones:  tensor(1.3216, device='cuda:0')
# MSE regions:  tensor(1.0882, device='cuda:0')
# MSE categories:  tensor(1.0638, device='cuda:0')
# MSE hier:  tensor(10.0935, device='cuda:0')
# 13.991769547325102 % done.
# MSE total:  tensor(4.5158, device='cuda:0')
# MSE states:  tensor(2.1054, device='cuda:0')
# MSE zones:  tensor(1.3221, device='cuda:0')
# MSE regions:  tensor(1.0885, device='cuda:0')
# MSE categories:  tensor(1.0648, device='cuda:0')
# MSE hier:  tensor(10.0965, device='cuda:0')
# 14.40329218106996 % done.
# MSE total:  tensor(4.5216, device='cuda:0')
# MSE states:  tensor(2.1113, device='cuda:0')
# MSE zones:  tensor(1.3275, device='cuda:0')
# MSE regions:  tensor(1.0929, device='cuda:0')
# MSE categories:  tensor(1.0740, device='cuda:0')
# MSE hier:  tensor(10.1272, device='cuda:0')
# 14.814814814814813 % done.
# MSE total:  tensor(4.5386, device='cuda:0')
# MSE states:  tensor(2.1110, device='cuda:0')
# MSE zones:  tensor(1.3186, device='cuda:0')
# MSE regions:  tensor(1.0843, device='cuda:0')
# MSE categories:  tensor(1.0482, device='cuda:0')
# MSE hier:  tensor(10.1007, device='cuda:0')
# 15.22633744855967 % done.
# MSE total:  tensor(4.5393, device='cuda:0')
# MSE states:  tensor(2.1111, device='cuda:0')
# MSE zones:  tensor(1.3188, device='cuda:0')
# MSE regions:  tensor(1.0842, device='cuda:0')
# MSE categories:  tensor(1.0489, device='cuda:0')
# MSE hier:  tensor(10.1024, device='cuda:0')
# 15.637860082304528 % done.
# MSE total:  tensor(4.5449, device='cuda:0')
# MSE states:  tensor(2.1137, device='cuda:0')
# MSE zones:  tensor(1.3221, device='cuda:0')
# MSE regions:  tensor(1.0862, device='cuda:0')
# MSE categories:  tensor(1.0570, device='cuda:0')
# MSE hier:  tensor(10.1239, device='cuda:0')
# 16.049382716049383 % done.
# MSE total:  tensor(4.5360, device='cuda:0')
# MSE states:  tensor(2.1086, device='cuda:0')
# MSE zones:  tensor(1.3183, device='cuda:0')
# MSE regions:  tensor(1.0842, device='cuda:0')
# MSE categories:  tensor(1.0498, device='cuda:0')
# MSE hier:  tensor(10.0968, device='cuda:0')
# 16.46090534979424 % done.
# MSE total:  tensor(4.5367, device='cuda:0')
# MSE states:  tensor(2.1088, device='cuda:0')
# MSE zones:  tensor(1.3186, device='cuda:0')
# MSE regions:  tensor(1.0842, device='cuda:0')
# MSE categories:  tensor(1.0505, device='cuda:0')
# MSE hier:  tensor(10.0987, device='cuda:0')
# 16.872427983539097 % done.
# MSE total:  tensor(4.5422, device='cuda:0')
# MSE states:  tensor(2.1121, device='cuda:0')
# MSE zones:  tensor(1.3223, device='cuda:0')
# MSE regions:  tensor(1.0866, device='cuda:0')
# MSE categories:  tensor(1.0588, device='cuda:0')
# MSE hier:  tensor(10.1220, device='cuda:0')
# 17.28395061728395 % done.
# MSE total:  tensor(4.5155, device='cuda:0')
# MSE states:  tensor(2.0979, device='cuda:0')
# MSE zones:  tensor(1.3222, device='cuda:0')
# MSE regions:  tensor(1.0898, device='cuda:0')
# MSE categories:  tensor(1.0667, device='cuda:0')
# MSE hier:  tensor(10.0920, device='cuda:0')
# 17.695473251028808 % done.
# MSE total:  tensor(4.5160, device='cuda:0')
# MSE states:  tensor(2.0985, device='cuda:0')
# MSE zones:  tensor(1.3227, device='cuda:0')
# MSE regions:  tensor(1.0901, device='cuda:0')
# MSE categories:  tensor(1.0676, device='cuda:0')
# MSE hier:  tensor(10.0950, device='cuda:0')
# 18.106995884773664 % done.
# MSE total:  tensor(4.5209, device='cuda:0')
# MSE states:  tensor(2.1053, device='cuda:0')
# MSE zones:  tensor(1.3281, device='cuda:0')
# MSE regions:  tensor(1.0946, device='cuda:0')
# MSE categories:  tensor(1.0768, device='cuda:0')
# MSE hier:  tensor(10.1257, device='cuda:0')
# 18.51851851851852 % done.
# MSE total:  tensor(4.5425, device='cuda:0')
# MSE states:  tensor(2.0770, device='cuda:0')
# MSE zones:  tensor(1.3309, device='cuda:0')
# MSE regions:  tensor(1.1022, device='cuda:0')
# MSE categories:  tensor(1.0739, device='cuda:0')
# MSE hier:  tensor(10.1265, device='cuda:0')
# 18.930041152263374 % done.
# MSE total:  tensor(4.5421, device='cuda:0')
# MSE states:  tensor(2.0775, device='cuda:0')
# MSE zones:  tensor(1.3310, device='cuda:0')
# MSE regions:  tensor(1.1021, device='cuda:0')
# MSE categories:  tensor(1.0746, device='cuda:0')
# MSE hier:  tensor(10.1273, device='cuda:0')
# 19.34156378600823 % done.
# MSE total:  tensor(4.5397, device='cuda:0')
# MSE states:  tensor(2.0838, device='cuda:0')
# MSE zones:  tensor(1.3340, device='cuda:0')
# MSE regions:  tensor(1.1036, device='cuda:0')
# MSE categories:  tensor(1.0819, device='cuda:0')
# MSE hier:  tensor(10.1430, device='cuda:0')
# 19.753086419753085 % done.
# MSE total:  tensor(4.5391, device='cuda:0')
# MSE states:  tensor(2.0771, device='cuda:0')
# MSE zones:  tensor(1.3308, device='cuda:0')
# MSE regions:  tensor(1.1022, device='cuda:0')
# MSE categories:  tensor(1.0752, device='cuda:0')
# MSE hier:  tensor(10.1244, device='cuda:0')
# 20.16460905349794 % done.
# MSE total:  tensor(4.5387, device='cuda:0')
# MSE states:  tensor(2.0777, device='cuda:0')
# MSE zones:  tensor(1.3310, device='cuda:0')
# MSE regions:  tensor(1.1022, device='cuda:0')
# MSE categories:  tensor(1.0759, device='cuda:0')
# MSE hier:  tensor(10.1255, device='cuda:0')
# 20.5761316872428 % done.
# MSE total:  tensor(4.5366, device='cuda:0')
# MSE states:  tensor(2.0841, device='cuda:0')
# MSE zones:  tensor(1.3344, device='cuda:0')
# MSE regions:  tensor(1.1041, device='cuda:0')
# MSE categories:  tensor(1.0834, device='cuda:0')
# MSE hier:  tensor(10.1426, device='cuda:0')
# 20.98765432098765 % done.
# MSE total:  tensor(4.5133, device='cuda:0')
# MSE states:  tensor(2.0811, device='cuda:0')
# MSE zones:  tensor(1.3353, device='cuda:0')
# MSE regions:  tensor(1.1072, device='cuda:0')
# MSE categories:  tensor(1.0901, device='cuda:0')
# MSE hier:  tensor(10.1269, device='cuda:0')
# 21.39917695473251 % done.
# MSE total:  tensor(4.5131, device='cuda:0')
# MSE states:  tensor(2.0819, device='cuda:0')
# MSE zones:  tensor(1.3357, device='cuda:0')
# MSE regions:  tensor(1.1074, device='cuda:0')
# MSE categories:  tensor(1.0909, device='cuda:0')
# MSE hier:  tensor(10.1290, device='cuda:0')
# 21.810699588477366 % done.
# MSE total:  tensor(4.5127, device='cuda:0')
# MSE states:  tensor(2.0895, device='cuda:0')
# MSE zones:  tensor(1.3405, device='cuda:0')
# MSE regions:  tensor(1.1113, device='cuda:0')
# MSE categories:  tensor(1.0994, device='cuda:0')
# MSE hier:  tensor(10.1535, device='cuda:0')
# 22.22222222222222 % done.
# MSE total:  tensor(4.5255, device='cuda:0')
# MSE states:  tensor(2.1295, device='cuda:0')
# MSE zones:  tensor(1.3233, device='cuda:0')
# MSE regions:  tensor(1.0875, device='cuda:0')
# MSE categories:  tensor(1.0499, device='cuda:0')
# MSE hier:  tensor(10.1157, device='cuda:0')
# 22.633744855967077 % done.
# MSE total:  tensor(4.5263, device='cuda:0')
# MSE states:  tensor(2.1291, device='cuda:0')
# MSE zones:  tensor(1.3234, device='cuda:0')
# MSE regions:  tensor(1.0874, device='cuda:0')
# MSE categories:  tensor(1.0507, device='cuda:0')
# MSE hier:  tensor(10.1170, device='cuda:0')
# 23.045267489711936 % done.
# MSE total:  tensor(4.5333, device='cuda:0')
# MSE states:  tensor(2.1288, device='cuda:0')
# MSE zones:  tensor(1.3262, device='cuda:0')
# MSE regions:  tensor(1.0893, device='cuda:0')
# MSE categories:  tensor(1.0589, device='cuda:0')
# MSE hier:  tensor(10.1365, device='cuda:0')
# 23.456790123456788 % done.
# MSE total:  tensor(4.5230, device='cuda:0')
# MSE states:  tensor(2.1255, device='cuda:0')
# MSE zones:  tensor(1.3227, device='cuda:0')
# MSE regions:  tensor(1.0873, device='cuda:0')
# MSE categories:  tensor(1.0515, device='cuda:0')
# MSE hier:  tensor(10.1100, device='cuda:0')
# 23.868312757201647 % done.
# MSE total:  tensor(4.5239, device='cuda:0')
# MSE states:  tensor(2.1253, device='cuda:0')
# MSE zones:  tensor(1.3229, device='cuda:0')
# MSE regions:  tensor(1.0873, device='cuda:0')
# MSE categories:  tensor(1.0522, device='cuda:0')
# MSE hier:  tensor(10.1116, device='cuda:0')
# 24.279835390946502 % done.
# MSE total:  tensor(4.5306, device='cuda:0')
# MSE states:  tensor(2.1261, device='cuda:0')
# MSE zones:  tensor(1.3262, device='cuda:0')
# MSE regions:  tensor(1.0897, device='cuda:0')
# MSE categories:  tensor(1.0607, device='cuda:0')
# MSE hier:  tensor(10.1334, device='cuda:0')
# 24.691358024691358 % done.
# MSE total:  tensor(4.5037, device='cuda:0')
# MSE states:  tensor(2.1073, device='cuda:0')
# MSE zones:  tensor(1.3251, device='cuda:0')
# MSE regions:  tensor(1.0925, device='cuda:0')
# MSE categories:  tensor(1.0687, device='cuda:0')
# MSE hier:  tensor(10.0973, device='cuda:0')
# 25.102880658436217 % done.
# MSE total:  tensor(4.5043, device='cuda:0')
# MSE states:  tensor(2.1079, device='cuda:0')
# MSE zones:  tensor(1.3256, device='cuda:0')
# MSE regions:  tensor(1.0929, device='cuda:0')
# MSE categories:  tensor(1.0696, device='cuda:0')
# MSE hier:  tensor(10.1003, device='cuda:0')
# 25.514403292181072 % done.
# MSE total:  tensor(4.5097, device='cuda:0')
# MSE states:  tensor(2.1139, device='cuda:0')
# MSE zones:  tensor(1.3311, device='cuda:0')
# MSE regions:  tensor(1.0975, device='cuda:0')
# MSE categories:  tensor(1.0791, device='cuda:0')
# MSE hier:  tensor(10.1313, device='cuda:0')
# 25.925925925925924 % done.
# MSE total:  tensor(4.5275, device='cuda:0')
# MSE states:  tensor(2.1135, device='cuda:0')
# MSE zones:  tensor(1.3221, device='cuda:0')
# MSE regions:  tensor(1.0884, device='cuda:0')
# MSE categories:  tensor(1.0528, device='cuda:0')
# MSE hier:  tensor(10.1043, device='cuda:0')
# 26.337448559670783 % done.
# MSE total:  tensor(4.5282, device='cuda:0')
# MSE states:  tensor(2.1136, device='cuda:0')
# MSE zones:  tensor(1.3223, device='cuda:0')
# MSE regions:  tensor(1.0884, device='cuda:0')
# MSE categories:  tensor(1.0535, device='cuda:0')
# MSE hier:  tensor(10.1060, device='cuda:0')
# 26.74897119341564 % done.
# MSE total:  tensor(4.5334, device='cuda:0')
# MSE states:  tensor(2.1164, device='cuda:0')
# MSE zones:  tensor(1.3257, device='cuda:0')
# MSE regions:  tensor(1.0905, device='cuda:0')
# MSE categories:  tensor(1.0618, device='cuda:0')
# MSE hier:  tensor(10.1278, device='cuda:0')
# 27.160493827160494 % done.
# MSE total:  tensor(4.5249, device='cuda:0')
# MSE states:  tensor(2.1110, device='cuda:0')
# MSE zones:  tensor(1.3218, device='cuda:0')
# MSE regions:  tensor(1.0884, device='cuda:0')
# MSE categories:  tensor(1.0543, device='cuda:0')
# MSE hier:  tensor(10.1004, device='cuda:0')
# 27.572016460905353 % done.
# MSE total:  tensor(4.5255, device='cuda:0')
# MSE states:  tensor(2.1112, device='cuda:0')
# MSE zones:  tensor(1.3220, device='cuda:0')
# MSE regions:  tensor(1.0884, device='cuda:0')
# MSE categories:  tensor(1.0551, device='cuda:0')
# MSE hier:  tensor(10.1023, device='cuda:0')
# 27.983539094650205 % done.
# MSE total:  tensor(4.5307, device='cuda:0')
# MSE states:  tensor(2.1147, device='cuda:0')
# MSE zones:  tensor(1.3259, device='cuda:0')
# MSE regions:  tensor(1.0910, device='cuda:0')
# MSE categories:  tensor(1.0636, device='cuda:0')
# MSE hier:  tensor(10.1258, device='cuda:0')
# 28.39506172839506 % done.
# MSE total:  tensor(4.5042, device='cuda:0')
# MSE states:  tensor(2.1003, device='cuda:0')
# MSE zones:  tensor(1.3257, device='cuda:0')
# MSE regions:  tensor(1.0942, device='cuda:0')
# MSE categories:  tensor(1.0716, device='cuda:0')
# MSE hier:  tensor(10.0959, device='cuda:0')
# 28.80658436213992 % done.
# MSE total:  tensor(4.5047, device='cuda:0')
# MSE states:  tensor(2.1010, device='cuda:0')
# MSE zones:  tensor(1.3262, device='cuda:0')
# MSE regions:  tensor(1.0945, device='cuda:0')
# MSE categories:  tensor(1.0725, device='cuda:0')
# MSE hier:  tensor(10.0989, device='cuda:0')
# 29.218106995884774 % done.
# MSE total:  tensor(4.5091, device='cuda:0')
# MSE states:  tensor(2.1079, device='cuda:0')
# MSE zones:  tensor(1.3318, device='cuda:0')
# MSE regions:  tensor(1.0991, device='cuda:0')
# MSE categories:  tensor(1.0819, device='cuda:0')
# MSE hier:  tensor(10.1298, device='cuda:0')
# 29.629629629629626 % done.
# MSE total:  tensor(4.5322, device='cuda:0')
# MSE states:  tensor(2.0793, device='cuda:0')
# MSE zones:  tensor(1.3342, device='cuda:0')
# MSE regions:  tensor(1.1063, device='cuda:0')
# MSE categories:  tensor(1.0785, device='cuda:0')
# MSE hier:  tensor(10.1305, device='cuda:0')
# 30.04115226337449 % done.
# MSE total:  tensor(4.5317, device='cuda:0')
# MSE states:  tensor(2.0799, device='cuda:0')
# MSE zones:  tensor(1.3344, device='cuda:0')
# MSE regions:  tensor(1.1063, device='cuda:0')
# MSE categories:  tensor(1.0791, device='cuda:0')
# MSE hier:  tensor(10.1314, device='cuda:0')
# 30.45267489711934 % done.
# MSE total:  tensor(4.5288, device='cuda:0')
# MSE states:  tensor(2.0863, device='cuda:0')
# MSE zones:  tensor(1.3376, device='cuda:0')
# MSE regions:  tensor(1.1080, device='cuda:0')
# MSE categories:  tensor(1.0867, device='cuda:0')
# MSE hier:  tensor(10.1473, device='cuda:0')
# 30.864197530864196 % done.
# MSE total:  tensor(4.5288, device='cuda:0')
# MSE states:  tensor(2.0794, device='cuda:0')
# MSE zones:  tensor(1.3342, device='cuda:0')
# MSE regions:  tensor(1.1064, device='cuda:0')
# MSE categories:  tensor(1.0798, device='cuda:0')
# MSE hier:  tensor(10.1285, device='cuda:0')
# 31.275720164609055 % done.
# MSE total:  tensor(4.5283, device='cuda:0')
# MSE states:  tensor(2.0800, device='cuda:0')
# MSE zones:  tensor(1.3344, device='cuda:0')
# MSE regions:  tensor(1.1064, device='cuda:0')
# MSE categories:  tensor(1.0805, device='cuda:0')
# MSE hier:  tensor(10.1296, device='cuda:0')
# 31.68724279835391 % done.
# MSE total:  tensor(4.5257, device='cuda:0')
# MSE states:  tensor(2.0867, device='cuda:0')
# MSE zones:  tensor(1.3379, device='cuda:0')
# MSE regions:  tensor(1.1084, device='cuda:0')
# MSE categories:  tensor(1.0883, device='cuda:0')
# MSE hier:  tensor(10.1469, device='cuda:0')
# 32.098765432098766 % done.
# MSE total:  tensor(4.5026, device='cuda:0')
# MSE states:  tensor(2.0835, device='cuda:0')
# MSE zones:  tensor(1.3388, device='cuda:0')
# MSE regions:  tensor(1.1115, device='cuda:0')
# MSE categories:  tensor(1.0949, device='cuda:0')
# MSE hier:  tensor(10.1313, device='cuda:0')
# 32.510288065843625 % done.
# MSE total:  tensor(4.5024, device='cuda:0')
# MSE states:  tensor(2.0843, device='cuda:0')
# MSE zones:  tensor(1.3392, device='cuda:0')
# MSE regions:  tensor(1.1118, device='cuda:0')
# MSE categories:  tensor(1.0957, device='cuda:0')
# MSE hier:  tensor(10.1335, device='cuda:0')
# 32.92181069958848 % done.
# MSE total:  tensor(4.5015, device='cuda:0')
# MSE states:  tensor(2.0921, device='cuda:0')
# MSE zones:  tensor(1.3442, device='cuda:0')
# MSE regions:  tensor(1.1158, device='cuda:0')
# MSE categories:  tensor(1.1044, device='cuda:0')
# MSE hier:  tensor(10.1580, device='cuda:0')
# 33.33333333333333 % done.
# MSE total:  tensor(4.4508, device='cuda:0')
# MSE states:  tensor(2.0222, device='cuda:0')
# MSE zones:  tensor(1.1950, device='cuda:0')
# MSE regions:  tensor(0.9711, device='cuda:0')
# MSE categories:  tensor(0.9309, device='cuda:0')
# MSE hier:  tensor(9.5700, device='cuda:0')
# 33.744855967078195 % done.
# MSE total:  tensor(4.4521, device='cuda:0')
# MSE states:  tensor(2.0217, device='cuda:0')
# MSE zones:  tensor(1.1948, device='cuda:0')
# MSE regions:  tensor(0.9709, device='cuda:0')
# MSE categories:  tensor(0.9311, device='cuda:0')
# MSE hier:  tensor(9.5706, device='cuda:0')
# 34.15637860082305 % done.
# MSE total:  tensor(4.4621, device='cuda:0')
# MSE states:  tensor(2.0181, device='cuda:0')
# MSE zones:  tensor(1.1941, device='cuda:0')
# MSE regions:  tensor(0.9694, device='cuda:0')
# MSE categories:  tensor(0.9329, device='cuda:0')
# MSE hier:  tensor(9.5766, device='cuda:0')
# 34.5679012345679 % done.
# MSE total:  tensor(4.4505, device='cuda:0')
# MSE states:  tensor(2.0210, device='cuda:0')
# MSE zones:  tensor(1.1953, device='cuda:0')
# MSE regions:  tensor(0.9711, device='cuda:0')
# MSE categories:  tensor(0.9316, device='cuda:0')
# MSE hier:  tensor(9.5695, device='cuda:0')
# 34.97942386831276 % done.
# MSE total:  tensor(4.4517, device='cuda:0')
# MSE states:  tensor(2.0206, device='cuda:0')
# MSE zones:  tensor(1.1952, device='cuda:0')
# MSE regions:  tensor(0.9708, device='cuda:0')
# MSE categories:  tensor(0.9317, device='cuda:0')
# MSE hier:  tensor(9.5701, device='cuda:0')
# 35.390946502057616 % done.
# MSE total:  tensor(4.4615, device='cuda:0')
# MSE states:  tensor(2.0171, device='cuda:0')
# MSE zones:  tensor(1.1946, device='cuda:0')
# MSE regions:  tensor(0.9695, device='cuda:0')
# MSE categories:  tensor(0.9336, device='cuda:0')
# MSE hier:  tensor(9.5763, device='cuda:0')
# 35.80246913580247 % done.
# MSE total:  tensor(4.4457, device='cuda:0')
# MSE states:  tensor(2.0136, device='cuda:0')
# MSE zones:  tensor(1.1997, device='cuda:0')
# MSE regions:  tensor(0.9720, device='cuda:0')
# MSE categories:  tensor(0.9379, device='cuda:0')
# MSE hier:  tensor(9.5689, device='cuda:0')
# 36.21399176954733 % done.
# MSE total:  tensor(4.4468, device='cuda:0')
# MSE states:  tensor(2.0133, device='cuda:0')
# MSE zones:  tensor(1.1996, device='cuda:0')
# MSE regions:  tensor(0.9719, device='cuda:0')
# MSE categories:  tensor(0.9381, device='cuda:0')
# MSE hier:  tensor(9.5697, device='cuda:0')
# 36.62551440329218 % done.
# MSE total:  tensor(4.4550, device='cuda:0')
# MSE states:  tensor(2.0114, device='cuda:0')
# MSE zones:  tensor(1.1995, device='cuda:0')
# MSE regions:  tensor(0.9713, device='cuda:0')
# MSE categories:  tensor(0.9404, device='cuda:0')
# MSE hier:  tensor(9.5776, device='cuda:0')
# 37.03703703703704 % done.
# MSE total:  tensor(4.4533, device='cuda:0')
# MSE states:  tensor(2.0150, device='cuda:0')
# MSE zones:  tensor(1.1947, device='cuda:0')
# MSE regions:  tensor(0.9718, device='cuda:0')
# MSE categories:  tensor(0.9323, device='cuda:0')
# MSE hier:  tensor(9.5671, device='cuda:0')
# 37.4485596707819 % done.
# MSE total:  tensor(4.4544, device='cuda:0')
# MSE states:  tensor(2.0146, device='cuda:0')
# MSE zones:  tensor(1.1946, device='cuda:0')
# MSE regions:  tensor(0.9715, device='cuda:0')
# MSE categories:  tensor(0.9325, device='cuda:0')
# MSE hier:  tensor(9.5677, device='cuda:0')
# 37.86008230452675 % done.
# MSE total:  tensor(4.4634, device='cuda:0')
# MSE states:  tensor(2.0118, device='cuda:0')
# MSE zones:  tensor(1.1941, device='cuda:0')
# MSE regions:  tensor(0.9701, device='cuda:0')
# MSE categories:  tensor(0.9343, device='cuda:0')
# MSE hier:  tensor(9.5738, device='cuda:0')
# 38.2716049382716 % done.
# MSE total:  tensor(4.4527, device='cuda:0')
# MSE states:  tensor(2.0142, device='cuda:0')
# MSE zones:  tensor(1.1952, device='cuda:0')
# MSE regions:  tensor(0.9718, device='cuda:0')
# MSE categories:  tensor(0.9330, device='cuda:0')
# MSE hier:  tensor(9.5668, device='cuda:0')
# 38.68312757201646 % done.
# MSE total:  tensor(4.4539, device='cuda:0')
# MSE states:  tensor(2.0138, device='cuda:0')
# MSE zones:  tensor(1.1951, device='cuda:0')
# MSE regions:  tensor(0.9715, device='cuda:0')
# MSE categories:  tensor(0.9331, device='cuda:0')
# MSE hier:  tensor(9.5674, device='cuda:0')
# 39.09465020576132 % done.
# MSE total:  tensor(4.4627, device='cuda:0')
# MSE states:  tensor(2.0112, device='cuda:0')
# MSE zones:  tensor(1.1946, device='cuda:0')
# MSE regions:  tensor(0.9702, device='cuda:0')
# MSE categories:  tensor(0.9351, device='cuda:0')
# MSE hier:  tensor(9.5737, device='cuda:0')
# 39.50617283950617 % done.
# MSE total:  tensor(4.4466, device='cuda:0')
# MSE states:  tensor(2.0091, device='cuda:0')
# MSE zones:  tensor(1.2000, device='cuda:0')
# MSE regions:  tensor(0.9729, device='cuda:0')
# MSE categories:  tensor(0.9394, device='cuda:0')
# MSE hier:  tensor(9.5680, device='cuda:0')
# 39.91769547325103 % done.
# MSE total:  tensor(4.4475, device='cuda:0')
# MSE states:  tensor(2.0089, device='cuda:0')
# MSE zones:  tensor(1.2000, device='cuda:0')
# MSE regions:  tensor(0.9728, device='cuda:0')
# MSE categories:  tensor(0.9396, device='cuda:0')
# MSE hier:  tensor(9.5688, device='cuda:0')
# 40.32921810699588 % done.
# MSE total:  tensor(4.4552, device='cuda:0')
# MSE states:  tensor(2.0074, device='cuda:0')
# MSE zones:  tensor(1.1999, device='cuda:0')
# MSE regions:  tensor(0.9722, device='cuda:0')
# MSE categories:  tensor(0.9419, device='cuda:0')
# MSE hier:  tensor(9.5766, device='cuda:0')
# 40.74074074074074 % done.
# MSE total:  tensor(4.4639, device='cuda:0')
# MSE states:  tensor(1.9933, device='cuda:0')
# MSE zones:  tensor(1.2022, device='cuda:0')
# MSE regions:  tensor(0.9813, device='cuda:0')
# MSE categories:  tensor(0.9459, device='cuda:0')
# MSE hier:  tensor(9.5866, device='cuda:0')
# 41.1522633744856 % done.
# MSE total:  tensor(4.4643, device='cuda:0')
# MSE states:  tensor(1.9931, device='cuda:0')
# MSE zones:  tensor(1.2021, device='cuda:0')
# MSE regions:  tensor(0.9811, device='cuda:0')
# MSE categories:  tensor(0.9461, device='cuda:0')
# MSE hier:  tensor(9.5867, device='cuda:0')
# 41.56378600823045 % done.
# MSE total:  tensor(4.4679, device='cuda:0')
# MSE states:  tensor(1.9919, device='cuda:0')
# MSE zones:  tensor(1.2016, device='cuda:0')
# MSE regions:  tensor(0.9796, device='cuda:0')
# MSE categories:  tensor(0.9477, device='cuda:0')
# MSE hier:  tensor(9.5887, device='cuda:0')
# 41.9753086419753 % done.
# MSE total:  tensor(4.4624, device='cuda:0')
# MSE states:  tensor(1.9935, device='cuda:0')
# MSE zones:  tensor(1.2028, device='cuda:0')
# MSE regions:  tensor(0.9814, device='cuda:0')
# MSE categories:  tensor(0.9466, device='cuda:0')
# MSE hier:  tensor(9.5866, device='cuda:0')
# 42.38683127572017 % done.
# MSE total:  tensor(4.4628, device='cuda:0')
# MSE states:  tensor(1.9933, device='cuda:0')
# MSE zones:  tensor(1.2027, device='cuda:0')
# MSE regions:  tensor(0.9812, device='cuda:0')
# MSE categories:  tensor(0.9467, device='cuda:0')
# MSE hier:  tensor(9.5867, device='cuda:0')
# 42.79835390946502 % done.
# MSE total:  tensor(4.4664, device='cuda:0')
# MSE states:  tensor(1.9920, device='cuda:0')
# MSE zones:  tensor(1.2022, device='cuda:0')
# MSE regions:  tensor(0.9797, device='cuda:0')
# MSE categories:  tensor(0.9484, device='cuda:0')
# MSE hier:  tensor(9.5888, device='cuda:0')
# 43.20987654320987 % done.
# MSE total:  tensor(4.4494, device='cuda:0')
# MSE states:  tensor(1.9948, device='cuda:0')
# MSE zones:  tensor(1.2084, device='cuda:0')
# MSE regions:  tensor(0.9828, device='cuda:0')
# MSE categories:  tensor(0.9528, device='cuda:0')
# MSE hier:  tensor(9.5882, device='cuda:0')
# 43.62139917695473 % done.
# MSE total:  tensor(4.4498, device='cuda:0')
# MSE states:  tensor(1.9947, device='cuda:0')
# MSE zones:  tensor(1.2084, device='cuda:0')
# MSE regions:  tensor(0.9826, device='cuda:0')
# MSE categories:  tensor(0.9530, device='cuda:0')
# MSE hier:  tensor(9.5885, device='cuda:0')
# 44.03292181069959 % done.
# MSE total:  tensor(4.4536, device='cuda:0')
# MSE states:  tensor(1.9937, device='cuda:0')
# MSE zones:  tensor(1.2081, device='cuda:0')
# MSE regions:  tensor(0.9818, device='cuda:0')
# MSE categories:  tensor(0.9550, device='cuda:0')
# MSE hier:  tensor(9.5922, device='cuda:0')
# 44.44444444444444 % done.
# MSE total:  tensor(4.3330, device='cuda:0')
# MSE states:  tensor(2.0728, device='cuda:0')
# MSE zones:  tensor(1.2598, device='cuda:0')
# MSE regions:  tensor(1.0325, device='cuda:0')
# MSE categories:  tensor(0.9935, device='cuda:0')
# MSE hier:  tensor(9.6916, device='cuda:0')
# 44.8559670781893 % done.
# MSE total:  tensor(4.3340, device='cuda:0')
# MSE states:  tensor(2.0719, device='cuda:0')
# MSE zones:  tensor(1.2593, device='cuda:0')
# MSE regions:  tensor(1.0320, device='cuda:0')
# MSE categories:  tensor(0.9935, device='cuda:0')
# MSE hier:  tensor(9.6906, device='cuda:0')
# 45.267489711934154 % done.
# MSE total:  tensor(4.3414, device='cuda:0')
# MSE states:  tensor(2.0650, device='cuda:0')
# MSE zones:  tensor(1.2556, device='cuda:0')
# MSE regions:  tensor(1.0284, device='cuda:0')
# MSE categories:  tensor(0.9945, device='cuda:0')
# MSE hier:  tensor(9.6849, device='cuda:0')
# 45.67901234567901 % done.
# MSE total:  tensor(4.3326, device='cuda:0')
# MSE states:  tensor(2.0704, device='cuda:0')
# MSE zones:  tensor(1.2593, device='cuda:0')
# MSE regions:  tensor(1.0320, device='cuda:0')
# MSE categories:  tensor(0.9938, device='cuda:0')
# MSE hier:  tensor(9.6880, device='cuda:0')
# 46.09053497942387 % done.
# MSE total:  tensor(4.3335, device='cuda:0')
# MSE states:  tensor(2.0695, device='cuda:0')
# MSE zones:  tensor(1.2588, device='cuda:0')
# MSE regions:  tensor(1.0315, device='cuda:0')
# MSE categories:  tensor(0.9938, device='cuda:0')
# MSE hier:  tensor(9.6872, device='cuda:0')
# 46.50205761316872 % done.
# MSE total:  tensor(4.3409, device='cuda:0')
# MSE states:  tensor(2.0632, device='cuda:0')
# MSE zones:  tensor(1.2553, device='cuda:0')
# MSE regions:  tensor(1.0282, device='cuda:0')
# MSE categories:  tensor(0.9949, device='cuda:0')
# MSE hier:  tensor(9.6824, device='cuda:0')
# 46.913580246913575 % done.
# MSE total:  tensor(4.3290, device='cuda:0')
# MSE states:  tensor(2.0562, device='cuda:0')
# MSE zones:  tensor(1.2580, device='cuda:0')
# MSE regions:  tensor(1.0301, device='cuda:0')
# MSE categories:  tensor(0.9981, device='cuda:0')
# MSE hier:  tensor(9.6715, device='cuda:0')
# 47.325102880658434 % done.
# MSE total:  tensor(4.3298, device='cuda:0')
# MSE states:  tensor(2.0558, device='cuda:0')
# MSE zones:  tensor(1.2577, device='cuda:0')
# MSE regions:  tensor(1.0298, device='cuda:0')
# MSE categories:  tensor(0.9982, device='cuda:0')
# MSE hier:  tensor(9.6713, device='cuda:0')
# 47.73662551440329 % done.
# MSE total:  tensor(4.3360, device='cuda:0')
# MSE states:  tensor(2.0522, device='cuda:0')
# MSE zones:  tensor(1.2557, device='cuda:0')
# MSE regions:  tensor(1.0276, device='cuda:0')
# MSE categories:  tensor(1.0000, device='cuda:0')
# MSE hier:  tensor(9.6715, device='cuda:0')
# 48.148148148148145 % done.
# MSE total:  tensor(4.3367, device='cuda:0')
# MSE states:  tensor(2.0622, device='cuda:0')
# MSE zones:  tensor(1.2579, device='cuda:0')
# MSE regions:  tensor(1.0322, device='cuda:0')
# MSE categories:  tensor(0.9941, device='cuda:0')
# MSE hier:  tensor(9.6831, device='cuda:0')
# 48.559670781893004 % done.
# MSE total:  tensor(4.3376, device='cuda:0')
# MSE states:  tensor(2.0616, device='cuda:0')
# MSE zones:  tensor(1.2574, device='cuda:0')
# MSE regions:  tensor(1.0317, device='cuda:0')
# MSE categories:  tensor(0.9941, device='cuda:0')
# MSE hier:  tensor(9.6824, device='cuda:0')
# 48.971193415637856 % done.
# MSE total:  tensor(4.3443, device='cuda:0')
# MSE states:  tensor(2.0563, device='cuda:0')
# MSE zones:  tensor(1.2542, device='cuda:0')
# MSE regions:  tensor(1.0284, device='cuda:0')
# MSE categories:  tensor(0.9952, device='cuda:0')
# MSE hier:  tensor(9.6783, device='cuda:0')
# 49.382716049382715 % done.
# MSE total:  tensor(4.3361, device='cuda:0')
# MSE states:  tensor(2.0605, device='cuda:0')
# MSE zones:  tensor(1.2576, device='cuda:0')
# MSE regions:  tensor(1.0318, device='cuda:0')
# MSE categories:  tensor(0.9944, device='cuda:0')
# MSE hier:  tensor(9.6805, device='cuda:0')
# 49.794238683127574 % done.
# MSE total:  tensor(4.3370, device='cuda:0')
# MSE states:  tensor(2.0599, device='cuda:0')
# MSE zones:  tensor(1.2571, device='cuda:0')
# MSE regions:  tensor(1.0313, device='cuda:0')
# MSE categories:  tensor(0.9945, device='cuda:0')
# MSE hier:  tensor(9.6799, device='cuda:0')
# 50.20576131687243 % done.
# MSE total:  tensor(4.3437, device='cuda:0')
# MSE states:  tensor(2.0550, device='cuda:0')
# MSE zones:  tensor(1.2541, device='cuda:0')
# MSE regions:  tensor(1.0282, device='cuda:0')
# MSE categories:  tensor(0.9957, device='cuda:0')
# MSE hier:  tensor(9.6766, device='cuda:0')
# 50.617283950617285 % done.
# MSE total:  tensor(4.3317, device='cuda:0')
# MSE states:  tensor(2.0504, device='cuda:0')
# MSE zones:  tensor(1.2574, device='cuda:0')
# MSE regions:  tensor(1.0304, device='cuda:0')
# MSE categories:  tensor(0.9990, device='cuda:0')
# MSE hier:  tensor(9.6688, device='cuda:0')
# 51.028806584362144 % done.
# MSE total:  tensor(4.3325, device='cuda:0')
# MSE states:  tensor(2.0500, device='cuda:0')
# MSE zones:  tensor(1.2571, device='cuda:0')
# MSE regions:  tensor(1.0301, device='cuda:0')
# MSE categories:  tensor(0.9991, device='cuda:0')
# MSE hier:  tensor(9.6688, device='cuda:0')
# 51.440329218106996 % done.
# MSE total:  tensor(4.3381, device='cuda:0')
# MSE states:  tensor(2.0471, device='cuda:0')
# MSE zones:  tensor(1.2552, device='cuda:0')
# MSE regions:  tensor(1.0280, device='cuda:0')
# MSE categories:  tensor(1.0009, device='cuda:0')
# MSE hier:  tensor(9.6693, device='cuda:0')
# 51.85185185185185 % done.
# MSE total:  tensor(4.3597, device='cuda:0')
# MSE states:  tensor(2.0294, device='cuda:0')
# MSE zones:  tensor(1.2571, device='cuda:0')
# MSE regions:  tensor(1.0362, device='cuda:0')
# MSE categories:  tensor(1.0025, device='cuda:0')
# MSE hier:  tensor(9.6849, device='cuda:0')
# 52.2633744855967 % done.
# MSE total:  tensor(4.3601, device='cuda:0')
# MSE states:  tensor(2.0292, device='cuda:0')
# MSE zones:  tensor(1.2568, device='cuda:0')
# MSE regions:  tensor(1.0357, device='cuda:0')
# MSE categories:  tensor(1.0025, device='cuda:0')
# MSE hier:  tensor(9.6843, device='cuda:0')
# 52.674897119341566 % done.
# MSE total:  tensor(4.3625, device='cuda:0')
# MSE states:  tensor(2.0274, device='cuda:0')
# MSE zones:  tensor(1.2544, device='cuda:0')
# MSE regions:  tensor(1.0327, device='cuda:0')
# MSE categories:  tensor(1.0037, device='cuda:0')
# MSE hier:  tensor(9.6807, device='cuda:0')
# 53.086419753086425 % done.
# MSE total:  tensor(4.3585, device='cuda:0')
# MSE states:  tensor(2.0294, device='cuda:0')
# MSE zones:  tensor(1.2573, device='cuda:0')
# MSE regions:  tensor(1.0360, device='cuda:0')
# MSE categories:  tensor(1.0029, device='cuda:0')
# MSE hier:  tensor(9.6842, device='cuda:0')
# 53.49794238683128 % done.
# MSE total:  tensor(4.3588, device='cuda:0')
# MSE states:  tensor(2.0292, device='cuda:0')
# MSE zones:  tensor(1.2569, device='cuda:0')
# MSE regions:  tensor(1.0356, device='cuda:0')
# MSE categories:  tensor(1.0030, device='cuda:0')
# MSE hier:  tensor(9.6836, device='cuda:0')
# 53.90946502057613 % done.
# MSE total:  tensor(4.3613, device='cuda:0')
# MSE states:  tensor(2.0275, device='cuda:0')
# MSE zones:  tensor(1.2547, device='cuda:0')
# MSE regions:  tensor(1.0326, device='cuda:0')
# MSE categories:  tensor(1.0042, device='cuda:0')
# MSE hier:  tensor(9.6803, device='cuda:0')
# 54.32098765432099 % done.
# MSE total:  tensor(4.3487, device='cuda:0')
# MSE states:  tensor(2.0300, device='cuda:0')
# MSE zones:  tensor(1.2598, device='cuda:0')
# MSE regions:  tensor(1.0357, device='cuda:0')
# MSE categories:  tensor(1.0080, device='cuda:0')
# MSE hier:  tensor(9.6821, device='cuda:0')
# 54.73251028806584 % done.
# MSE total:  tensor(4.3490, device='cuda:0')
# MSE states:  tensor(2.0298, device='cuda:0')
# MSE zones:  tensor(1.2596, device='cuda:0')
# MSE regions:  tensor(1.0354, device='cuda:0')
# MSE categories:  tensor(1.0081, device='cuda:0')
# MSE hier:  tensor(9.6819, device='cuda:0')
# 55.144032921810705 % done.
# MSE total:  tensor(4.3514, device='cuda:0')
# MSE states:  tensor(2.0285, device='cuda:0')
# MSE zones:  tensor(1.2580, device='cuda:0')
# MSE regions:  tensor(1.0332, device='cuda:0')
# MSE categories:  tensor(1.0098, device='cuda:0')
# MSE hier:  tensor(9.6808, device='cuda:0')
# 55.55555555555556 % done.
# MSE total:  tensor(4.3123, device='cuda:0')
# MSE states:  tensor(2.0862, device='cuda:0')
# MSE zones:  tensor(1.2756, device='cuda:0')
# MSE regions:  tensor(1.0481, device='cuda:0')
# MSE categories:  tensor(1.0100, device='cuda:0')
# MSE hier:  tensor(9.7320, device='cuda:0')
# 55.96707818930041 % done.
# MSE total:  tensor(4.3133, device='cuda:0')
# MSE states:  tensor(2.0852, device='cuda:0')
# MSE zones:  tensor(1.2749, device='cuda:0')
# MSE regions:  tensor(1.0475, device='cuda:0')
# MSE categories:  tensor(1.0101, device='cuda:0')
# MSE hier:  tensor(9.7309, device='cuda:0')
# 56.37860082304527 % done.
# MSE total:  tensor(4.3208, device='cuda:0')
# MSE states:  tensor(2.0779, device='cuda:0')
# MSE zones:  tensor(1.2707, device='cuda:0')
# MSE regions:  tensor(1.0436, device='cuda:0')
# MSE categories:  tensor(1.0111, device='cuda:0')
# MSE hier:  tensor(9.7242, device='cuda:0')
# 56.79012345679012 % done.
# MSE total:  tensor(4.3118, device='cuda:0')
# MSE states:  tensor(2.0835, device='cuda:0')
# MSE zones:  tensor(1.2748, device='cuda:0')
# MSE regions:  tensor(1.0475, device='cuda:0')
# MSE categories:  tensor(1.0103, device='cuda:0')
# MSE hier:  tensor(9.7279, device='cuda:0')
# 57.20164609053497 % done.
# MSE total:  tensor(4.3127, device='cuda:0')
# MSE states:  tensor(2.0826, device='cuda:0')
# MSE zones:  tensor(1.2743, device='cuda:0')
# MSE regions:  tensor(1.0470, device='cuda:0')
# MSE categories:  tensor(1.0104, device='cuda:0')
# MSE hier:  tensor(9.7270, device='cuda:0')
# 57.61316872427984 % done.
# MSE total:  tensor(4.3202, device='cuda:0')
# MSE states:  tensor(2.0759, device='cuda:0')
# MSE zones:  tensor(1.2703, device='cuda:0')
# MSE regions:  tensor(1.0434, device='cuda:0')
# MSE categories:  tensor(1.0116, device='cuda:0')
# MSE hier:  tensor(9.7214, device='cuda:0')
# 58.0246913580247 % done.
# MSE total:  tensor(4.3085, device='cuda:0')
# MSE states:  tensor(2.0680, device='cuda:0')
# MSE zones:  tensor(1.2724, device='cuda:0')
# MSE regions:  tensor(1.0454, device='cuda:0')
# MSE categories:  tensor(1.0147, device='cuda:0')
# MSE hier:  tensor(9.7091, device='cuda:0')
# 58.43621399176955 % done.
# MSE total:  tensor(4.3094, device='cuda:0')
# MSE states:  tensor(2.0676, device='cuda:0')
# MSE zones:  tensor(1.2721, device='cuda:0')
# MSE regions:  tensor(1.0451, device='cuda:0')
# MSE categories:  tensor(1.0148, device='cuda:0')
# MSE hier:  tensor(9.7089, device='cuda:0')
# 58.8477366255144 % done.
# MSE total:  tensor(4.3157, device='cuda:0')
# MSE states:  tensor(2.0640, device='cuda:0')
# MSE zones:  tensor(1.2699, device='cuda:0')
# MSE regions:  tensor(1.0427, device='cuda:0')
# MSE categories:  tensor(1.0167, device='cuda:0')
# MSE hier:  tensor(9.7090, device='cuda:0')
# 59.25925925925925 % done.
# MSE total:  tensor(4.3158, device='cuda:0')
# MSE states:  tensor(2.0746, device='cuda:0')
# MSE zones:  tensor(1.2733, device='cuda:0')
# MSE regions:  tensor(1.0477, device='cuda:0')
# MSE categories:  tensor(1.0105, device='cuda:0')
# MSE hier:  tensor(9.7219, device='cuda:0')
# 59.67078189300411 % done.
# MSE total:  tensor(4.3167, device='cuda:0')
# MSE states:  tensor(2.0739, device='cuda:0')
# MSE zones:  tensor(1.2728, device='cuda:0')
# MSE regions:  tensor(1.0471, device='cuda:0')
# MSE categories:  tensor(1.0106, device='cuda:0')
# MSE hier:  tensor(9.7211, device='cuda:0')
# 60.08230452674898 % done.
# MSE total:  tensor(4.3235, device='cuda:0')
# MSE states:  tensor(2.0685, device='cuda:0')
# MSE zones:  tensor(1.2691, device='cuda:0')
# MSE regions:  tensor(1.0435, device='cuda:0')
# MSE categories:  tensor(1.0118, device='cuda:0')
# MSE hier:  tensor(9.7164, device='cuda:0')
# 60.49382716049383 % done.
# MSE total:  tensor(4.3152, device='cuda:0')
# MSE states:  tensor(2.0727, device='cuda:0')
# MSE zones:  tensor(1.2728, device='cuda:0')
# MSE regions:  tensor(1.0472, device='cuda:0')
# MSE categories:  tensor(1.0109, device='cuda:0')
# MSE hier:  tensor(9.7189, device='cuda:0')
# 60.90534979423868 % done.
# MSE total:  tensor(4.3161, device='cuda:0')
# MSE states:  tensor(2.0721, device='cuda:0')
# MSE zones:  tensor(1.2723, device='cuda:0')
# MSE regions:  tensor(1.0467, device='cuda:0')
# MSE categories:  tensor(1.0110, device='cuda:0')
# MSE hier:  tensor(9.7182, device='cuda:0')
# 61.31687242798354 % done.
# MSE total:  tensor(4.3229, device='cuda:0')
# MSE states:  tensor(2.0671, device='cuda:0')
# MSE zones:  tensor(1.2689, device='cuda:0')
# MSE regions:  tensor(1.0433, device='cuda:0')
# MSE categories:  tensor(1.0123, device='cuda:0')
# MSE hier:  tensor(9.7143, device='cuda:0')
# 61.72839506172839 % done.
# MSE total:  tensor(4.3112, device='cuda:0')
# MSE states:  tensor(2.0618, device='cuda:0')
# MSE zones:  tensor(1.2717, device='cuda:0')
# MSE regions:  tensor(1.0456, device='cuda:0')
# MSE categories:  tensor(1.0155, device='cuda:0')
# MSE hier:  tensor(9.7058, device='cuda:0')
# 62.139917695473244 % done.
# MSE total:  tensor(4.3120, device='cuda:0')
# MSE states:  tensor(2.0614, device='cuda:0')
# MSE zones:  tensor(1.2714, device='cuda:0')
# MSE regions:  tensor(1.0453, device='cuda:0')
# MSE categories:  tensor(1.0157, device='cuda:0')
# MSE hier:  tensor(9.7057, device='cuda:0')
# 62.55144032921811 % done.
# MSE total:  tensor(4.3178, device='cuda:0')
# MSE states:  tensor(2.0586, device='cuda:0')
# MSE zones:  tensor(1.2694, device='cuda:0')
# MSE regions:  tensor(1.0430, device='cuda:0')
# MSE categories:  tensor(1.0176, device='cuda:0')
# MSE hier:  tensor(9.7063, device='cuda:0')
# 62.96296296296296 % done.
# MSE total:  tensor(4.3387, device='cuda:0')
# MSE states:  tensor(2.0389, device='cuda:0')
# MSE zones:  tensor(1.2714, device='cuda:0')
# MSE regions:  tensor(1.0512, device='cuda:0')
# MSE categories:  tensor(1.0186, device='cuda:0')
# MSE hier:  tensor(9.7189, device='cuda:0')
# 63.37448559670782 % done.
# MSE total:  tensor(4.3391, device='cuda:0')
# MSE states:  tensor(2.0387, device='cuda:0')
# MSE zones:  tensor(1.2710, device='cuda:0')
# MSE regions:  tensor(1.0508, device='cuda:0')
# MSE categories:  tensor(1.0187, device='cuda:0')
# MSE hier:  tensor(9.7183, device='cuda:0')
# 63.78600823045267 % done.
# MSE total:  tensor(4.3417, device='cuda:0')
# MSE states:  tensor(2.0372, device='cuda:0')
# MSE zones:  tensor(1.2683, device='cuda:0')
# MSE regions:  tensor(1.0474, device='cuda:0')
# MSE categories:  tensor(1.0200, device='cuda:0')
# MSE hier:  tensor(9.7146, device='cuda:0')
# 64.19753086419753 % done.
# MSE total:  tensor(4.3376, device='cuda:0')
# MSE states:  tensor(2.0389, device='cuda:0')
# MSE zones:  tensor(1.2715, device='cuda:0')
# MSE regions:  tensor(1.0510, device='cuda:0')
# MSE categories:  tensor(1.0191, device='cuda:0')
# MSE hier:  tensor(9.7181, device='cuda:0')
# 64.60905349794238 % done.
# MSE total:  tensor(4.3379, device='cuda:0')
# MSE states:  tensor(2.0387, device='cuda:0')
# MSE zones:  tensor(1.2711, device='cuda:0')
# MSE regions:  tensor(1.0505, device='cuda:0')
# MSE categories:  tensor(1.0192, device='cuda:0')
# MSE hier:  tensor(9.7175, device='cuda:0')
# 65.02057613168725 % done.
# MSE total:  tensor(4.3405, device='cuda:0')
# MSE states:  tensor(2.0372, device='cuda:0')
# MSE zones:  tensor(1.2685, device='cuda:0')
# MSE regions:  tensor(1.0474, device='cuda:0')
# MSE categories:  tensor(1.0206, device='cuda:0')
# MSE hier:  tensor(9.7143, device='cuda:0')
# 65.4320987654321 % done.
# MSE total:  tensor(4.3285, device='cuda:0')
# MSE states:  tensor(2.0397, device='cuda:0')
# MSE zones:  tensor(1.2734, device='cuda:0')
# MSE regions:  tensor(1.0507, device='cuda:0')
# MSE categories:  tensor(1.0243, device='cuda:0')
# MSE hier:  tensor(9.7166, device='cuda:0')
# 65.84362139917695 % done.
# MSE total:  tensor(4.3288, device='cuda:0')
# MSE states:  tensor(2.0395, device='cuda:0')
# MSE zones:  tensor(1.2732, device='cuda:0')
# MSE regions:  tensor(1.0503, device='cuda:0')
# MSE categories:  tensor(1.0244, device='cuda:0')
# MSE hier:  tensor(9.7163, device='cuda:0')
# 66.2551440329218 % done.
# MSE total:  tensor(4.3313, device='cuda:0')
# ...
# MSE zones:  tensor(1.2879, device='cuda:0')
# MSE regions:  tensor(1.0641, device='cuda:0')
# MSE categories:  tensor(1.0089, device='cuda:0')
# MSE hier:  tensor(9.9388, device='cuda:0')
# 78.18930041152264 % done.
# MSE total:  tensor(4.4375, device='cuda:0')
# MSE states:  tensor(2.1382, device='cuda:0')
# MSE zones:  tensor(1.2870, device='cuda:0')
# MSE regions:  tensor(1.0633, device='cuda:0')
# MSE categories:  tensor(1.0083, device='cuda:0')
# MSE hier:  tensor(9.9344, device='cuda:0')
# 78.60082304526749 % done.
# MSE total:  tensor(4.4286, device='cuda:0')
# MSE states:  tensor(2.1293, device='cuda:0')
# MSE zones:  tensor(1.2801, device='cuda:0')
# MSE regions:  tensor(1.0564, device='cuda:0')
# MSE categories:  tensor(1.0044, device='cuda:0')
# MSE hier:  tensor(9.8987, device='cuda:0')
# 79.01234567901234 % done.
# MSE total:  tensor(4.4379, device='cuda:0')
# MSE states:  tensor(2.1380, device='cuda:0')
# MSE zones:  tensor(1.2871, device='cuda:0')
# MSE regions:  tensor(1.0633, device='cuda:0')
# MSE categories:  tensor(1.0084, device='cuda:0')
# MSE hier:  tensor(9.9346, device='cuda:0')
# 79.42386831275721 % done.
# MSE total:  tensor(4.4368, device='cuda:0')
# MSE states:  tensor(2.1369, device='cuda:0')
# MSE zones:  tensor(1.2862, device='cuda:0')
# MSE regions:  tensor(1.0624, device='cuda:0')
# MSE categories:  tensor(1.0079, device='cuda:0')
# MSE hier:  tensor(9.9303, device='cuda:0')
# 79.83539094650206 % done.
# MSE total:  tensor(4.4279, device='cuda:0')
# MSE states:  tensor(2.1281, device='cuda:0')
# MSE zones:  tensor(1.2793, device='cuda:0')
# MSE regions:  tensor(1.0557, device='cuda:0')
# MSE categories:  tensor(1.0040, device='cuda:0')
# MSE hier:  tensor(9.8951, device='cuda:0')
# 80.24691358024691 % done.
# MSE total:  tensor(4.4320, device='cuda:0')
# MSE states:  tensor(2.1277, device='cuda:0')
# MSE zones:  tensor(1.2804, device='cuda:0')
# MSE regions:  tensor(1.0570, device='cuda:0')
# MSE categories:  tensor(1.0049, device='cuda:0')
# MSE hier:  tensor(9.9020, device='cuda:0')
# 80.65843621399176 % done.
# MSE total:  tensor(4.4310, device='cuda:0')
# MSE states:  tensor(2.1268, device='cuda:0')
# MSE zones:  tensor(1.2797, device='cuda:0')
# MSE regions:  tensor(1.0562, device='cuda:0')
# MSE categories:  tensor(1.0045, device='cuda:0')
# MSE hier:  tensor(9.8982, device='cuda:0')
# 81.06995884773663 % done.
# MSE total:  tensor(4.4228, device='cuda:0')
# MSE states:  tensor(2.1189, device='cuda:0')
# MSE zones:  tensor(1.2739, device='cuda:0')
# MSE regions:  tensor(1.0504, device='cuda:0')
# MSE categories:  tensor(1.0012, device='cuda:0')
# MSE hier:  tensor(9.8672, device='cuda:0')
# 81.48148148148148 % done.
# MSE total:  tensor(4.4413, device='cuda:0')
# MSE states:  tensor(2.1365, device='cuda:0')
# MSE zones:  tensor(1.2871, device='cuda:0')
# MSE regions:  tensor(1.0637, device='cuda:0')
# MSE categories:  tensor(1.0086, device='cuda:0')
# MSE hier:  tensor(9.9370, device='cuda:0')
# 81.89300411522635 % done.
# MSE total:  tensor(4.4402, device='cuda:0')
# MSE states:  tensor(2.1354, device='cuda:0')
# MSE zones:  tensor(1.2862, device='cuda:0')
# MSE regions:  tensor(1.0628, device='cuda:0')
# MSE categories:  tensor(1.0081, device='cuda:0')
# MSE hier:  tensor(9.9326, device='cuda:0')
# 82.3045267489712 % done.
# MSE total:  tensor(4.4309, device='cuda:0')
# MSE states:  tensor(2.1266, device='cuda:0')
# MSE zones:  tensor(1.2792, device='cuda:0')
# MSE regions:  tensor(1.0560, device='cuda:0')
# MSE categories:  tensor(1.0042, device='cuda:0')
# MSE hier:  tensor(9.8970, device='cuda:0')
# 82.71604938271605 % done.
# MSE total:  tensor(4.4405, device='cuda:0')
# MSE states:  tensor(2.1352, device='cuda:0')
# MSE zones:  tensor(1.2862, device='cuda:0')
# MSE regions:  tensor(1.0628, device='cuda:0')
# MSE categories:  tensor(1.0081, device='cuda:0')
# MSE hier:  tensor(9.9328, device='cuda:0')
# 83.1275720164609 % done.
# MSE total:  tensor(4.4394, device='cuda:0')
# MSE states:  tensor(2.1342, device='cuda:0')
# MSE zones:  tensor(1.2853, device='cuda:0')
# MSE regions:  tensor(1.0620, device='cuda:0')
# MSE categories:  tensor(1.0077, device='cuda:0')
# MSE hier:  tensor(9.9285, device='cuda:0')
# 83.53909465020575 % done.
# MSE total:  tensor(4.4302, device='cuda:0')
# MSE states:  tensor(2.1255, device='cuda:0')
# MSE zones:  tensor(1.2785, device='cuda:0')
# MSE regions:  tensor(1.0554, device='cuda:0')
# MSE categories:  tensor(1.0038, device='cuda:0')
# MSE hier:  tensor(9.8934, device='cuda:0')
# 83.9506172839506 % done.
# MSE total:  tensor(4.4342, device='cuda:0')
# MSE states:  tensor(2.1254, device='cuda:0')
# MSE zones:  tensor(1.2797, device='cuda:0')
# MSE regions:  tensor(1.0566, device='cuda:0')
# MSE categories:  tensor(1.0048, device='cuda:0')
# MSE hier:  tensor(9.9007, device='cuda:0')
# 84.36213991769547 % done.
# MSE total:  tensor(4.4332, device='cuda:0')
# MSE states:  tensor(2.1245, device='cuda:0')
# MSE zones:  tensor(1.2790, device='cuda:0')
# MSE regions:  tensor(1.0559, device='cuda:0')
# MSE categories:  tensor(1.0043, device='cuda:0')
# MSE hier:  tensor(9.8969, device='cuda:0')
# 84.77366255144034 % done.
# MSE total:  tensor(4.4249, device='cuda:0')
# MSE states:  tensor(2.1167, device='cuda:0')
# MSE zones:  tensor(1.2732, device='cuda:0')
# MSE regions:  tensor(1.0501, device='cuda:0')
# MSE categories:  tensor(1.0011, device='cuda:0')
# MSE hier:  tensor(9.8661, device='cuda:0')
# 85.18518518518519 % done.
# MSE total:  tensor(4.4582, device='cuda:0')
# MSE states:  tensor(2.1183, device='cuda:0')
# MSE zones:  tensor(1.2810, device='cuda:0')
# MSE regions:  tensor(1.0608, device='cuda:0')
# MSE categories:  tensor(1.0075, device='cuda:0')
# MSE hier:  tensor(9.9259, device='cuda:0')
# 85.59670781893004 % done.
# MSE total:  tensor(4.4570, device='cuda:0')
# MSE states:  tensor(2.1174, device='cuda:0')
# MSE zones:  tensor(1.2802, device='cuda:0')
# MSE regions:  tensor(1.0600, device='cuda:0')
# MSE categories:  tensor(1.0071, device='cuda:0')
# MSE hier:  tensor(9.9217, device='cuda:0')
# 86.0082304526749 % done.
# MSE total:  tensor(4.4469, device='cuda:0')
# MSE states:  tensor(2.1098, device='cuda:0')
# MSE zones:  tensor(1.2739, device='cuda:0')
# MSE regions:  tensor(1.0537, device='cuda:0')
# MSE categories:  tensor(1.0036, device='cuda:0')
# MSE hier:  tensor(9.8879, device='cuda:0')
# 86.41975308641975 % done.
# MSE total:  tensor(4.4572, device='cuda:0')
# MSE states:  tensor(2.1175, device='cuda:0')
# MSE zones:  tensor(1.2804, device='cuda:0')
# MSE regions:  tensor(1.0601, device='cuda:0')
# MSE categories:  tensor(1.0072, device='cuda:0')
# MSE hier:  tensor(9.9223, device='cuda:0')
# 86.83127572016461 % done.
# MSE total:  tensor(4.4560, device='cuda:0')
# MSE states:  tensor(2.1166, device='cuda:0')
# MSE zones:  tensor(1.2796, device='cuda:0')
# MSE regions:  tensor(1.0593, device='cuda:0')
# MSE categories:  tensor(1.0067, device='cuda:0')
# MSE hier:  tensor(9.9182, device='cuda:0')
# 87.24279835390946 % done.
# MSE total:  tensor(4.4461, device='cuda:0')
# MSE states:  tensor(2.1091, device='cuda:0')
# MSE zones:  tensor(1.2734, device='cuda:0')
# MSE regions:  tensor(1.0531, device='cuda:0')
# MSE categories:  tensor(1.0034, device='cuda:0')
# MSE hier:  tensor(9.8850, device='cuda:0')
# 87.65432098765432 % done.
# MSE total:  tensor(4.4498, device='cuda:0')
# MSE states:  tensor(2.1110, device='cuda:0')
# MSE zones:  tensor(1.2753, device='cuda:0')
# MSE regions:  tensor(1.0548, device='cuda:0')
# MSE categories:  tensor(1.0045, device='cuda:0')
# MSE hier:  tensor(9.8954, device='cuda:0')
# 88.06584362139918 % done.
# MSE total:  tensor(4.4488, device='cuda:0')
# MSE states:  tensor(2.1101, device='cuda:0')
# MSE zones:  tensor(1.2746, device='cuda:0')
# MSE regions:  tensor(1.0541, device='cuda:0')
# MSE categories:  tensor(1.0042, device='cuda:0')
# MSE hier:  tensor(9.8917, device='cuda:0')
# 88.47736625514403 % done.
# MSE total:  tensor(4.4397, device='cuda:0')
# MSE states:  tensor(2.1033, device='cuda:0')
# MSE zones:  tensor(1.2693, device='cuda:0')
# MSE regions:  tensor(1.0487, device='cuda:0')
# MSE categories:  tensor(1.0013, device='cuda:0')
# MSE hier:  tensor(9.8623, device='cuda:0')
# 88.88888888888889 % done.
# MSE total:  tensor(4.4408, device='cuda:0')
# MSE states:  tensor(2.2355, device='cuda:0')
# MSE zones:  tensor(1.3966, device='cuda:0')
# MSE regions:  tensor(1.1601, device='cuda:0')
# MSE categories:  tensor(1.1026, device='cuda:0')
# MSE hier:  tensor(10.3357, device='cuda:0')
# 89.30041152263375 % done.
# MSE total:  tensor(4.4395, device='cuda:0')
# MSE states:  tensor(2.2341, device='cuda:0')
# MSE zones:  tensor(1.3951, device='cuda:0')
# MSE regions:  tensor(1.1586, device='cuda:0')
# MSE categories:  tensor(1.1018, device='cuda:0')
# MSE hier:  tensor(10.3292, device='cuda:0')
# 89.7119341563786 % done.
# MSE total:  tensor(4.4284, device='cuda:0')
# MSE states:  tensor(2.2222, device='cuda:0')
# MSE zones:  tensor(1.3837, device='cuda:0')
# MSE regions:  tensor(1.1470, device='cuda:0')
# MSE categories:  tensor(1.0961, device='cuda:0')
# MSE hier:  tensor(10.2773, device='cuda:0')
# 90.12345679012346 % done.
# MSE total:  tensor(4.4396, device='cuda:0')
# MSE states:  tensor(2.2334, device='cuda:0')
# MSE zones:  tensor(1.3946, device='cuda:0')
# MSE regions:  tensor(1.1588, device='cuda:0')
# MSE categories:  tensor(1.1019, device='cuda:0')
# MSE hier:  tensor(10.3282, device='cuda:0')
# 90.53497942386831 % done.
# MSE total:  tensor(4.4383, device='cuda:0')
# MSE states:  tensor(2.2320, device='cuda:0')
# MSE zones:  tensor(1.3932, device='cuda:0')
# MSE regions:  tensor(1.1573, device='cuda:0')
# MSE categories:  tensor(1.1011, device='cuda:0')
# MSE hier:  tensor(10.3218, device='cuda:0')
# 90.94650205761316 % done.
# MSE total:  tensor(4.4274, device='cuda:0')
# MSE states:  tensor(2.2203, device='cuda:0')
# MSE zones:  tensor(1.3821, device='cuda:0')
# MSE regions:  tensor(1.1459, device='cuda:0')
# MSE categories:  tensor(1.0955, device='cuda:0')
# MSE hier:  tensor(10.2711, device='cuda:0')
# 91.35802469135803 % done.
# MSE total:  tensor(4.4306, device='cuda:0')
# MSE states:  tensor(2.2165, device='cuda:0')
# MSE zones:  tensor(1.3804, device='cuda:0')
# MSE regions:  tensor(1.1487, device='cuda:0')
# MSE categories:  tensor(1.0964, device='cuda:0')
# MSE hier:  tensor(10.2727, device='cuda:0')
# 91.76954732510289 % done.
# MSE total:  tensor(4.4294, device='cuda:0')
# MSE states:  tensor(2.2153, device='cuda:0')
# MSE zones:  tensor(1.3793, device='cuda:0')
# MSE regions:  tensor(1.1474, device='cuda:0')
# MSE categories:  tensor(1.0958, device='cuda:0')
# MSE hier:  tensor(10.2673, device='cuda:0')
# 92.18106995884774 % done.
# MSE total:  tensor(4.4196, device='cuda:0')
# MSE states:  tensor(2.2053, device='cuda:0')
# MSE zones:  tensor(1.3704, device='cuda:0')
# MSE regions:  tensor(1.1375, device='cuda:0')
# MSE categories:  tensor(1.0910, device='cuda:0')
# MSE hier:  tensor(10.2237, device='cuda:0')
# 92.5925925925926 % done.
# MSE total:  tensor(4.4427, device='cuda:0')
# MSE states:  tensor(2.2302, device='cuda:0')
# MSE zones:  tensor(1.3947, device='cuda:0')
# MSE regions:  tensor(1.1592, device='cuda:0')
# MSE categories:  tensor(1.1020, device='cuda:0')
# MSE hier:  tensor(10.3288, device='cuda:0')
# 93.00411522633745 % done.
# MSE total:  tensor(4.4413, device='cuda:0')
# MSE states:  tensor(2.2288, device='cuda:0')
# MSE zones:  tensor(1.3933, device='cuda:0')
# MSE regions:  tensor(1.1577, device='cuda:0')
# MSE categories:  tensor(1.1013, device='cuda:0')
# MSE hier:  tensor(10.3223, device='cuda:0')
# 93.4156378600823 % done.
# MSE total:  tensor(4.4299, device='cuda:0')
# MSE states:  tensor(2.2173, device='cuda:0')
# MSE zones:  tensor(1.3819, device='cuda:0')
# MSE regions:  tensor(1.1462, device='cuda:0')
# MSE categories:  tensor(1.0956, device='cuda:0')
# MSE hier:  tensor(10.2710, device='cuda:0')
# 93.82716049382715 % done.
# MSE total:  tensor(4.4414, device='cuda:0')
# MSE states:  tensor(2.2281, device='cuda:0')
# MSE zones:  tensor(1.3928, device='cuda:0')
# MSE regions:  tensor(1.1579, device='cuda:0')
# MSE categories:  tensor(1.1013, device='cuda:0')
# MSE hier:  tensor(10.3215, device='cuda:0')
# 94.23868312757202 % done.
# MSE total:  tensor(4.4400, device='cuda:0')
# MSE states:  tensor(2.2268, device='cuda:0')
# MSE zones:  tensor(1.3914, device='cuda:0')
# MSE regions:  tensor(1.1564, device='cuda:0')
# MSE categories:  tensor(1.1006, device='cuda:0')
# MSE hier:  tensor(10.3152, device='cuda:0')
# 94.65020576131687 % done.
# MSE total:  tensor(4.4289, device='cuda:0')
# MSE states:  tensor(2.2155, device='cuda:0')
# MSE zones:  tensor(1.3804, device='cuda:0')
# MSE regions:  tensor(1.1451, device='cuda:0')
# MSE categories:  tensor(1.0950, device='cuda:0')
# MSE hier:  tensor(10.2649, device='cuda:0')
# 95.06172839506173 % done.
# MSE total:  tensor(4.4321, device='cuda:0')
# MSE states:  tensor(2.2124, device='cuda:0')
# MSE zones:  tensor(1.3789, device='cuda:0')
# MSE regions:  tensor(1.1480, device='cuda:0')
# MSE categories:  tensor(1.0960, device='cuda:0')
# MSE hier:  tensor(10.2674, device='cuda:0')
# 95.47325102880659 % done.
# MSE total:  tensor(4.4309, device='cuda:0')
# MSE states:  tensor(2.2113, device='cuda:0')
# MSE zones:  tensor(1.3778, device='cuda:0')
# MSE regions:  tensor(1.1467, device='cuda:0')
# MSE categories:  tensor(1.0954, device='cuda:0')
# MSE hier:  tensor(10.2621, device='cuda:0')
# 95.88477366255144 % done.
# MSE total:  tensor(4.4209, device='cuda:0')
# MSE states:  tensor(2.2015, device='cuda:0')
# MSE zones:  tensor(1.3690, device='cuda:0')
# MSE regions:  tensor(1.1369, device='cuda:0')
# MSE categories:  tensor(1.0907, device='cuda:0')
# MSE hier:  tensor(10.2190, device='cuda:0')
# 96.29629629629629 % done.
# MSE total:  tensor(4.4526, device='cuda:0')
# MSE states:  tensor(2.1980, device='cuda:0')
# MSE zones:  tensor(1.3823, device='cuda:0')
# MSE regions:  tensor(1.1532, device='cuda:0')
# MSE categories:  tensor(1.0988, device='cuda:0')
# MSE hier:  tensor(10.2849, device='cuda:0')
# 96.70781893004116 % done.
# MSE total:  tensor(4.4511, device='cuda:0')
# MSE states:  tensor(2.1970, device='cuda:0')
# MSE zones:  tensor(1.3809, device='cuda:0')
# MSE regions:  tensor(1.1518, device='cuda:0')
# MSE categories:  tensor(1.0981, device='cuda:0')
# MSE hier:  tensor(10.2789, device='cuda:0')
# 97.11934156378601 % done.
# MSE total:  tensor(4.4392, device='cuda:0')
# MSE states:  tensor(2.1878, device='cuda:0')
# MSE zones:  tensor(1.3706, device='cuda:0')
# MSE regions:  tensor(1.1410, device='cuda:0')
# MSE categories:  tensor(1.0930, device='cuda:0')
# MSE hier:  tensor(10.2316, device='cuda:0')
# 97.53086419753086 % done.
# MSE total:  tensor(4.4512, device='cuda:0')
# MSE states:  tensor(2.1968, device='cuda:0')
# MSE zones:  tensor(1.3806, device='cuda:0')
# MSE regions:  tensor(1.1521, device='cuda:0')
# MSE categories:  tensor(1.0982, device='cuda:0')
# MSE hier:  tensor(10.2789, device='cuda:0')
# 97.94238683127571 % done.
# MSE total:  tensor(4.4498, device='cuda:0')
# MSE states:  tensor(2.1957, device='cuda:0')
# MSE zones:  tensor(1.3793, device='cuda:0')
# MSE regions:  tensor(1.1507, device='cuda:0')
# MSE categories:  tensor(1.0975, device='cuda:0')
# MSE hier:  tensor(10.2731, device='cuda:0')
# 98.35390946502058 % done.
# MSE total:  tensor(4.4381, device='cuda:0')
# MSE states:  tensor(2.1867, device='cuda:0')
# MSE zones:  tensor(1.3694, device='cuda:0')
# MSE regions:  tensor(1.1400, device='cuda:0')
# MSE categories:  tensor(1.0925, device='cuda:0')
# MSE hier:  tensor(10.2267, device='cuda:0')
# 98.76543209876543 % done.
# MSE total:  tensor(4.4417, device='cuda:0')
# MSE states:  tensor(2.1870, device='cuda:0')
# MSE zones:  tensor(1.3692, device='cuda:0')
# MSE regions:  tensor(1.1435, device='cuda:0')
# MSE categories:  tensor(1.0939, device='cuda:0')
# MSE hier:  tensor(10.2353, device='cuda:0')
# 99.1769547325103 % done.
# MSE total:  tensor(4.4404, device='cuda:0')
# MSE states:  tensor(2.1860, device='cuda:0')
# MSE zones:  tensor(1.3682, device='cuda:0')
# MSE regions:  tensor(1.1423, device='cuda:0')
# MSE categories:  tensor(1.0934, device='cuda:0')
# MSE hier:  tensor(10.2303, device='cuda:0')
# 99.58847736625515 % done.
# MSE total:  tensor(4.4300, device='cuda:0')
# MSE states:  tensor(2.1779, device='cuda:0')
# MSE zones:  tensor(1.3602, device='cuda:0')
# MSE regions:  tensor(1.1330, device='cuda:0')
# MSE categories:  tensor(1.0890, device='cuda:0')
# MSE hier:  tensor(10.1902, device='cuda:0')
# 100.0 % done.

# %%
print(best_lambdas)
print(best_lr)
# Out:
# {'lambda_tot': 0.3, 'lambda_states': 0.1, 'lambda_zones': 0.1, 'lambda_regions': 0.03, 'lambda_categories': 1}
# 1.0

# %%
# best_lr = 1.0
# best_lambdas = {'lambda_tot': 0.3, 'lambda_states': 0.1, 'lambda_zones': 0.1, 'lambda_regions': 0.03, 'lambda_categories': 1}
h_list = [i for i in range(0, 24)] #h correspond au lag h_learn-h
h_learn=24
lambda_r = best_lr
lambdas = best_lambdas
start = 12*18*4//5
end = 12*18

mse_tot, mse_states, mse_zones, mse_regions, mse_categories, mse_hier, theta_transfer, se_by_level = weakl_bu_transfer(lambdas, lambda_r, h_learn, h_list, start, end, tourism_data)
# Out:
# MSE total:  tensor(3.0623, device='cuda:0')
# MSE states:  tensor(1.6595, device='cuda:0')
# MSE zones:  tensor(1.2711, device='cuda:0')
# MSE regions:  tensor(1.1521, device='cuda:0')
# MSE categories:  tensor(1.1260, device='cuda:0')
# MSE hier:  tensor(8.2709, device='cuda:0')

# %%
n_test =se_by_level.shape[0]
print("MSE total: " +str(se_by_level["total"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["total"],12))))
print("MSE states: " +str(se_by_level["states"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["states"],12))))
print("MSE zones: " +str(se_by_level["zones"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["zones"],12))))
print("MSE regions: " +str(se_by_level["regions"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["regions"],12))))
print("MSE categories: " +str(se_by_level["categories"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["categories"],12))))
print("MSE hier: " +str(se_by_level["hier"].mean())+ " -+ "+str(1/np.sqrt(n_test)*np.sqrt(mbb_var(se_by_level["hier"],12))))
# Out:
# MSE total: 3.0622547818617316 -+ 0.34294251969767103
# MSE states: 1.659505637954397 -+ 0.1414846281535945
# MSE zones: 1.2711022096127644 -+ 0.04591777088586882
# MSE regions: 1.1520754467167762 -+ 0.023459135385410463
# MSE categories: 1.1259771649789247 -+ 0.030154876587399407
# MSE hier: 8.270915241124595 -+ 0.4307229141006
